# %%
import random
import json
from pprint import pprint
import nltk
import re
import string
from nltk.tag.stanford import StanfordPOSTagger
from nltk.tag.stanford import StanfordNERTagger
post = StanfordPOSTagger('lib/stanford-postagger-2014-08-27/models/english-bidirectional-distsim.tagger', 'lib/stanford-postagger-2014-08-27/stanford-postagger.jar', 'utf-8') # doctest: +SKIP

# %% [markdown]
# ### make a random sample of 2 and smaple of 5 from the json data as starting data.
# Note: only run this code once. Currently commented out.

# %%
# with open('movies-with-roles-summaries.json')as data_file:
#     data = json.load(data_file)

# print(type(data))

# %%
# data_sample_2 = random.sample((data.items()), 2)

# %%
# data_sample_5 = random.sample((data.items()), 5)

# %%
# with open('data_sample_2.json', 'w') as outfile:
#     json.dump(data_sample_2, outfile)

# %%
# with open('data_sample_5.json', 'w') as outfile:
#     json.dump(data_sample_5, outfile)

# %% [markdown]
# ###Load in the sample of five

# %%
with open('data_sample_5.json') as sample:
    sample = json.load(sample)

# %%
print(sample)
# Out:
# [['city after dark.1980', {'year': '1980', 'num_ratings': '94', 'id': 19412, 'roles': [{'role': 'Vanessa', 'gender': 'F'}, {'role': 'Nelie', 'gender': 'F'}, {'role': 'Kano', 'gender': 'F'}, {'role': 'Cora', 'gender': 'F'}, {'role': 'Bea', 'gender': 'F'}, {'role': 'Gaying', 'gender': 'F'}, {'role': 'Adelina', 'gender': 'F'}, {'role': "Vanessa's Mother", 'gender': 'F'}, {'role': 'Virgie', 'gender': 'F'}, {'role': 'Baby', 'gender': 'F'}, {'role': 'Marichu', 'gender': 'F'}, {'role': "Adelina's Client", 'gender': 'M'}, {'role': 'Manay Sharon', 'gender': 'M'}, {'role': 'Recruiter', 'gender': 'M'}, {'role': 'Mall couple', 'gender': 'M'}, {'role': 'Alex', 'gender': 'M'}, {'role': 'Pebrero', 'gender': 'M'}, {'role': 'Greggy Williams', 'gender': 'M'}, {'role': "Virgir's Husband", 'gender': 'M'}], 'summaries_imdb': ["The hidden nightlife of ordinary people living in Manila unveils. Lovers and families' conflicts are radically pitted against each other as they live in the night streets rampant with drugs and prostitution. The outstanding narrative explicitly unravels the various characters and episodes. This landmark film of Ishmael Bernal depicts the darkness of city life so vividly that it was once prohibited to use the word 'Manila' on its title."], 'language': None, 'ratings': '7.5', 'version': 'I', 'summaries_wikipedia': [], 'title': 'City After Dark', 'venue': 'T'}], ['angelica.2015', {'year': '2015', 'num_ratings': '60', 'id': 7054, 'roles': [{'role': 'Midwife', 'gender': 'F'}, {'role': 'Angelica', 'gender': 'F'}, {'role': 'Snobby Woman', 'gender': 'F'}, {'role': 'Lady in Park', 'gender': 'F'}, {'role': 'Nora', 'gender': 'F'}, {'role': 'Beggar girl', 'gender': 'F'}, {'role': 'Young Angelica', 'gender': 'F'}, {'role': 'Constance', 'gender': 'F'}, {'role': 'Anne Montague', 'gender': 'F'}, {'role': 'Older Constance', 'gender': 'F'}, {'role': 'Spirit Girl', 'gender': 'F'}, {'role': 'Unnamed Scientist', 'gender': 'M'}, {'role': 'Unnamed Scientist', 'gender': 'M'}, {'role': 'Medical Student', 'gender': 'M'}, {'role': 'Mr. Pendleton', 'gender': 'M'}, {'role': 'Spirit Boy', 'gender': 'M'}, {'role': 'Unnamed Scientist', 'gender': 'M'}, {'role': 'Bookseller', 'gender': 'M'}, {'role': 'Dr. Joseph Barton', 'gender': 'M'}], 'summaries_imdb': ['In Victorian England, sexual repression opens a rift between young couple Constance and Joseph after the birth of their daughter Angelica. As Constance becomes more and more protective of little Angelica, a ghostly predator begins to make its way through the house late at night... ANGELICA is a spellbinding ghost story about desire, repression and its consequences... The new film by Mitchell Lichtenstein, director of HAPPY TEARS and the cult favorite TEETH.'], 'language': None, 'ratings': '5.8', 'version': 'I', 'summaries_wikipedia': [], 'title': 'Angelica', 'venue': 'T'}], ['bedazzled.2000', {'year': '2000', 'num_ratings': '78401', 'id': 11106, 'roles': [{'role': 'DV8 Clubgoer', 'gender': 'F'}, {'role': 'DV8 Clubgoer', 'gender': 'F'}, {'role': 'Cheerleader/Dancer', 'gender': 'F'}, {'role': 'Cheerleader/Dancer', 'gender': 'F'}, {'role': 'DV8 Waitress', 'gender': 'F'}, {'role': 'Cheerleader/Dancer', 'gender': 'F'}, {'role': 'Churchgoer', 'gender': 'F'}, {'role': 'Cheerleader/Dancer', 'gender': 'F'}, {'role': 'Caged Go-Go Dancer', 'gender': 'F'}, {'role': 'Tech Support Advisor', 'gender': 'F'}, {'role': 'Play Actor', 'gender': 'F'}, {'role': 'Cheerleader/Dancer', 'gender': 'F'}, {'role': 'The Devil', 'gender': 'F'}, {'role': 'Fly Girl', 'gender': 'F'}, {'role': 'DV8 Clubgoer', 'gender': 'F'}, {'role': 'Cheerleader/Dancer', 'gender': 'F'}, {'role': 'Alison/Nicole', 'gender': 'F'}, {'role': 'DV8 Clubgoer', 'gender': 'F'}, {'role': 'Fly Girl', 'gender': 'F'}, {'role': 'Cheerleader/Dancer', 'gender': 'F'}, {'role': 'Cheerleader/Dancer', 'gender': 'F'}, {'role': 'Carol/Penthouse Hostess', 'gender': 'F'}, {'role': 'Girl at Beer Garden', 'gender': 'F'}, {'role': 'Girl at Beer Garden', 'gender': 'F'}, {'role': 'Fly ...

# %% [markdown]
# ###More data cleaning

# %%
# get rid of ([[ in the wikipidia summaries
for i in range(len(sample)):
#     summaries_imdb = sample[i][1]["summaries_imdb"]
    summaries_wiki = sample[i][1]['summaries_wikipedia']
    if len(summaries_wiki) > 0:
        summaries_wiki = re.sub(r'\s\(\[\[', ' ', summaries_wiki[0])
        sample[i][1]['summaries_wikipedia'][0] = summaries_wiki

# %% [markdown]
# ###Tagging

# %%
#specify stage to get the text format you need
def ie_preprocess(document, lower='false', stage="sents"):
    sentences = nltk.sent_tokenize(document)
    if stage == 'sents':
        return sentences
    sentences = [nltk.word_tokenize(sent) for sent in sentences]
    if lower == "true":
        for sent in sentences:
            for i in range(len(sent)):
                if sent[i] != sent[i].lower():
                    sent[i] = sent[i].lower()
    if stage == "words":
        return sentences
    sentences = [nltk.pos_tag(sent) for sent in sentences]
    if stage == "pos":
        return sentences
    if stage == "ner":
        return nert.tag(document.split())

# %%
# pos tag summaries and roles
for i in range(len(sample)):
    summaries_imdb = sample[i][1]["summaries_imdb"]
    summaries_wiki = sample[i][1]['summaries_wikipedia']
    roles = sample[i][1]['roles']
    if len(summaries_imdb) > 0:
        sample[i][1]["summaries_imdb_pos"] = \
        ie_preprocess(summaries_imdb[0])
        sample[i][1]["summaries_imdb_ner"] = \
        ie_preprocess(summaries_imdb[0], stage="ner")
    if len(summaries_wiki) > 0:
        sample[i][1]["summaries_wikipedia_pos"] = ie_preprocess(summaries_wiki[0])
        sample[i][1]["summaries_wikipedia_ner"] = ie_preprocess(summaries_wiki[0], stage='ner')

    
    
    if len(roles) > 0:
#All words in roles are originally capitalized. This confuses the tagger and all words
# are tagged NN*. So we lowercase all the words in role. 
        for j in range(len(roles)):
            roles[j]['role_pos'] = ie_preprocess(roles[j]["role"], lower="true")
#the NLP NER does not recognize named entities that are lowercase. It does do a good job
# tagging entities in sentences that are all capitalized. Therefore, we capitalize 
# all pos-tagged words in role for NER purposes.
#         for i in range(len(roles[j]['role_pos'][0])):
#             roles[j]['role_pos'][0][i] = list(roles[j]['role_pos'][0][i])
#             roles[j]['role_pos'][0][i][0] = roles[j]['role_pos'][0][i][0].capitalize()
# tag named entities using nltk.ne_chunk, didn't work well.
#         roles[j]['role_ne'] = [nltk.ne_chunk(pts) for pts in roles[j]['role_pos']]

# %%
nert.tag(sample[2][1]['summaries_wikipedia'][0].split())
# Out:
# [('Elliot', 'PERSON'),
#  ('Richards', 'PERSON'),
#  ('is', 'O'),
#  ('a', 'O'),
#  ('geeky,', 'O'),
#  ('over-zealous', 'O'),
#  ('man', 'O'),
#  ('working', 'O'),
#  ('a', 'O'),
#  ('dead-end', 'O'),
#  ('technical', 'O'),
#  ('support', 'O'),
#  ('job', 'O'),
#  ('in', 'O'),
#  ('a', 'O'),
#  ('San', 'LOCATION'),
#  ('Francisco', 'LOCATION'),
#  ('computer', 'O'),
#  ('company.', 'O'),
#  ('He', 'O'),
#  ('has', 'O'),
#  ('no', 'O'),
#  ('friends', 'O'),
#  ('and', 'O'),
#  ('his', 'O'),
#  ('co-workers', 'O'),
#  ('use', 'O'),
#  ('him,', 'O'),
#  ('knowing', 'O'),
#  ('he', 'O'),
#  ('will', 'O'),
#  ('do', 'O'),
#  ('anything', 'O'),
#  ('for', 'O'),
#  ('acceptance.', 'O'),
#  ('He', 'O'),
#  ('has', 'O'),
#  ('a', 'O'),
#  ('crush', 'O'),
#  ('on', 'O'),
#  ('his', 'O'),
#  ('colleague,', 'O'),
#  ('Alison', 'PERSON'),
#  ('Gardner', 'PERSON'),
#  (',', 'O'),
#  ('but', 'O'),
#  ('lacks', 'O'),
#  ('the', 'O'),
#  ('courage', 'O'),
#  ('to', 'O'),
#  ('ask', 'O'),
#  ('her', 'O'),
#  ('out.', 'O'),
#  ('After', 'O'),
#  ('Elliot', 'PERSON'),
#  ('is', 'O'),
#  ('again', 'O'),
#  ('ditched', 'O'),
#  ('by', 'O'),
#  ('his', 'O'),
#  ('co-workers,', 'O'),
#  ('at', 'O'),
#  ('a', 'O'),
#  ('bar', 'O'),
#  ('while', 'O'),
#  ('trying', 'O'),
#  ('to', 'O'),
#  ('talk', 'O'),
#  ('to', 'O'),
#  ('Alison,', 'O'),
#  ('he', 'O'),
#  ('says', 'O'),
#  ('to', 'O'),
#  ('himself', 'O'),
#  ('that', 'O'),
#  ('he', 'O'),
#  ('would', 'O'),
#  ('give', 'O'),
#  ('anything', 'O'),
#  ('for', 'O'),
#  ('Alison', 'PERSON'),
#  ('to', 'O'),
#  ('be', 'O'),
#  ('with', 'O'),
#  ('him.', 'O'),
#  ('Satan', 'O'),
#  (',', 'O'),
#  ('in', 'O'),
#  ('the', 'O'),
#  ('form', 'O'),
#  ('of', 'O'),
#  ('a', 'O'),
#  ('beautiful', 'O'),
#  ('woman,', 'O'),
#  ('overhears', 'O'),
#  ('him', 'O'),
#  ('and', 'O'),
#  ('offers', 'O'),
#  ('to', 'O'),
#  ('give', 'O'),
#  ('Elliot', 'PERSON'),
#  ('seven', 'O'),
#  ('wishes', 'O'),
#  ('in', 'O'),
#  ('return', 'O'),
#  ('for', 'O'),
#  ('his', 'O'),
#  ('soul.', 'O'),
#  ('As', 'O'),
#  ('a', 'O'),
#  ('test,', 'O'),
#  ('he', 'O'),
#  ('wishes', 'O'),
#  ('for', 'O'),
#  ('a', 'O'),
#  ('Big', 'O'),
#  ('Mac', 'O'),
#  ('and', 'O'),
#  ('Coke.', 'O'),
#  ('Satan', 'PERSON'),
#  ('takes', 'O'),
#  ('him', 'O'),
#  ('to', 'O'),
#  ("McDonald's", 'O'),
#  ('and', 'O'),
#  ('places', 'O'),
#  ('the', 'O'),
#  ('order.', 'O'),
#  ('Elliot', 'PERSON'),
#  ('has', 'O'),
#  ('to', 'O'),
#  ('pay', 'O'),
#  ('for', 'O'),
#  ('it,', 'O'),
#  ('because,', 'O'),
#  ('"there', 'O'),
#  ("ain't", 'O'),
#  ('no', 'O'),
#  ('such', 'O'),
#  ('thing', 'O'),
#  ('as', 'O'),
#  ('a', 'O'),
#  ('free', 'O'),
#  ('lunch."', 'O'),
#  ('After', 'O'),
#  ('taking', 'O'),
#  ('Elliot', 'PERSON'),
#  ('to', 'O'),
#  ('her', 'O'),
#  ('office,', 'O'),
#  ('based', 'O'),
#  ('at', 'O'),
#  ('a', 'O'),
#  ('nightclub', 'O'),
#  ('in', 'O'),
#  ('Oakland,', 'O'),
#  ('Satan', 'O'),
#  ('convinces', 'O'),
#  ('Elliot', 'PERSON'),
#  ('to', 'O'),
#  ('sign', 'O'),
#  ('her', 'O'),
#  ('contract,', 'O'),
#  ('and', 'O'),
#  ('delivers', 'O'),
#  ('further', 'O'),
#  ('wishes.', 'O'),
#  ('Each', 'O'),
#  ('wish', 'O'),
#  ('has', 'O'),
#  ('Elliot', 'PERSON'),
#  ('living', 'O'),
#  ('them', 'O'),
#  ('out', 'O'),
#  ('with', 'O'),
#  ('Alison', 'PERSON'),
#  ('and', 'O'),
#  ('his', 'O'),
#  ('co-workers', 'O'),
#  ('in', 'O'),
#  ('surrogate', 'O'),
#  ('roles.', 'O'),
#  ('However,', 'O'),
#  ('he', 'O'),
#  ("doesn't", 'O'),
#  ('know', 'O'),
#  ('that', 'O'),
#  ('Satan', 'O'),
#  ('will', 'O'),
#  ('always', 'O'),
#  ('spoil', 'O'),
#  ('his', 'O'),
#  ('wishes', 'O'),
#  ('by', 'O'),
#  ('adding', 'O'),
#  ('something', 'O'),
#  ('he', 'O'),
#  ("doesn't", 'O'),
#  ('want.', 'O'),
#  ('Elliot', 'PERSON'),
#  ('wishes', 'O'),
#  ('to', 'O'),
#  ('be', 'O'),
#  ('rich', 'O'),
#  ('and', 'O'),
#  ('powerful,', 'O'),
#  ('with', 'O'),
#  ('Alison', 'PERSON'),
#  ('as', 'O'),
#  ('his', 'O'),
#  ('wife.', 'O'),
#  ('Satan', 'O'),
#  ('makes', 'O'),
#  ('him', 'O'),
#  ('a', 'O'),
#  ('Colombian', 'O'),
#  ('drug', 'O'),
#  ('lord', 'O'),
#  ('whose', 'O'),
#  ('wife', 'O'),
#  ('despises', 'O'),
#  ('him', 'O'),
#  ('and', 'O'),
#  ('cheats', 'O'),
#  ('on', 'O'),
#  ('him', 'O'),
#  ('with', 'O'),
#  ('Raul,', 'O'),
#  ('his', 'O'),
#  ('co-worker,', 'O'),
#  ('who', 'O'),
#  ('is', 'O'),
#  ('secretly', 'O'),
#  ('planning', 'O'),
#  ('to', 'O'),
#  ('get', 'O'),
#  ('rid', 'O'),
#  ('of', 'O'),
#  ('Elliot', 'PERSON'),
#  ('and', 'O'),
#  ('take', 'O'),
#  ('his', 'O'),
#  ('position', 'O'),
#  ('and', 'O'),
#  ('property.', 'O'),
#  ('Soon', 'O'),
#  ('after', 'O'),
#  ('there', 'O'),
#  ('is', 'O'),
#  ('a', 'O'),
#  ('firefight', 'O'),
#  ('between', 'O'),
#  ('his', 'O'),
#  ('and', 'O'),
#  ("Raul's", 'O'),
#  ('people', 'O'),
#  ('where', 'O'),
#  ('Elliot', 'PERSON'),
#  ('"dies".', 'O'),
#  ('When', 'O'),
#  ('he', 'O'),
#  ('returns', 'O'),
#  ('to', 'O'),
#  ('the', 'O'),
#  ('real', 'O'),
#  ('world,', 'O'),
#  ('Satan', 'O'),
#  ('points', 'O'),
#  ('out', 'O'),
#  ('that', 'O'),
#  ('he', 'O'),
#  ('never', 'O'),
#  ('wished', 'O'),
#  ('for', 'O'),
#  ('Alison', 'PERSON'),
#  ('to', 'O'),
#  ('love', 'O'),
#  ('him.', 'O'),
#  ('Secondly,', 'O'),
#  ('Elliot', 'PERSON'),
#  ('wishes', 'O'),
#  ('to', 'O'),
#  ('be', 'O'),
#  ('emotionally', 'O'),
#  ('sensitive', 'O'),
#  ('so', 'O'),
#  ('he', 'O'),
#  ('will', 'O'),
#  ('understand', 'O'),
#  ('the', 'O'),
#  ('needs', 'O'),
#  ('and', 'O'),
#  ('desires', 'O'),
#  ('of', 'O'),
#  ('women.', 'O'),
#  ('Satan', 'O'),
#  ('makes', 'O'),
#  ('him', 'O'),
#  ('so', 'O'),
#  ('sensitive', 'O'),
#  ('that', 'O'),
#  ('he', 'O'),
#  ('spends', 'O'),
#  ('most', 'O'),
#  ('of', 'O'),
#  ('his', 'O'),
#  ('time', 'O'),
#  ('crying', 'O'),
#  ('over', 'O'),
#  ('how', 'O'),
#  ('beautiful', 'O'),
#  ('the', 'O'),
#  ('world', 'O'),
#  ('is,', 'O'),
#  ('and', 'O'),
#  ('constantly', 'O'),
#  ('asks', 'O'),
#  ('Alison,', 'O'),
#  ('his', 'O'),
#  ('girlfriend', 'O'),
#  ('of', 'O'),
#  ('"three', 'O'),
#  ('magical', 'O'),
#  ('weeks,"', 'O'),
#  ('whether', 'O'),
#  ('he', 'O'),
#  ('has', 'O'),
#  ('hurt', 'O'),
#  ('her', 'O'),
#  ('or', 'O'),
#  ('if', 'O'),
#  ('she', 'O'),
#  ('needs', 'O'),
#  ('anything.', 'O'),
#  ('Alison', 'PERSON'),
#  ('says', 'O'),
#  ('she', 'O'),
#  ('has', 'O'),
#  ('had', 'O'),
#  ('enough', 'O'),
#  ('of', 'O'),
#  ('it', 'O'),
#  ('and', 'O'),
#  ('wants', 'O'),
#  ('to', 'O'),
#  ('be', 'O'),
#  ('with', 'O'),
#  ('a', 'O'),
#  ('man', 'O'),
#  ('who', 'O'),
#  ('is', 'O'),
#  ('strong', 'O'),
#  ('and', 'O'),
#  ('shallow.', 'O'),
#  ('She', 'O'),
#  ('then', 'O'),
#  ('leaves', 'O'),
#  ('Elliot', 'PERSON'),
#  ('for', 'O'),
#  ('a', 'O'),
#  ('man', 'O'),
#  ('who', 'O'),
#  ('is', 'O'),
#  ('strong,', 'O'),
#  ('rude', 'O'),
#  ('and', 'O'),
#  ('completely', 'O'),
#  ('different', 'O'),
#  ('from', 'O'),
#  ('the', 'O'),
#  ('romantic', 'O'),
#  ('and', 'O'),
#  ('emotionally', 'O'),
#  ('sensitive', 'O'),
#  ('Elliot.', 'O'),
#  ('Elliot', 'PERSON'),
#  ('then', 'O'),
#  ('wishes', 'O'),
#  ('to', 'O'),
#  ('be', 'O'),
#  ('a', 'O'),
#  ('superstar', 'O'),
#  ('athlete', 'O'),
#  ('who', 'O'),
#  ('would', 'O'),
#  ('be', 'O'),
#  ('a', 'O'),
#  ('woman', 'O'),
#  ('magnet.', 'O'),
#  ('Satan', 'O'),
#  ('makes', 'O'),
#  ('him', 'O'),
#  ('a', 'O'),
#  ('clich̩-spewing', 'O'),
#  ('NBA', 'O'),
#  ('star,', 'O'),
#  ('but', 'O'),
#  ('also', 'O'),
#  ('gives', 'O'),
#  ('him', 'O'),
#  ('a', 'O'),
#  ('small', 'O'),
#  ('penis', 'O'),
#  ('and', 'O'),
#  ('a', 'O'),
#  ('low', 'O'),
#  ('IQ,', 'O'),
#  ('which', 'O'),
#  ('causes', 'O'),
#  ('Alison,', 'O'),
#  ('a', 'O'),
#  ('sports', 'O'),
#  ('reporter,', 'O'),
#  ('to', 'O'),
#  ('lose', 'O'),
#  ('interest', 'O'),
#  ('in', 'O'),
#  ('him', 'O'),
#  ('shortly', 'O'),
#  ('after', 'O'),
#  ('they', 'O'),
#  ('meet.', 'O'),
#  ('He', 'O'),
#  ('then', 'O'),
#  ('wishes', 'O'),
#  ('to', 'O'),
#  ('be', 'O'),
#  ('intelligent,', 'O'),
#  ('witty', 'O'),
#  ('and', 'O'),
#  ('well-endowed.', 'O'),
#  ('Satan', 'O'),
#  ('grants', 'O'),
#  ('this', 'O'),
#  ('by', 'O'),
#  ('making', 'O'),
#  ('him', 'O'),
#  ('a', 'O'),
#  ('famous', 'O'),
#  ('writer', 'O'),
#  ('whom', 'O'),
#  ('Alison', 'PERSON'),
#  ('falls', 'O'),
#  ('in', 'O'),
#  ('love', 'O'),
#  ('with', 'O'),
#  ('at', 'O'),
#  ('a', 'O'),
#  ('cocktail', 'O'),
#  ('party.', 'O'),
#  ('When', 'O'),
#  ('they', 'O'),
#  ('arrive', 'O'),
#  ('at', 'O'),
#  ("Elliot's", 'O'),
#  ('home', 'O'),
#  ('to', 'O'),
#  ('make', 'O'),
#  ('love', 'O'),
#  ('it', 'O'),
#  ('is', 'O'),
#  ('revealed', 'O'),
#  ('that', 'O'),
#  ('Elliot', 'PERSON'),
#  ('is', 'O'),
#  ('gay', 'O'),
#  ('and', 'O'),
#  ('living', 'O'),
#  ('with', 'O'),
#  ('a', 'O'),
#  ('flamboyant', 'O'),
#  ('male', 'O'),
#  ('partner.', 'O'),
#  ('Lastly,', 'O'),
#  ('Elliot', 'PERSON'),
#  ('wishes', 'O'),
#  ('to', 'O'),
#  ('be', 'O'),
#  ('President', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('United', 'LOCATION'),
#  ('States', 'LOCATION'),
#  ('to', 'O'),
#  ('try', 'O'),
#  ('to', 'O'),
#  ('improve', 'O'),
#  ('the', 'O'),
#  ('world', 'O'),
#  ('and', 'O'),
#  ('get', 'O'),
#  ('Alison', 'PERSON'),
#  ('to', 'O'),
#  ('take', 'O'),
#  ('him', 'O'),
#  ('seriously.', 'O'),
#  ('Satan', 'O'),
#  ('makes', 'O'),
#  ('him', 'O'),
#  ('Abraham', 'PERSON'),
#  ('Lincoln', 'PERSON'),
#  ('at', 'O'),
#  ("Ford's", 'O'),
#  ('Theatre', 'O'),
#  ('on', 'O'),
#  ('the', 'O'),
#  ('night', 'O'),
#  ('of', 'O'),
#  ('his', 'O'),
#  ('assassination', 'O'),
#  ('which', 'O'),
#  ('he', 'O'),
#  ('nearly', 'O'),
#  ('avoids.', 'O'),
#  ('After', 'O'),
#  ('each', 'O'),
#  ('wish', 'O'),
#  ('is', 'O'),
#  ('renounced,', 'O'),
#  ('Elliot', 'PERSON'),
#  ('meets', 'O'),
#  ('with', 'O'),
#  ('Satan', 'PERSON'),
#  ('and', 'O'),
#  ('she', 'O'),
#  ('blames', 'O'),
#  ('him', 'O'),
#  ('for', 'O'),
#  ('not', 'O'),
#  ('being', 'O'),
#  ('specific', 'O'),
#  ('enough.', 'O'),
#  ('Eventually', 'O'),
#  ('he', 'O'),
#  ('returns', 'O'),
#  ('to', 'O'),
#  ('work,', 'O'),
#  ('thinking', 'O'),
#  ('about', 'O'),
#  ('what', 'O'),
#  ('he', 'O'),
#  ('should', 'O'),
#  ('do', 'O'),
#  ('with', 'O'),
#  ('the', 'O'),
#  ('last', 'O'),
#  ('two', 'O'),
#  ('wishes.', 'O'),
#  ('Satan', 'O'),
#  ('appears', 'O'),
#  ('on', 'O'),
#  ('the', 'O'),
#  ('computer', 'O'),
#  ('screen,', 'O'),
#  ('pointing', 'O'),
#  ('out', 'O'),
#  ('that', 'O'),
#  ('on', 'O'),
#  ('their', 'O'),
#  ('first', 'O'),
#  ('meeting', 'O'),
#  ('he', 'O'),
#  ('asked', 'O'),
#  ('for', 'O'),
#  ('a', 'O'),
#  ('Big', 'O'),
#  ('Mac', 'O'),
#  ('and', 'O'),
#  ('Coke,', 'O'),
#  ('although', 'O'),
#  ('she', 'O'),
#  ('had', 'O'),
#  ('stated', 'O'),
#  ('that', 'O'),
#  ('it', 'O'),
#  ('was', 'O'),
#  ('a', 'O'),
#  ('test', 'O'),
#  ('wish', 'O'),
#  ('and', 'O'),
#  ('granted', 'O'),
#  ('it', 'O'),
#  ('before', 'O'),
#  ('Elliot', 'PERSON'),
#  ('signed', 'O'),
#  ('the', 'O'),
#  ('contract.', 'O'),
#  ('Elliot', 'PERSON'),
#  ('loses', 'O'),
#  ('his', 'O'),
#  ('patience', 'O'),
#  ('and', 'O'),
#  ('storms', 'O'),
#  ('out', 'O'),
#  ('of', 'O'),
#  ('his', 'O'),
#  ('office.', 'O'),
#  ('Elliot', 'PERSON'),
#  ('visits', 'O'),
#  ('a', 'O'),
#  ('church', 'O'),
#  ('looking', 'O'),
#  ('for', 'O'),
#  ("God's", 'O'),
#  ('help,', 'O'),
#  ('where', 'O'),
#  ('he', 'O'),
#  ('briefly', 'O'),
#  ('confesses', 'O'),
#  ('to', 'O'),
#  ('a', 'O'),
#  ('priest', 'O'),
#  ('who', 'O'),
#  ('seems', 'O'),
#  ('sympathetic.', 'O'),
#  ('However,', 'O'),
#  ('after', 'O'),
#  ('being', 'O'),
#  ('asked', 'O'),
#  ('whether', 'O'),
#  ('he', 'O'),
#  ('thinks', 'O'),
#  ('asking', 'O'),
#  ('Satan', 'O'),
#  ('for', 'O'),
#  ('a', 'O'),
#  ('Big', 'O'),
#  ('Mac', 'O'),
#  ('and', 'O'),
#  ('Coke', 'ORGANIZATION'),
#  ('counts', 'O'),
#  ('as', 'O'),
#  ('a', 'O'),
#  ('wish,', 'O'),
#  ('the', 'O'),
#  ('priest,', 'O'),
#  ('believing', 'O'),
#  ('he', 'O'),
#  ('is', 'O'),
#  ('drunk,', 'O'),
#  ('has', 'O'),
#  ('Elliot', 'PERSON'),
#  ('arrested.', 'O'),
#  ('The', 'O'),
#  ('sergeant', 'O'),
#  ('books', 'O'),
#  ('him,', 'O'),
#  ('and', 'O'),
#  ('Satan,', 'O'),
#  ('dressed', 'O'),
#  ('as', 'O'),
#  ('a', 'O'),
#  ('police', 'O'),
#  ('officer,', 'O'),
#  ('throws', 'O'),
#  ('him', 'O'),
#  ('in', 'O'),
#  ('a', 'O'),
#  ('cell,', 'O'),
#  ('telling', 'O'),
#  ('him', 'O'),
#  ('that', 'O'),
#  ('she', 'O'),
#  ('does', 'O'),
#  ('like', 'O'),
#  ('him,', 'O'),
#  ('and', 'O'),
#  ('it', 'O'),
#  ('would', 'O'),
#  ('not', 'O'),
#  ('hurt', 'O'),
#  ('to', 'O'),
#  ('have', 'O'),
#  ('her', 'O'),
#  ('as', 'O'),
#  ('a', 'O'),
#  ('friend.', 'O'),
#  ("Elliot's", 'O'),
#  ('cellmate', 'O'),
#  ('tells', 'O'),
#  ('him', 'O'),
#  ('that', 'O'),
#  ('he', 'O'),
#  ('cannot', 'O'),
#  ('possibly', 'O'),
#  ('sell', 'O'),
#  ('his', 'O'),
#  ('soul', 'O'),
#  ('as', 'O'),
#  ('it', 'O'),
#  ('belongs', 'O'),
#  ('to', 'O'),
#  ('God,', 'O'),
#  ('and', 'O'),
#  ('although', 'O'),
#  ('Satan', 'O'),
#  ('may', 'O'),
#  ('try', 'O'),
#  ('to', 'O'),
#  ('confuse', 'O'),
#  ('him,', 'O'),
#  ('in', 'O'),
#  ('the', 'O'),
#  ('end', 'O'),
#  ('he', 'O'),
#  ('will', 'O'),
#  ('realise', 'O'),
#  ('who', 'O'),
#  ('he', 'O'),
#  ('truly', 'O'),
#  ('is,', 'O'),
#  ('and', 'O'),
#  ('what', 'O'),
#  ('his', 'O'),
#  ('purpose', 'O'),
#  ('is.', 'O'),
#  ('Elliot', 'PERSON'),
#  ('questions', 'O'),
#  ('the', 'O'),
#  ('man', 'O'),
#  ('as', 'O'),
#  ('to', 'O'),
#  ('his', 'O'),
#  ('identity,', 'O'),
#  ('but', 'O'),
#  ('the', 'O'),
#  ('response', 'O'),
#  ('is', 'O'),
#  ('simply', 'O'),
#  ('"a', 'O'),
#  ('really', 'O'),
#  ('good', 'O'),
#  ('friend".', 'O'),
#  ('Elliot', 'PERSON'),
#  ('asks', 'O'),
#  ('Satan', 'O'),
#  ('to', 'O'),
#  ('cancel', 'O'),
#  ('their', 'O'),
#  ('contract.', 'O'),
#  ('When', 'O'),
#  ('Satan', 'O'),
#  ('refuses,', 'O'),
#  ('Elliot', 'PERSON'),
#  ('states', 'O'),
#  ('he', 'O'),
#  ('will', 'O'),
#  ('not', 'O'),
#  ('use', 'O'),
#  ('his', 'O'),
#  ('final', 'O'),
#  ('wish.', 'O'),
#  ('Satan', 'O'),
#  ('teleports', 'O'),
#  ('them', 'O'),
#  ('to', 'O'),
#  ('Hell,', 'O'),
#  ('where', 'O'),
#  ('she', 'O'),
#  ('transforms', 'O'),
#  ('first', 'O'),
#  ('into', 'O'),
#  ('a', 'O'),
#  ('black', 'O'),
#  ('horned', 'O'),
#  ('monster,', 'O'),
#  ('then', 'O'),
#  ('into', 'O'),
#  ('a', 'O'),
#  ('giant.', 'O'),
#  ('When', 'O'),
#  ('Satan', 'PERSON'),
#  ('pushes', 'O'),
#  ('him', 'O'),
#  ('to', 'O'),
#  ('make', 'O'),
#  ('a', 'O'),
#  ('final', 'O'),
#  ('wish,', 'O'),
#  ('Elliot', 'PERSON'),
#  ('wishes', 'O'),
#  ('that', 'O'),
#  ('Alison', 'PERSON'),
#  ('could', 'O'),
#  ('have', 'O'),
#  ('a', 'O'),
#  ('happy', 'O'),
#  ('life', 'O'),
#  ('-', 'O'),
#  ('with', 'O'),
#  ('or', 'O'),
#  ('without', 'O'),
#  ('him.', 'O'),
#  ('Satan', 'O'),
#  ('sighs', 'O'),
#  ('and', 'O'),
#  ('Elliot', 'PERSON'),
#  ('falls', 'O'),
#  ('into', 'O'),
#  ('the', 'O'),
#  ('depths', 'O'),
#  ('of', 'O'),
#  ('Hell.', 'O'),
#  ('Elliot', 'PERSON'),
#  ('wakes', 'O'),
#  ('up', 'O'),
#  ('on', 'O'),
#  ('a', 'O'),
#  ('marble', 'O'),
#  ('staircase,', 'O'),
#  ('wondering', 'O'),
#  ('if', 'O'),
#  ('it', 'O'),
#  ('is', 'O'),
#  ('Heaven.', 'O'),
#  ('Satan', 'PERSON'),
#  ('tells', 'O'),
#  ('him', 'O'),
#  ('that', 'O'),
#  ('it', 'O'),
#  ('is', 'O'),
#  ('a', 'O'),
#  ('courthouse', 'O'),
#  ('and', 'O'),
#  ('that', 'O'),
#  ('a', 'O'),
#  ('selfless', 'O'),
#  ('wish', 'O'),
#  ('voids', 'O'),
#  ('the', 'O'),
#  ('contract,', 'O'),
#  ('so', 'O'),
#  ('he', 'O'),
#  ('keeps', 'O'),
#  ('his', 'O'),
#  ('soul.', 'O'),
#  ('Elliot', 'PERSON'),
#  ('admits', 'O'),
#  ('that', 'O'),
#  ('despite', 'O'),
#  ('her', 'O'),
#  ('manipulation', 'O'),
#  ('of', 'O'),
#  ('him', 'O'),
#  ('he', 'O'),
#  ('has', 'O'),
#  ('come', 'O'),
#  ('to', 'O'),
#  ('like', 'O'),
#  ('Satan', 'PERSON'),
#  ('and', 'O'),
#  ('regards', 'O'),
#  ('her', 'O'),
#  ('as', 'O'),
#  ('a', 'O'),
#  ('friend,', 'O'),
#  ('something', 'O'),
#  ('she', 'O'),
#  ('does', 'O'),
#  ('not', 'O'),
#  ('object', 'O'),
#  ('to.', 'O'),
#  ('She', 'O'),
#  ('replies', 'O'),
#  ('that', 'O'),
#  ('Heaven', 'O'),
#  ('and', 'O'),
#  ('Hell', 'O'),
#  ('can', 'O'),
#  ('be', 'O'),
#  ('found', 'O'),
#  ('on', 'O'),
#  ('Earth;', 'O'),
#  ('it', 'O'),
#  ('is', 'O'),
#  ('up', 'O'),
#  ('to', 'O'),
#  ('humans', 'O'),
#  ('to', 'O'),
#  ('choose.', 'O'),
#  ('Elliot', 'PERSON'),
#  ('asks', 'O'),
#  ('Alison', 'PERSON'),
#  ('out,', 'O'),
#  ('only', 'O'),
#  ('to', 'O'),
#  ('learn', 'O'),
#  ('that', 'O'),
#  ('she', 'O'),
#  ('is', 'O'),
#  ('already', 'O'),
#  ('dating', 'O'),
#  ('somebody.', 'O'),
#  ('He', 'O'),
#  ('continues', 'O'),
#  ('with', 'O'),
#  ('his', 'O'),
#  ('life,', 'O'),
#  ('but', 'O'),
#  ('with', 'O'),
#  ('a', 'O'),
#  ('better', 'O'),
#  ('understanding', 'O'),
#  ('of', 'O'),
#  ('who', 'O'),
#  ('he', 'O'),
#  ('is.', 'O'),
#  ('Later', 'O'),
#  ('Elliot', 'PERSON'),
#  ('is', 'O'),
#  ('confronted', 'O'),
#  ('by', 'O'),
#  ('Bob,', 'O'),
#  ('one', 'O'),
#  ('of', 'O'),
#  ('his', 'O'),
#  ('co-workers,', 'O'),
#  ('who', 'O'),
#  ('starts', 'O'),
#  ('ridiculing', 'O'),
#  ('Elliot', 'PERSON'),
#  ('at', 'O'),
#  ('the', 'O'),
#  ('encouragement', 'O'),
#  ('of', 'O'),
#  ('his', 'O'),
#  ('co-workers.', 'O'),
#  ('Elliot', 'PERSON'),
#  ('loses', 'O'),
#  ('his', 'O'),
#  ('temper', 'O'),
#  ('and', 'O'),
#  ('grabs', 'O'),
#  ('a', 'O'),
#  ('terrified', 'O'),
#  ('Bob', 'PERSON'),
#  ('by', 'O'),
#  ('the', 'O'),
#  ('shirt,', 'O'),
#  ('but', 'O'),
#  ('lets', 'O'),
#  ('go,', 'O'),
#  ('simply', 'O'),
#  ('saying,', 'O'),
#  ('"Nice', 'O'),
#  ('talking', 'O'),
#  ('to', 'O'),
#  ('you."', 'O'),
#  ('A', 'O'),
#  ('threatening', 'O'),
#  ('look', 'O'),
#  ('sends', 'O'),
#  ('his', 'O'),
#  ('other', 'O'),
#  ('co-workers', 'O'),
#  ('scurrying', 'O'),
#  ('away', 'O'),
#  ('in', 'O'),
#  ('fear.', 'O'),
#  ('At', 'O'),
#  ('home,', 'O'),
#  ('he', 'O'),
#  ('meets', 'O'),
#  ('a', 'O'),
#  ('new', 'O'),
#  ('neighbor,', 'O'),
#  ('Nicole', 'PERSON'),
#  ('Delarusso', 'PERSON'),
#  (',', 'O'),
#  ('whose', 'O'),
#  ('looks', 'O'),
#  ('resemble', 'O'),
#  ("Alison's", 'O'),
#  ('and', 'O'),
#  ('has', 'O'),
#  ('personality,', 'O'),
#  ('interests', 'O'),
#  ('and', 'O'),
#  ('dressing', 'O'),
#  ('styles', 'O'),
#  ('similar', 'O'),
#  ('to', 'O'),
#  ('his.', 'O'),
#  ('He', 'O'),
#  ('offers', 'O'),
#  ('to', 'O'),
#  ('help', 'O'),
#  ('her', 'O'),
#  ('unpack', 'O'),
#  ('and', 'O'),
#  ('they', 'O'),
#  ('presumably', 'O'),
#  ('begin', 'O'),
#  ('a', 'O'),
#  ('relationship.', 'O'),
#  ('While', 'O'),
#  ('the', 'O'),
#  ('two', 'O'),
#  ('walk', 'O'),
#  ('along', 'O'),
#  ...]

# %% [markdown]
# ###checking the NER results
# As seen below in the sample, NER does a poor job tagging named entities in the roles. This is because the roles are short phrases, not full sentences, and NER is not designed to tag short phrases.
#
# In addition, we did find a tool that would conveniently make the nltk.ne_chuck text usable with nltk.chuck. We decided to use the Stanford NER tagger, which works well with nltk.chuck.
#
# With this finding in mind, we went on to develop other extraction methods.

# %%
# for i in range(len(sample[1][1]['roles'][2]['role_pos'][0])):
#     sample[1][1]['roles'][2]['role_pos'][0][i] = list(sample[1][1]['roles'][2]['role_pos'][0][i])
#     sample[1][1]['roles'][2]['role_pos'][0][i][0] = sample[1][1]['roles'][2]['role_pos'][0][i][0].lower()
#     print(sample[1][1]['roles'][2]['role_pos'][0][i][0])

# %%
sample
# Out:
# [['city after dark.1980',
#   {'id': 19412,
#    'language': None,
#    'num_ratings': '94',
#    'ratings': '7.5',
#    'roles': [{'gender': 'F',
#      'role': 'Vanessa',
#      'role_pos': [[('vanessa', 'NN')]]},
#     {'gender': 'F', 'role': 'Nelie', 'role_pos': [[('nelie', 'NN')]]},
#     {'gender': 'F', 'role': 'Kano', 'role_pos': [[('kano', 'NN')]]},
#     {'gender': 'F', 'role': 'Cora', 'role_pos': [[('cora', 'NN')]]},
#     {'gender': 'F', 'role': 'Bea', 'role_pos': [[('bea', 'NN')]]},
#     {'gender': 'F', 'role': 'Gaying', 'role_pos': [[('gaying', 'VBG')]]},
#     {'gender': 'F', 'role': 'Adelina', 'role_pos': [[('adelina', 'NN')]]},
#     {'gender': 'F',
#      'role': "Vanessa's Mother",
#      'role_pos': [[('vanessa', 'NN'), ("'s", 'POS'), ('mother', 'NN')]]},
#     {'gender': 'F', 'role': 'Virgie', 'role_pos': [[('virgie', 'NN')]]},
#     {'gender': 'F', 'role': 'Baby', 'role_pos': [[('baby', 'NN')]]},
#     {'gender': 'F', 'role': 'Marichu', 'role_pos': [[('marichu', 'NN')]]},
#     {'gender': 'M',
#      'role': "Adelina's Client",
#      'role_pos': [[('adelina', 'NN'), ("'s", 'POS'), ('client', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Manay Sharon',
#      'role_pos': [[('manay', 'NN'), ('sharon', 'VBD')]]},
#     {'gender': 'M', 'role': 'Recruiter', 'role_pos': [[('recruiter', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Mall couple',
#      'role_pos': [[('mall', 'NN'), ('couple', 'NN')]]},
#     {'gender': 'M', 'role': 'Alex', 'role_pos': [[('alex', 'NN')]]},
#     {'gender': 'M', 'role': 'Pebrero', 'role_pos': [[('pebrero', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Greggy Williams',
#      'role_pos': [[('greggy', 'NN'), ('williams', 'NNS')]]},
#     {'gender': 'M',
#      'role': "Virgir's Husband",
#      'role_ne': [Tree('S', [Tree('GPE', [['Virgir', 'PRP$']]), ["'s", 'POS'], Tree('ORGANIZATION', [['Husband', 'NN']])])],
#      'role_pos': [[['Virgir', 'PRP$'], ["'s", 'POS'], ['Husband', 'NN']]]}],
#    'summaries_imdb': ["The hidden nightlife of ordinary people living in Manila unveils. Lovers and families' conflicts are radically pitted against each other as they live in the night streets rampant with drugs and prostitution. The outstanding narrative explicitly unravels the various characters and episodes. This landmark film of Ishmael Bernal depicts the darkness of city life so vividly that it was once prohibited to use the word 'Manila' on its title."],
#    'summaries_imdb_ner': [('The', 'O'),
#     ('hidden', 'O'),
#     ('nightlife', 'O'),
#     ('of', 'O'),
#     ('ordinary', 'O'),
#     ('people', 'O'),
#     ('living', 'O'),
#     ('in', 'O'),
#     ('Manila', 'LOCATION'),
#     ('unveils.', 'O'),
#     ('Lovers', 'O'),
#     ('and', 'O'),
#     ("families'", 'O'),
#     ('conflicts', 'O'),
#     ('are', 'O'),
#     ('radically', 'O'),
#     ('pitted', 'O'),
#     ('against', 'O'),
#     ('each', 'O'),
#     ('other', 'O'),
#     ('as', 'O'),
#     ('they', 'O'),
#     ('live', 'O'),
#     ('in', 'O'),
#     ('the', 'O'),
#     ('night', 'O'),
#     ('streets', 'O'),
#     ('rampant', 'O'),
#     ('with', 'O'),
#     ('drugs', 'O'),
#     ('and', 'O'),
#     ('prostitution.', 'O'),
#     ('The', 'O'),
#     ('outstanding', 'O'),
#     ('narrative', 'O'),
#     ('explicitly', 'O'),
#     ('unravels', 'O'),
#     ('the', 'O'),
#     ('various', 'O'),
#     ('characters', 'O'),
#     ('and', 'O'),
#     ('episodes.', 'O'),
#     ('This', 'O'),
#     ('landmark', 'O'),
#     ('film', 'O'),
#     ('of', 'O'),
#     ('Ishmael', 'PERSON'),
#     ('Bernal', 'PERSON'),
#     ('depicts', 'O'),
#     ('the', 'O'),
#     ('darkness', 'O'),
#     ('of', 'O'),
#     ('city', 'O'),
#     ('life', 'O'),
#     ('so', 'O'),
#     ('vividly', 'O'),
#     ('that', 'O'),
#     ('it', 'O'),
#     ('was', 'O'),
#     ('once', 'O'),
#     ('prohibited', 'O'),
#     ('to', 'O'),
#     ('use', 'O'),
#     ('the', 'O'),
#     ('word', 'O'),
#     ("'Manila'", 'O'),
#     ('on', 'O'),
#     ('its', 'O'),
#     ('title.', 'O')],
#    'summaries_imdb_pos': [[('The', 'DT'),
#      ('hidden', 'VBN'),
#      ('nightlife', 'NN'),
#      ('of', 'IN'),
#      ('ordinary', 'JJ'),
#      ('people', 'NNS'),
#      ('living', 'VBG'),
#      ('in', 'IN'),
#      ('Manila', 'NNP'),
#      ('unveils', 'NNS'),
#      ('.', '.')],
#     [('Lovers', 'NNS'),
#      ('and', 'CC'),
#      ('families', 'NNS'),
#      ("'", 'POS'),
#      ('conflicts', 'NNS'),
#      ('are', 'VBP'),
#      ('radically', 'RB'),
#      ('pitted', 'VBN'),
#      ('against', 'IN'),
#      ('each', 'DT'),
#      ('other', 'JJ'),
#      ('as', 'IN'),
#      ('they', 'PRP'),
#      ('live', 'VBP'),
#      ('in', 'IN'),
#      ('the', 'DT'),
#      ('night', 'NN'),
#      ('streets', 'NNS'),
#      ('rampant', 'VBP'),
#      ('with', 'IN'),
#      ('drugs', 'NNS'),
#      ('and', 'CC'),
#      ('prostitution', 'NN'),
#      ('.', '.')],
#     [('The', 'DT'),
#      ('outstanding', 'JJ'),
#      ('narrative', 'JJ'),
#      ('explicitly', 'RB'),
#      ('unravels', 'VBZ'),
#      ('the', 'DT'),
#      ('various', 'JJ'),
#      ('characters', 'NNS'),
#      ('and', 'CC'),
#      ('episodes', 'NNS'),
#      ('.', '.')],
#     [('This', 'DT'),
#      ('landmark', 'NN'),
#      ('film', 'NN'),
#      ('of', 'IN'),
#      ('Ishmael', 'NNP'),
#      ('Bernal', 'NNP'),
#      ('depicts', 'VBZ'),
#      ('the', 'DT'),
#      ('darkness', 'NN'),
#      ('of', 'IN'),
#      ('city', 'NN'),
#      ('life', 'NN'),
#      ('so', 'RB'),
#      ('vividly', 'RB'),
#      ('that', 'IN'),
#      ('it', 'PRP'),
#      ('was', 'VBD'),
#      ('once', 'RB'),
#      ('prohibited', 'VBN'),
#      ('to', 'TO'),
#      ('use', 'VB'),
#      ('the', 'DT'),
#      ('word', 'NN'),
#      ("'Manila", 'NN'),
#      ("'", "''"),
#      ('on', 'IN'),
#      ('its', 'PRP$'),
#      ('title', 'NN'),
#      ('.', '.')]],
#    'summaries_wikipedia': [],
#    'title': 'City After Dark',
#    'venue': 'T',
#    'version': 'I',
#    'year': '1980'}],
#  ['angelica.2015',
#   {'id': 7054,
#    'language': None,
#    'num_ratings': '60',
#    'ratings': '5.8',
#    'roles': [{'gender': 'F',
#      'role': 'Midwife',
#      'role_pos': [[('midwife', 'NN')]]},
#     {'gender': 'F', 'role': 'Angelica', 'role_pos': [[('angelica', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Snobby Woman',
#      'role_pos': [[('snobby', 'NN'), ('woman', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Lady in Park',
#      'role_pos': [[('lady', 'NN'), ('in', 'IN'), ('park', 'NN')]]},
#     {'gender': 'F', 'role': 'Nora', 'role_pos': [[('nora', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Beggar girl',
#      'role_pos': [[('beggar', 'NN'), ('girl', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Young Angelica',
#      'role_pos': [[('young', 'JJ'), ('angelica', 'NN')]]},
#     {'gender': 'F', 'role': 'Constance', 'role_pos': [[('constance', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Anne Montague',
#      'role_pos': [[('anne', 'NN'), ('montague', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Older Constance',
#      'role_pos': [[('older', 'JJR'), ('constance', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Spirit Girl',
#      'role_pos': [[('spirit', 'NN'), ('girl', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Unnamed Scientist',
#      'role_pos': [[('unnamed', 'VBD'), ('scientist', 'VBN')]]},
#     {'gender': 'M',
#      'role': 'Unnamed Scientist',
#      'role_pos': [[('unnamed', 'VBD'), ('scientist', 'VBN')]]},
#     {'gender': 'M',
#      'role': 'Medical Student',
#      'role_pos': [[('medical', 'JJ'), ('student', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Mr. Pendleton',
#      'role_pos': [[('mr.', 'NNP'), ('pendleton', 'VBD')]]},
#     {'gender': 'M',
#      'role': 'Spirit Boy',
#      'role_pos': [[('spirit', 'NN'), ('boy', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Unnamed Scientist',
#      'role_pos': [[('unnamed', 'VBD'), ('scientist', 'VBN')]]},
#     {'gender': 'M',
#      'role': 'Bookseller',
#      'role_pos': [[('bookseller', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Dr. Joseph Barton',
#      'role_ne': [Tree('S', [['Dr.', 'NNP'], ['Joseph', 'VBP'], Tree('PERSON', [['Barton', 'NN']])])],
#      'role_pos': [[['Dr.', 'NNP'], ['Joseph', 'VBP'], ['Barton', 'NN']]]}],
#    'summaries_imdb': ['In Victorian England, sexual repression opens a rift between young couple Constance and Joseph after the birth of their daughter Angelica. As Constance becomes more and more protective of little Angelica, a ghostly predator begins to make its way through the house late at night... ANGELICA is a spellbinding ghost story about desire, repression and its consequences... The new film by Mitchell Lichtenstein, director of HAPPY TEARS and the cult favorite TEETH.'],
#    'summaries_imdb_ner': [('In', 'O'),
#     ('Victorian', 'O'),
#     ('England,', 'O'),
#     ('sexual', 'O'),
#     ('repression', 'O'),
#     ('opens', 'O'),
#     ('a', 'O'),
#     ('rift', 'O'),
#     ('between', 'O'),
#     ('young', 'O'),
#     ('couple', 'O'),
#     ('Constance', 'PERSON'),
#     ('and', 'O'),
#     ('Joseph', 'PERSON'),
#     ('after', 'O'),
#     ('the', 'O'),
#     ('birth', 'O'),
#     ('of', 'O'),
#     ('their', 'O'),
#     ('daughter', 'O'),
#     ('Angelica.', 'O'),
#     ('As', 'O'),
#     ('Constance', 'PERSON'),
#     ('becomes', 'O'),
#     ('more', 'O'),
#     ('and', 'O'),
#     ('more', 'O'),
#     ('protective', 'O'),
#     ('of', 'O'),
#     ('little', 'O'),
#     ('Angelica,', 'O'),
#     ('a', 'O'),
#     ('ghostly', 'O'),
#     ('predator', 'O'),
#     ('begins', 'O'),
#     ('to', 'O'),
#     ('make', 'O'),
#     ('its', 'O'),
#     ('way', 'O'),
#     ('through', 'O'),
#     ('the', 'O'),
#     ('house', 'O'),
#     ('late', 'O'),
#     ('at', 'O'),
#     ('night...', 'O'),
#     ('ANGELICA', 'O'),
#     ('is', 'O'),
#     ('a', 'O'),
#     ('spellbinding', 'O'),
#     ('ghost', 'O'),
#     ('story', 'O'),
#     ('about', 'O'),
#     ('desire,', 'O'),
#     ('repression', 'O'),
#     ('and', 'O'),
#     ('its', 'O'),
#     ('consequences...', 'O'),
#     ('The', 'O'),
#     ('new', 'O'),
#     ('film', 'O'),
#     ('by', 'O'),
#     ('Mitchell', 'PERSON'),
#     ('Lichtenstein,', 'O'),
#     ('director', 'O'),
#     ('of', 'O'),
#     ('HAPPY', 'O'),
#     ('TEARS', 'O'),
#     ('and', 'O'),
#     ('the', 'O'),
#     ('cult', 'O'),
#     ('favorite', 'O'),
#     ('TEETH.', 'O')],
#    'summaries_imdb_pos': [[('In', 'IN'),
#      ('Victorian', 'NNP'),
#      ('England', 'NNP'),
#      (',', ','),
#      ('sexual', 'JJ'),
#      ('repression', 'NN'),
#      ('opens', 'NNS'),
#      ('a', 'DT'),
#      ('rift', 'NN'),
#      ('between', 'IN'),
#      ('young', 'JJ'),
#      ('couple', 'NN'),
#      ('Constance', 'NNP'),
#      ('and', 'CC'),
#      ('Joseph', 'NNP'),
#      ('after', 'IN'),
#      ('the', 'DT'),
#      ('birth', 'NN'),
#      ('of', 'IN'),
#      ('their', 'PRP$'),
#      ('daughter', 'NN'),
#      ('Angelica', 'NNP'),
#      ('.', '.')],
#     [('As', 'IN'),
#      ('Constance', 'NNP'),
#      ('becomes', 'VBZ'),
#      ('more', 'JJR'),
#      ('and', 'CC'),
#      ('more', 'JJR'),
#      ('protective', 'JJ'),
#      ('of', 'IN'),
#      ('little', 'JJ'),
#      ('Angelica', 'NNP'),
#      (',', ','),
#      ('a', 'DT'),
#      ('ghostly', 'RB'),
#      ('predator', 'NN'),
#      ('begins', 'VBZ'),
#      ('to', 'TO'),
#      ('make', 'VB'),
#      ('its', 'PRP$'),
#      ('way', 'NN'),
#      ('through', 'IN'),
#      ('the', 'DT'),
#      ('house', 'NN'),
#      ('late', 'RB'),
#      ('at', 'IN'),
#      ('night', 'NN'),
#      ('...', ':'),
#      ('ANGELICA', 'NNP'),
#      ('is', 'VBZ'),
#      ('a', 'DT'),
#      ('spellbinding', 'NN'),
#      ('ghost', 'NN'),
#      ('story', 'NN'),
#      ('about', 'IN'),
#      ('desire', 'NN'),
#      (',', ','),
#      ('repression', 'NN'),
#      ('and', 'CC'),
#      ('its', 'PRP$'),
#      ('consequences', 'NNS'),
#      ('...', ':')],
#     [('The', 'DT'),
#      ('new', 'JJ'),
#      ('film', 'NN'),
#      ('by', 'IN'),
#      ('Mitchell', 'NNP'),
#      ('Lichtenstein', 'NNP'),
#      (',', ','),
#      ('director', 'NN'),
#      ('of', 'IN'),
#      ('HAPPY', 'NNP'),
#      ('TEARS', 'NNP'),
#      ('and', 'CC'),
#      ('the', 'DT'),
#      ('cult', 'NN'),
#      ('favorite', 'JJ'),
#      ('TEETH', 'NNP'),
#      ('.', '.')]],
#    'summaries_wikipedia': [],
#    'title': 'Angelica',
#    'venue': 'T',
#    'version': 'I',
#    'year': '2015'}],
#  ['bedazzled.2000',
#   {'id': 11106,
#    'language': None,
#    'num_ratings': '78401',
#    'ratings': '5.9',
#    'roles': [{'gender': 'F',
#      'role': 'DV8 Clubgoer',
#      'role_pos': [[('dv8', 'NNP'), ('clubgoer', 'NN')]]},
#     {'gender': 'F',
#      'role': 'DV8 Clubgoer',
#      'role_pos': [[('dv8', 'NNP'), ('clubgoer', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Cheerleader/Dancer',
#      'role_pos': [[('cheerleader/dancer', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Cheerleader/Dancer',
#      'role_pos': [[('cheerleader/dancer', 'NN')]]},
#     {'gender': 'F',
#      'role': 'DV8 Waitress',
#      'role_pos': [[('dv8', 'NNP'), ('waitress', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Cheerleader/Dancer',
#      'role_pos': [[('cheerleader/dancer', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Churchgoer',
#      'role_pos': [[('churchgoer', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Cheerleader/Dancer',
#      'role_pos': [[('cheerleader/dancer', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Caged Go-Go Dancer',
#      'role_pos': [[('caged', 'VBD'), ('go-go', 'JJ'), ('dancer', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Tech Support Advisor',
#      'role_pos': [[('tech', 'NN'), ('support', 'NN'), ('advisor', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Play Actor',
#      'role_pos': [[('play', 'NN'), ('actor', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Cheerleader/Dancer',
#      'role_pos': [[('cheerleader/dancer', 'NN')]]},
#     {'gender': 'F',
#      'role': 'The Devil',
#      'role_pos': [[('the', 'DT'), ('devil', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Fly Girl',
#      'role_pos': [[('fly', 'RB'), ('girl', 'VBP')]]},
#     {'gender': 'F',
#      'role': 'DV8 Clubgoer',
#      'role_pos': [[('dv8', 'NNP'), ('clubgoer', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Cheerleader/Dancer',
#      'role_pos': [[('cheerleader/dancer', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Alison/Nicole',
#      'role_pos': [[('alison/nicole', 'JJ')]]},
#     {'gender': 'F',
#      'role': 'DV8 Clubgoer',
#      'role_pos': [[('dv8', 'NNP'), ('clubgoer', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Fly Girl',
#      'role_pos': [[('fly', 'RB'), ('girl', 'VBP')]]},
#     {'gender': 'F',
#      'role': 'Cheerleader/Dancer',
#      'role_pos': [[('cheerleader/dancer', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Cheerleader/Dancer',
#      'role_pos': [[('cheerleader/dancer', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Carol/Penthouse Hostess',
#      'role_pos': [[('carol/penthouse', 'NN'), ('hostess', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Girl at Beer Garden',
#      'role_pos': [[('girl', 'NN'),
#        ('at', 'IN'),
#        ('beer', 'NN'),
#        ('garden', 'NNS')]]},
#     {'gender': 'F',
#      'role': 'Girl at Beer Garden',
#      'role_pos': [[('girl', 'NN'),
#        ('at', 'IN'),
#        ('beer', 'NN'),
#        ('garden', 'NNS')]]},
#     {'gender': 'F',
#      'role': 'Fly Girl',
#      'role_pos': [[('fly', 'RB'), ('girl', 'VBP')]]},
#     {'gender': 'F',
#      'role': 'Restaurant Customer',
#      'role_pos': [[('restaurant', 'NN'), ('customer', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Cheerleader/Dancer',
#      'role_pos': [[('cheerleader/dancer', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Tech Support Advisor',
#      'role_pos': [[('tech', 'NN'), ('support', 'NN'), ('advisor', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Tech Support Advisor',
#      'role_pos': [[('tech', 'NN'), ('support', 'NN'), ('advisor', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Demonic Waitress',
#      'role_pos': [[('demonic', 'JJ'), ('waitress', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Cheerleader/Dancer',
#      'role_pos': [[('cheerleader/dancer', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Bob/Roberto/Beach Jock/Sportscaster/Lincoln Aide',
#      'role_pos': [[('bob/roberto/beach', 'JJ'),
#        ('jock/sportscaster/lincoln', 'JJ'),
#        ('aide', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Tech Support Advisor',
#      'role_pos': [[('tech', 'NN'), ('support', 'NN'), ('advisor', 'NN')]]},
#     {'gender': 'M',
#      'role': "McDonald's Employee",
#      'role_pos': [[('mcdonald', 'NN'), ("'s", 'POS'), ('employee', 'NN')]]},
#     {'gender': 'M',
#      'role': 'DV8 Clubgoer',
#      'role_pos': [[('dv8', 'NNP'), ('clubgoer', 'NN')]]},
#     {'gender': 'M', 'role': 'Prisoner', 'role_pos': [[('prisoner', 'NN')]]},
#     {'gender': 'M',
#      'role': "Elliot's Cellmate",
#      'role_pos': [[('elliot', 'NN'), ("'s", 'POS'), ('cellmate', 'NN')]]},
#     {'gender': 'M',
#      'role': 'San Francisco Pedestrian',
#      'role_pos': [[('san', 'NN'),
#        ('francisco', 'VBD'),
#        ('pedestrian', 'JJ')]]},
#     {'gender': 'M',
#      'role': 'Tech Support Advisor',
#      'role_pos': [[('tech', 'NN'), ('support', 'NN'), ('advisor', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Cornell, Peter (II)',
#      'role_pos': [[('cornell', 'NN'),
#        (',', ','),
#        ('peter', 'NN'),
#        ('(', ':'),
#        ('ii', 'NN'),
#        (')', ':')]]},
#     {'gender': 'M',
#      'role': 'Businessman #1',
#      'role_pos': [[('businessman', 'NN'), ('#', '#'), ('1', 'CD')]]},
#     {'gender': 'M',
#      'role': 'Desk Sergeant',
#      'role_pos': [[('desk', 'NN'), ('sergeant', 'VBD')]]},
#     {'gender': 'M', 'role': 'Priest', 'role_pos': [[('priest', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Ivan the Russian',
#      'role_pos': [[('ivan', 'NN'), ('the', 'DT'), ('russian', 'JJ')]]},
#     {'gender': 'M',
#      'role': 'John Wilkes Booth',
#      'role_pos': [[('john', 'NN'), ('wilkes', 'VBZ'), ('booth', 'NN')]]},
#     {'gender': 'M', 'role': 'Elliot', 'role_pos': [[('elliot', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Man in Park',
#      'role_pos': [[('man', 'NN'), ('in', 'IN'), ('park', 'NN')]]},
#     {'gender': 'M', 'role': 'Mover', 'role_pos': [[('mover', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Play Actor',
#      'role_pos': [[('play', 'NN'), ('actor', 'NN')]]},
#     {'gender': 'M', 'role': 'Pablito', 'role_pos': [[('pablito', 'IN')]]},
#     {'gender': 'M',
#      'role': 'Diablos Fan #4',
#      'role_pos': [[('diablos', 'NNS'),
#        ('fan', 'VBP'),
#        ('#', '#'),
#        ('4', 'CD')]]},
#     {'gender': 'M',
#      'role': 'DV8 Clubgoer',
#      'role_pos': [[('dv8', 'NNP'), ('clubgoer', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Diablos Fan #3',
#      'role_pos': [[('diablos', 'NNS'),
#        ('fan', 'VBP'),
#        ('#', '#'),
#        ('3', 'CD')]]},
#     {'gender': 'M',
#      'role': 'Jerry/Alejandro/Beach Jock/Sportscaster/Lance',
#      'role_pos': [[('jerry/alejandro/beach', 'JJ'),
#        ('jock/sportscaster/lance', 'NN')]]},
#     {'gender': 'M',
#      'role': 'NBA Player #10',
#      'role_pos': [[('nba', 'NN'),
#        ('player', 'NN'),
#        ('#', '#'),
#        ('10', 'CD')]]},
#     {'gender': 'M',
#      'role': 'Dan/Esteban/Beach Jock/Sportscaster/African Party Guest',
#      'role_pos': [[('dan/esteban/beach', 'JJ'),
#        ('jock/sportscaster/african', 'JJ'),
#        ('party', 'NN'),
#        ('guest', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Club DV8 Patron',
#      'role_pos': [[('club', 'NN'), ('dv8', 'NNP'), ('patron', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Synedyne Supervisor',
#      'role_pos': [[('synedyne', 'NN'), ('supervisor', 'NN')]]},
#     {'gender': 'M', 'role': 'Eduardo', 'role_pos': [[('eduardo', 'NN')]]},
#     {'gender': 'M', 'role': 'Raoul', 'role_pos': [[('raoul', 'NN')]]},
#     {'gender': 'M',
#      'role': 'DV8 Bouncer',
#      'role_pos': [[('dv8', 'NNP'), ('bouncer', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Russian Drug Dealer',
#      'role_pos': [[('russian', 'JJ'), ('drug', 'NN'), ('dealer', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Club DV8 Dancer',
#      'role_pos': [[('club', 'NN'), ('dv8', 'NNP'), ('dancer', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Raging Fan',
#      'role_pos': [[('raging', 'VBG'), ('fan', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Office worker',
#      'role_pos': [[('office', 'NN'), ('worker', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Play Actor',
#      'role_pos': [[('play', 'NN'), ('actor', 'NN')]]},
#     {'gender': 'M', 'role': 'Extra', 'role_pos': [[('extra', 'NN')]]},
#     {'gender': 'M', 'role': 'Surfer', 'role_pos': [[('surfer', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Club Dancer',
#      'role_pos': [[('club', 'NN'), ('dancer', 'NN')]]},
#     {'gender': 'M',
#      'role': 'NBA Player #30',
#      'role_pos': [[('nba', 'NN'),
#        ('player', 'NN'),
#        ('#', '#'),
#        ('30', 'CD')]]},
#     {'gender': 'M',
#      'role': "Devil's Lawyer",
#      'role_pos': [[('devil', 'NN'), ("'s", 'POS'), ('lawyer', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Play Actor',
#      'role_pos': [[('play', 'NN'), ('actor', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Club DV8 Goth',
#      'role_pos': [[('club', 'NN'), ('dv8', 'NNP'), ('goth', 'NN')]]},
#     {'gender': 'M', 'role': 'Usher', 'role_pos': [[('usher', 'PRP$')]]},
#     {'gender': 'M',
#      'role': 'Elegant Devil',
#      'role_pos': [[('elegant', 'NN'), ('devil', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Police Officer',
#      'role_pos': [[('police', 'NN'), ('officer', 'NN')]]},
#     {'gender': 'M',
#      'role': 'DV8 Clubgoer',
#      'role_pos': [[('dv8', 'NNP'), ('clubgoer', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Cafe Patron at the Car Crash',
#      'role_pos': [[('cafe', 'NN'),
#        ('patron', 'VBD'),
#        ('at', 'IN'),
#        ('the', 'DT'),
#        ('car', 'NN'),
#        ('crash', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Drug Factory Foreman',
#      'role_pos': [[('drug', 'NN'), ('factory', 'NN'), ('foreman', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Columbian Soldier',
#      'role_pos': [[('columbian', 'JJ'), ('soldier', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Security Guard (Rock Fantasy)',
#      'role_pos': [[('security', 'NN'),
#        ('guard', 'VBD'),
#        ('(', 'CD'),
#        ('rock', 'NN'),
#        ('fantasy', 'NN'),
#        (')', ':')]]},
#     {'gender': 'M',
#      'role': 'Biggest Devil',
#      'role_ne': [Tree('S', [Tree('GPE', [['Biggest', 'JJS']]), Tree('ORGANIZATION', [['Devil', 'NN']])])],
#      'role_pos': [[['Biggest', 'JJS'], ['Devil', 'NN']]]}],
#    'summaries_imdb': ['Elliot Richardson, a socially awkward IT worker, is given seven wishes to get the girl of his dreams when he meets up with a very seductive Satan. The catch: his soul. Some of his wishes include being a 7 foot basketball star, a wealthy, powerful man, and a sensitive caring guy. But, as could be expected, the Devil must put her own little twist on each his fantasies. Elliot Richards, a socially incompetent technical advisor working at a call-center, has had a crush on Alison Gardner for nearly four years. One evening, which already started particularly bad for Elliot, she ditches him. Elliot wishes for her to be in his life with all his heart - and is heard. An incredibly beautiful young lady addresses Elliot, and after introducing herself as the Devil, Lucifer, the Princess of Darkness, she offers him a deal: Seven wishes for him, his Soul for her. Quickly, Elliot is convinced and accepts. But every wish he gets fulfilled has massive disadvantages as well, and soon Elliot wants to get out of the contract. The only thing that matters to him now is being able to take his chances by himself.'],
#    'summaries_imdb_ner': [('Elliot', 'PERSON'),
#     ('Richardson,', 'O'),
#     ('a', 'O'),
#     ('socially', 'O'),
#     ('awkward', 'O'),
#     ('IT', 'O'),
#     ('worker,', 'O'),
#     ('is', 'O'),
#     ('given', 'O'),
#     ('seven', 'O'),
#     ('wishes', 'O'),
#     ('to', 'O'),
#     ('get', 'O'),
#     ('the', 'O'),
#     ('girl', 'O'),
#     ('of', 'O'),
#     ('his', 'O'),
#     ('dreams', 'O'),
#     ('when', 'O'),
#     ('he', 'O'),
#     ('meets', 'O'),
#     ('up', 'O'),
#     ('with', 'O'),
#     ('a', 'O'),
#     ('very', 'O'),
#     ('seductive', 'O'),
#     ('Satan.', 'O'),
#     ('The', 'O'),
#     ('catch:', 'O'),
#     ('his', 'O'),
#     ('soul.', 'O'),
#     ('Some', 'O'),
#     ('of', 'O'),
#     ('his', 'O'),
#     ('wishes', 'O'),
#     ('include', 'O'),
#     ('being', 'O'),
#     ('a', 'O'),
#     ('7', 'O'),
#     ('foot', 'O'),
#     ('basketball', 'O'),
#     ('star,', 'O'),
#     ('a', 'O'),
#     ('wealthy,', 'O'),
#     ('powerful', 'O'),
#     ('man,', 'O'),
#     ('and', 'O'),
#     ('a', 'O'),
#     ('sensitive', 'O'),
#     ('caring', 'O'),
#     ('guy.', 'O'),
#     ('But,', 'O'),
#     ('as', 'O'),
#     ('could', 'O'),
#     ('be', 'O'),
#     ('expected,', 'O'),
#     ('the', 'O'),
#     ('Devil', 'O'),
#     ('must', 'O'),
#     ('put', 'O'),
#     ('her', 'O'),
#     ('own', 'O'),
#     ('little', 'O'),
#     ('twist', 'O'),
#     ('on', 'O'),
#     ('each', 'O'),
#     ('his', 'O'),
#     ('fantasies.', 'O'),
#     ('Elliot', 'PERSON'),
#     ('Richards,', 'O'),
#     ('a', 'O'),
#     ('socially', 'O'),
#     ('incompetent', 'O'),
#     ('technical', 'O'),
#     ('advisor', 'O'),
#     ('working', 'O'),
#     ('at', 'O'),
#     ('a', 'O'),
#     ('call-center,', 'O'),
#     ('has', 'O'),
#     ('had', 'O'),
#     ('a', 'O'),
#     ('crush', 'O'),
#     ('on', 'O'),
#     ('Alison', 'PERSON'),
#     ('Gardner', 'PERSON'),
#     ('for', 'O'),
#     ('nearly', 'O'),
#     ('four', 'O'),
#     ('years.', 'O'),
#     ('One', 'O'),
#     ('evening,', 'O'),
#     ('which', 'O'),
#     ('already', 'O'),
#     ('started', 'O'),
#     ('particularly', 'O'),
#     ('bad', 'O'),
#     ('for', 'O'),
#     ('Elliot,', 'O'),
#     ('she', 'O'),
#     ('ditches', 'O'),
#     ('him.', 'O'),
#     ('Elliot', 'PERSON'),
#     ('wishes', 'O'),
#     ('for', 'O'),
#     ('her', 'O'),
#     ('to', 'O'),
#     ('be', 'O'),
#     ('in', 'O'),
#     ('his', 'O'),
#     ('life', 'O'),
#     ('with', 'O'),
#     ('all', 'O'),
#     ('his', 'O'),
#     ('heart', 'O'),
#     ('-', 'O'),
#     ('and', 'O'),
#     ('is', 'O'),
#     ('heard.', 'O'),
#     ('An', 'O'),
#     ('incredibly', 'O'),
#     ('beautiful', 'O'),
#     ('young', 'O'),
#     ('lady', 'O'),
#     ('addresses', 'O'),
#     ('Elliot,', 'O'),
#     ('and', 'O'),
#     ('after', 'O'),
#     ('introducing', 'O'),
#     ('herself', 'O'),
#     ('as', 'O'),
#     ('the', 'O'),
#     ('Devil,', 'O'),
#     ('Lucifer,', 'O'),
#     ('the', 'O'),
#     ('Princess', 'O'),
#     ('of', 'O'),
#     ('Darkness,', 'O'),
#     ('she', 'O'),
#     ('offers', 'O'),
#     ('him', 'O'),
#     ('a', 'O'),
#     ('deal:', 'O'),
#     ('Seven', 'O'),
#     ('wishes', 'O'),
#     ('for', 'O'),
#     ('him,', 'O'),
#     ('his', 'O'),
#     ('Soul', 'O'),
#     ('for', 'O'),
#     ('her.', 'O'),
#     ('Quickly,', 'O'),
#     ('Elliot', 'PERSON'),
#     ('is', 'O'),
#     ('convinced', 'O'),
#     ('and', 'O'),
#     ('accepts.', 'O'),
#     ('But', 'O'),
#     ('every', 'O'),
#     ('wish', 'O'),
#     ('he', 'O'),
#     ('gets', 'O'),
#     ('fulfilled', 'O'),
#     ('has', 'O'),
#     ('massive', 'O'),
#     ('disadvantages', 'O'),
#     ('as', 'O'),
#     ('well,', 'O'),
#     ('and', 'O'),
#     ('soon', 'O'),
#     ('Elliot', 'PERSON'),
#     ('wants', 'O'),
#     ('to', 'O'),
#     ('get', 'O'),
#     ('out', 'O'),
#     ('of', 'O'),
#     ('the', 'O'),
#     ('contract.', 'O'),
#     ('The', 'O'),
#     ('only', 'O'),
#     ('thing', 'O'),
#     ('that', 'O'),
#     ('matters', 'O'),
#     ('to', 'O'),
#     ('him', 'O'),
#     ('now', 'O'),
#     ('is', 'O'),
#     ('being', 'O'),
#     ('able', 'O'),
#     ('to', 'O'),
#     ('take', 'O'),
#     ('his', 'O'),
#     ('chances', 'O'),
#     ('by', 'O'),
#     ('himself.', 'O')],
#    'summaries_imdb_pos': [[('Elliot', 'NNP'),
#      ('Richardson', 'NNP'),
#      (',', ','),
#      ('a', 'DT'),
#      ('socially', 'RB'),
#      ('awkward', 'JJ'),
#      ('IT', 'PRP'),
#      ('worker', 'NN'),
#      (',', ','),
#      ('is', 'VBZ'),
#      ('given', 'VBN'),
#      ('seven', 'CD'),
#      ('wishes', 'NNS'),
#      ('to', 'TO'),
#      ('get', 'VB'),
#      ('the', 'DT'),
#      ('girl', 'NN'),
#      ('of', 'IN'),
#      ('his', 'PRP$'),
#      ('dreams', 'NNS'),
#      ('when', 'WRB'),
#      ('he', 'PRP'),
#      ('meets', 'VBZ'),
#      ('up', 'RP'),
#      ('with', 'IN'),
#      ('a', 'DT'),
#      ('very', 'RB'),
#      ('seductive', 'JJ'),
#      ('Satan', 'NNP'),
#      ('.', '.')],
#     [('The', 'DT'),
#      ('catch', 'NN'),
#      (':', ':'),
#      ('his', 'PRP$'),
#      ('soul', 'NN'),
#      ('.', '.')],
#     [('Some', 'DT'),
#      ('of', 'IN'),
#      ('his', 'PRP$'),
#      ('wishes', 'NNS'),
#      ('include', 'VBP'),
#      ('being', 'VBG'),
#      ('a', 'DT'),
#      ('7', 'CD'),
#      ('foot', 'NN'),
#      ('basketball', 'NN'),
#      ('star', 'NN'),
#      (',', ','),
#      ('a', 'DT'),
#      ('wealthy', 'JJ'),
#      (',', ','),
#      ('powerful', 'JJ'),
#      ('man', 'NN'),
#      (',', ','),
#      ('and', 'CC'),
#      ('a', 'DT'),
#      ('sensitive', 'JJ'),
#      ('caring', 'NN'),
#      ('guy', 'NN'),
#      ('.', '.')],
#     [('But', 'CC'),
#      (',', ','),
#      ('as', 'IN'),
#      ('could', 'MD'),
#      ('be', 'VB'),
#      ('expected', 'VBN'),
#      (',', ','),
#      ('the', 'DT'),
#      ('Devil', 'NNP'),
#      ('must', 'MD'),
#      ('put', 'VB'),
#      ('her', 'PRP'),
#      ('own', 'VB'),
#      ('little', 'JJ'),
#      ('twist', 'NN'),
#      ('on', 'IN'),
#      ('each', 'DT'),
#      ('his', 'PRP$'),
#      ('fantasies', 'NNS'),
#      ('.', '.')],
#     [('Elliot', 'NNP'),
#      ('Richards', 'NNP'),
#      (',', ','),
#      ('a', 'DT'),
#      ('socially', 'RB'),
#      ('incompetent', 'JJ'),
#      ('technical', 'JJ'),
#      ('advisor', 'NN'),
#      ('working', 'VBG'),
#      ('at', 'IN'),
#      ('a', 'DT'),
#      ('call-center', 'JJ'),
#      (',', ','),
#      ('has', 'VBZ'),
#      ('had', 'VBN'),
#      ('a', 'DT'),
#      ('crush', 'JJ'),
#      ('on', 'IN'),
#      ('Alison', 'NNP'),
#      ('Gardner', 'NNP'),
#      ('for', 'IN'),
#      ('nearly', 'RB'),
#      ('four', 'CD'),
#      ('years', 'NNS'),
#      ('.', '.')],
#     [('One', 'CD'),
#      ('evening', 'NN'),
#      (',', ','),
#      ('which', 'WDT'),
#      ('already', 'RB'),
#      ('started', 'VBD'),
#      ('particularly', 'RB'),
#      ('bad', 'JJ'),
#      ('for', 'IN'),
#      ('Elliot', 'NNP'),
#      (',', ','),
#      ('she', 'PRP'),
#      ('ditches', 'VBZ'),
#      ('him', 'PRP'),
#      ('.', '.')],
#     [('Elliot', 'NNP'),
#      ('wishes', 'VBZ'),
#      ('for', 'IN'),
#      ('her', 'PRP$'),
#      ('to', 'TO'),
#      ('be', 'VB'),
#      ('in', 'IN'),
#      ('his', 'PRP$'),
#      ('life', 'NN'),
#      ('with', 'IN'),
#      ('all', 'DT'),
#      ('his', 'PRP$'),
#      ('heart', 'NN'),
#      ('-', ':'),
#      ('and', 'CC'),
#      ('is', 'VBZ'),
#      ('heard', 'VBN'),
#      ('.', '.')],
#     [('An', 'DT'),
#      ('incredibly', 'RB'),
#      ('beautiful', 'JJ'),
#      ('young', 'JJ'),
#      ('lady', 'NN'),
#      ('addresses', 'NNS'),
#      ('Elliot', 'NNP'),
#      (',', ','),
#      ('and', 'CC'),
#      ('after', 'IN'),
#      ('introducing', 'VBG'),
#      ('herself', 'PRP'),
#      ('as', 'IN'),
#      ('the', 'DT'),
#      ('Devil', 'NNP'),
#      (',', ','),
#      ('Lucifer', 'NNP'),
#      (',', ','),
#      ('the', 'DT'),
#      ('Princess', 'NNP'),
#      ('of', 'IN'),
#      ('Darkness', 'NNP'),
#      (',', ','),
#      ('she', 'PRP'),
#      ('offers', 'VBZ'),
#      ('him', 'PRP'),
#      ('a', 'DT'),
#      ('deal', 'NN'),
#      (':', ':'),
#      ('Seven', 'CD'),
#      ('wishes', 'NNS'),
#      ('for', 'IN'),
#      ('him', 'PRP'),
#      (',', ','),
#      ('his', 'PRP$'),
#      ('Soul', 'NNP'),
#      ('for', 'IN'),
#      ('her', 'PRP'),
#      ('.', '.')],
#     [('Quickly', 'RB'),
#      (',', ','),
#      ('Elliot', 'NNP'),
#      ('is', 'VBZ'),
#      ('convinced', 'VBN'),
#      ('and', 'CC'),
#      ('accepts', 'NNS'),
#      ('.', '.')],
#     [('But', 'CC'),
#      ('every', 'DT'),
#      ('wish', 'NN'),
#      ('he', 'PRP'),
#      ('gets', 'VBZ'),
#      ('fulfilled', 'VBN'),
#      ('has', 'VBZ'),
#      ('massive', 'JJ'),
#      ('disadvantages', 'NNS'),
#      ('as', 'IN'),
#      ('well', 'RB'),
#      (',', ','),
#      ('and', 'CC'),
#      ('soon', 'RB'),
#      ('Elliot', 'NNP'),
#      ('wants', 'VBZ'),
#      ('to', 'TO'),
#      ('get', 'VB'),
#      ('out', 'IN'),
#      ('of', 'IN'),
#      ('the', 'DT'),
#      ('contract', 'NN'),
#      ('.', '.')],
#     [('The', 'DT'),
#      ('only', 'JJ'),
#      ('thing', 'NN'),
#      ('that', 'WDT'),
#      ('matters', 'NNS'),
#      ('to', 'TO'),
#      ('him', 'PRP'),
#      ('now', 'RB'),
#      ('is', 'VBZ'),
#      ('being', 'VBG'),
#      ('able', 'JJ'),
#      ('to', 'TO'),
#      ('take', 'VB'),
#      ('his', 'PRP$'),
#      ('chances', 'NNS'),
#      ('by', 'IN'),
#      ('himself', 'PRP'),
#      ('.', '.')]],
#    'summaries_wikipedia': ['Elliot Richards  is a geeky, over-zealous man working a dead-end technical support job in a San Francisco computer company. He has no friends and his co-workers use him, knowing he will do anything for acceptance. He has a crush on his colleague, Alison Gardner , but lacks the courage to ask her out. After Elliot is again ditched by his co-workers, at a bar while trying to talk to Alison, he says to himself that he would give anything for Alison to be with him. Satan , in the form of a beautiful woman, overhears him and offers to give Elliot seven wishes in return for his soul. As a test, he wishes for a Big Mac and Coke. Satan takes him to McDonald\'s and places the order. Elliot has to pay for it, because, "there ain\'t no such thing as a free lunch." After taking Elliot to her office, based at a nightclub in Oakland, Satan convinces Elliot to sign her contract, and delivers further wishes. Each wish has Elliot living them out with Alison and his co-workers in surrogate roles. However, he doesn\'t know that Satan will always spoil his wishes by adding something he doesn\'t want. Elliot wishes to be rich and powerful, with Alison as his wife. Satan makes him a Colombian drug lord whose wife despises him and cheats on him with Raul, his co-worker, who is secretly planning to get rid of Elliot and take his position and property. Soon after there is a firefight between his and Raul\'s people where Elliot "dies". When he returns to the real world, Satan points out that he never wished for Alison to love him. Secondly, Elliot wishes to be emotionally sensitive so he will understand the needs and desires of women. Satan makes him so sensitive that he spends most of his time crying over how beautiful the world is, and constantly asks Alison, his girlfriend of "three magical weeks," whether he has hurt her or if she needs anything. Alison says she has had enough of it and wants to be with a man who is strong and shallow. She then leaves Elliot for a man who is strong, rude and completely different from the romantic and emotionally sensitive Elliot. Elliot then wishes to be a superstar athlete who would be a woman magnet. Satan makes him a clich̩-spewing NBA star, but also gives him a small penis and a low IQ, which causes Alison, a sports reporter, to lose interest in him shortly after they meet. He then wishes to be intelligent, witty and well-endowed. Satan grants this by making him a famous writer whom Alison falls in love with at a cocktail party. When they arrive at Elliot\'s home to make love it is revealed that Elliot is gay and living with a flamboyant male partner. Lastly, Elliot wishes to be President of the United States to try to improve the world and get Alison to take him seriously. Satan makes him Abraham Lincoln at Ford\'s Theatre on the night of his assassination which he nearly avoids. After each wish is renounced, Elliot meets with Satan and she blames him for not being specific enough. Eventually he returns to work, thinking about what he should do with the last two wishes. Satan appears on the computer screen, pointing out that on their first meeting he asked for a Big Mac and Coke, although she had stated that it was a test wish and granted it before Elliot signed the contract. Elliot loses his patience and storms out of his office. Elliot visits a church looking for God\'s help, where he briefly confesses to a priest who seems sympathetic. However, after being asked whether he thinks asking Satan for a Big Mac and Coke counts as a wish, the priest, believing he is drunk, has Elliot arrested. The sergeant books him, and Satan, dressed as a police officer, throws him in a cell, telling him that she does like him, and it would not hurt to have her as a friend. Elliot\'s cellmate  tells him that he cannot possibly sell his soul as it belongs to God, and although Satan may try to confuse him, in the end he will realise who he truly is, and what his purpose is. Elliot questions the man as ...
#    'summaries_wikipedia_ner': [('Elliot', 'PERSON'),
#     ('Richards', 'PERSON'),
#     ('is', 'O'),
#     ('a', 'O'),
#     ('geeky,', 'O'),
#     ('over-zealous', 'O'),
#     ('man', 'O'),
#     ('working', 'O'),
#     ('a', 'O'),
#     ('dead-end', 'O'),
#     ('technical', 'O'),
#     ('support', 'O'),
#     ('job', 'O'),
#     ('in', 'O'),
#     ('a', 'O'),
#     ('San', 'LOCATION'),
#     ('Francisco', 'LOCATION'),
#     ('computer', 'O'),
#     ('company.', 'O'),
#     ('He', 'O'),
#     ('has', 'O'),
#     ('no', 'O'),
#     ('friends', 'O'),
#     ('and', 'O'),
#     ('his', 'O'),
#     ('co-workers', 'O'),
#     ('use', 'O'),
#     ('him,', 'O'),
#     ('knowing', 'O'),
#     ('he', 'O'),
#     ('will', 'O'),
#     ('do', 'O'),
#     ('anything', 'O'),
#     ('for', 'O'),
#     ('acceptance.', 'O'),
#     ('He', 'O'),
#     ('has', 'O'),
#     ('a', 'O'),
#     ('crush', 'O'),
#     ('on', 'O'),
#     ('his', 'O'),
#     ('colleague,', 'O'),
#     ('Alison', 'PERSON'),
#     ('Gardner', 'PERSON'),
#     (',', 'O'),
#     ('but', 'O'),
#     ('lacks', 'O'),
#     ('the', 'O'),
#     ('courage', 'O'),
#     ('to', 'O'),
#     ('ask', 'O'),
#     ('her', 'O'),
#     ('out.', 'O'),
#     ('After', 'O'),
#     ('Elliot', 'PERSON'),
#     ('is', 'O'),
#     ('again', 'O'),
#     ('ditched', 'O'),
#     ('by', 'O'),
#     ('his', 'O'),
#     ('co-workers,', 'O'),
#     ('at', 'O'),
#     ('a', 'O'),
#     ('bar', 'O'),
#     ('while', 'O'),
#     ('trying', 'O'),
#     ('to', 'O'),
#     ('talk', 'O'),
#     ('to', 'O'),
#     ('Alison,', 'O'),
#     ('he', 'O'),
#     ('says', 'O'),
#     ('to', 'O'),
#     ('himself', 'O'),
#     ('that', 'O'),
#     ('he', 'O'),
#     ('would', 'O'),
#     ('give', 'O'),
#     ('anything', 'O'),
#     ('for', 'O'),
#     ('Alison', 'PERSON'),
#     ('to', 'O'),
#     ('be', 'O'),
#     ('with', 'O'),
#     ('him.', 'O'),
#     ('Satan', 'O'),
#     (',', 'O'),
#     ('in', 'O'),
#     ('the', 'O'),
#     ('form', 'O'),
#     ('of', 'O'),
#     ('a', 'O'),
#     ('beautiful', 'O'),
#     ('woman,', 'O'),
#     ('overhears', 'O'),
#     ('him', 'O'),
#     ('and', 'O'),
#     ('offers', 'O'),
#     ('to', 'O'),
#     ('give', 'O'),
#     ('Elliot', 'PERSON'),
#     ('seven', 'O'),
#     ('wishes', 'O'),
#     ('in', 'O'),
#     ('return', 'O'),
#     ('for', 'O'),
#     ('his', 'O'),
#     ('soul.', 'O'),
#     ('As', 'O'),
#     ('a', 'O'),
#     ('test,', 'O'),
#     ('he', 'O'),
#     ('wishes', 'O'),
#     ('for', 'O'),
#     ('a', 'O'),
#     ('Big', 'O'),
#     ('Mac', 'O'),
#     ('and', 'O'),
#     ('Coke.', 'O'),
#     ('Satan', 'PERSON'),
#     ('takes', 'O'),
#     ('him', 'O'),
#     ('to', 'O'),
#     ("McDonald's", 'O'),
#     ('and', 'O'),
#     ('places', 'O'),
#     ('the', 'O'),
#     ('order.', 'O'),
#     ('Elliot', 'PERSON'),
#     ('has', 'O'),
#     ('to', 'O'),
#     ('pay', 'O'),
#     ('for', 'O'),
#     ('it,', 'O'),
#     ('because,', 'O'),
#     ('"there', 'O'),
#     ("ain't", 'O'),
#     ('no', 'O'),
#     ('such', 'O'),
#     ('thing', 'O'),
#     ('as', 'O'),
#     ('a', 'O'),
#     ('free', 'O'),
#     ('lunch."', 'O'),
#     ('After', 'O'),
#     ('taking', 'O'),
#     ('Elliot', 'PERSON'),
#     ('to', 'O'),
#     ('her', 'O'),
#     ('office,', 'O'),
#     ('based', 'O'),
#     ('at', 'O'),
#     ('a', 'O'),
#     ('nightclub', 'O'),
#     ('in', 'O'),
#     ('Oakland,', 'O'),
#     ('Satan', 'O'),
#     ('convinces', 'O'),
#     ('Elliot', 'PERSON'),
#     ('to', 'O'),
#     ('sign', 'O'),
#     ('her', 'O'),
#     ('contract,', 'O'),
#     ('and', 'O'),
#     ('delivers', 'O'),
#     ('further', 'O'),
#     ('wishes.', 'O'),
#     ('Each', 'O'),
#     ('wish', 'O'),
#     ('has', 'O'),
#     ('Elliot', 'PERSON'),
#     ('living', 'O'),
#     ('them', 'O'),
#     ('out', 'O'),
#     ('with', 'O'),
#     ('Alison', 'PERSON'),
#     ('and', 'O'),
#     ('his', 'O'),
#     ('co-workers', 'O'),
#     ('in', 'O'),
#     ('surrogate', 'O'),
#     ('roles.', 'O'),
#     ('However,', 'O'),
#     ('he', 'O'),
#     ("doesn't", 'O'),
#     ('know', 'O'),
#     ('that', 'O'),
#     ('Satan', 'O'),
#     ('will', 'O'),
#     ('always', 'O'),
#     ('spoil', 'O'),
#     ('his', 'O'),
#     ('wishes', 'O'),
#     ('by', 'O'),
#     ('adding', 'O'),
#     ('something', 'O'),
#     ('he', 'O'),
#     ("doesn't", 'O'),
#     ('want.', 'O'),
#     ('Elliot', 'PERSON'),
#     ('wishes', 'O'),
#     ('to', 'O'),
#     ('be', 'O'),
#     ('rich', 'O'),
#     ('and', 'O'),
#     ('powerful,', 'O'),
#     ('with', 'O'),
#     ('Alison', 'PERSON'),
#     ('as', 'O'),
#     ('his', 'O'),
#     ('wife.', 'O'),
#     ('Satan', 'O'),
#     ('makes', 'O'),
#     ('him', 'O'),
#     ('a', 'O'),
#     ('Colombian', 'O'),
#     ('drug', 'O'),
#     ('lord', 'O'),
#     ('whose', 'O'),
#     ('wife', 'O'),
#     ('despises', 'O'),
#     ('him', 'O'),
#     ('and', 'O'),
#     ('cheats', 'O'),
#     ('on', 'O'),
#     ('him', 'O'),
#     ('with', 'O'),
#     ('Raul,', 'O'),
#     ('his', 'O'),
#     ('co-worker,', 'O'),
#     ('who', 'O'),
#     ('is', 'O'),
#     ('secretly', 'O'),
#     ('planning', 'O'),
#     ('to', 'O'),
#     ('get', 'O'),
#     ('rid', 'O'),
#     ('of', 'O'),
#     ('Elliot', 'PERSON'),
#     ('and', 'O'),
#     ('take', 'O'),
#     ('his', 'O'),
#     ('position', 'O'),
#     ('and', 'O'),
#     ('property.', 'O'),
#     ('Soon', 'O'),
#     ('after', 'O'),
#     ('there', 'O'),
#     ('is', 'O'),
#     ('a', 'O'),
#     ('firefight', 'O'),
#     ('between', 'O'),
#     ('his', 'O'),
#     ('and', 'O'),
#     ("Raul's", 'O'),
#     ('people', 'O'),
#     ('where', 'O'),
#     ('Elliot', 'PERSON'),
#     ('"dies".', 'O'),
#     ('When', 'O'),
#     ('he', 'O'),
#     ('returns', 'O'),
#     ('to', 'O'),
#     ('the', 'O'),
#     ('real', 'O'),
#     ('world,', 'O'),
#     ('Satan', 'O'),
#     ('points', 'O'),
#     ('out', 'O'),
#     ('that', 'O'),
#     ('he', 'O'),
#     ('never', 'O'),
#     ('wished', 'O'),
#     ('for', 'O'),
#     ('Alison', 'PERSON'),
#     ('to', 'O'),
#     ('love', 'O'),
#     ('him.', 'O'),
#     ('Secondly,', 'O'),
#     ('Elliot', 'PERSON'),
#     ('wishes', 'O'),
#     ('to', 'O'),
#     ('be', 'O'),
#     ('emotionally', 'O'),
#     ('sensitive', 'O'),
#     ('so', 'O'),
#     ('he', 'O'),
#     ('will', 'O'),
#     ('understand', 'O'),
#     ('the', 'O'),
#     ('needs', 'O'),
#     ('and', 'O'),
#     ('desires', 'O'),
#     ('of', 'O'),
#     ('women.', 'O'),
#     ('Satan', 'O'),
#     ('makes', 'O'),
#     ('him', 'O'),
#     ('so', 'O'),
#     ('sensitive', 'O'),
#     ('that', 'O'),
#     ('he', 'O'),
#     ('spends', 'O'),
#     ('most', 'O'),
#     ('of', 'O'),
#     ('his', 'O'),
#     ('time', 'O'),
#     ('crying', 'O'),
#     ('over', 'O'),
#     ('how', 'O'),
#     ('beautiful', 'O'),
#     ('the', 'O'),
#     ('world', 'O'),
#     ('is,', 'O'),
#     ('and', 'O'),
#     ('constantly', 'O'),
#     ('asks', 'O'),
#     ('Alison,', 'O'),
#     ('his', 'O'),
#     ('girlfriend', 'O'),
#     ('of', 'O'),
#     ('"three', 'O'),
#     ('magical', 'O'),
#     ('weeks,"', 'O'),
#     ('whether', 'O'),
#     ('he', 'O'),
#     ('has', 'O'),
#     ('hurt', 'O'),
#     ('her', 'O'),
#     ('or', 'O'),
#     ('if', 'O'),
#     ('she', 'O'),
#     ('needs', 'O'),
#     ('anything.', 'O'),
#     ('Alison', 'PERSON'),
#     ('says', 'O'),
#     ('she', 'O'),
#     ('has', 'O'),
#     ('had', 'O'),
#     ('enough', 'O'),
#     ('of', 'O'),
#     ('it', 'O'),
#     ('and', 'O'),
#     ('wants', 'O'),
#     ('to', 'O'),
#     ('be', 'O'),
#     ('with', 'O'),
#     ('a', 'O'),
#     ('man', 'O'),
#     ('who', 'O'),
#     ('is', 'O'),
#     ('strong', 'O'),
#     ('and', 'O'),
#     ('shallow.', 'O'),
#     ('She', 'O'),
#     ('then', 'O'),
#     ('leaves', 'O'),
#     ('Elliot', 'PERSON'),
#     ('for', 'O'),
#     ('a', 'O'),
#     ('man', 'O'),
#     ('who', 'O'),
#     ('is', 'O'),
#     ('strong,', 'O'),
#     ('rude', 'O'),
#     ('and', 'O'),
#     ('completely', 'O'),
#     ('different', 'O'),
#     ('from', 'O'),
#     ('the', 'O'),
#     ('romantic', 'O'),
#     ('and', 'O'),
#     ('emotionally', 'O'),
#     ('sensitive', 'O'),
#     ('Elliot.', 'O'),
#     ('Elliot', 'PERSON'),
#     ('then', 'O'),
#     ('wishes', 'O'),
#     ('to', 'O'),
#     ('be', 'O'),
#     ('a', 'O'),
#     ('superstar', 'O'),
#     ('athlete', 'O'),
#     ('who', 'O'),
#     ('would', 'O'),
#     ('be', 'O'),
#     ('a', 'O'),
#     ('woman', 'O'),
#     ('magnet.', 'O'),
#     ('Satan', 'O'),
#     ('makes', 'O'),
#     ('him', 'O'),
#     ('a', 'O'),
#     ('clich̩-spewing', 'O'),
#     ('NBA', 'O'),
#     ('star,', 'O'),
#     ('but', 'O'),
#     ('also', 'O'),
#     ('gives', 'O'),
#     ('him', 'O'),
#     ('a', 'O'),
#     ('small', 'O'),
#     ('penis', 'O'),
#     ('and', 'O'),
#     ('a', 'O'),
#     ('low', 'O'),
#     ('IQ,', 'O'),
#     ('which', 'O'),
#     ('causes', 'O'),
#     ('Alison,', 'O'),
#     ('a', 'O'),
#     ('sports', 'O'),
#     ('reporter,', 'O'),
#     ('to', 'O'),
#     ('lose', 'O'),
#     ('interest', 'O'),
#     ('in', 'O'),
#     ('him', 'O'),
#     ('shortly', 'O'),
#     ('after', 'O'),
#     ('they', 'O'),
#     ('meet.', 'O'),
#     ('He', 'O'),
#     ('then', 'O'),
#     ('wishes', 'O'),
#     ('to', 'O'),
#     ('be', 'O'),
#     ('intelligent,', 'O'),
#     ('witty', 'O'),
#     ('and', 'O'),
#     ('well-endowed.', 'O'),
#     ('Satan', 'O'),
#     ('grants', 'O'),
#     ('this', 'O'),
#     ('by', 'O'),
#     ('making', 'O'),
#     ('him', 'O'),
#     ('a', 'O'),
#     ('famous', 'O'),
#     ('writer', 'O'),
#     ('whom', 'O'),
#     ('Alison', 'PERSON'),
#     ('falls', 'O'),
#     ('in', 'O'),
#     ('love', 'O'),
#     ('with', 'O'),
#     ('at', 'O'),
#     ('a', 'O'),
#     ('cocktail', 'O'),
#     ('party.', 'O'),
#     ('When', 'O'),
#     ('they', 'O'),
#     ('arrive', 'O'),
#     ('at', 'O'),
#     ("Elliot's", 'O'),
#     ('home', 'O'),
#     ('to', 'O'),
#     ('make', 'O'),
#     ('love', 'O'),
#     ('it', 'O'),
#     ('is', 'O'),
#     ('revealed', 'O'),
#     ('that', 'O'),
#     ('Elliot', 'PERSON'),
#     ('is', 'O'),
#     ('gay', 'O'),
#     ('and', 'O'),
#     ('living', 'O'),
#     ('with', 'O'),
#     ('a', 'O'),
#     ('flamboyant', 'O'),
#     ('male', 'O'),
#     ('partner.', 'O'),
#     ('Lastly,', 'O'),
#     ('Elliot', 'PERSON'),
#     ('wishes', 'O'),
#     ('to', 'O'),
#     ('be', 'O'),
#     ('President', 'O'),
#     ('of', 'O'),
#     ('the', 'O'),
#     ('United', 'LOCATION'),
#     ('States', 'LOCATION'),
#     ('to', 'O'),
#     ('try', 'O'),
#     ('to', 'O'),
#     ('improve', 'O'),
#     ('the', 'O'),
#     ('world', 'O'),
#     ('and', 'O'),
#     ('get', 'O'),
#     ('Alison', 'PERSON'),
#     ('to', 'O'),
#     ('take', 'O'),
#     ('him', 'O'),
#     ('seriously.', 'O'),
#     ('Satan', 'O'),
#     ('makes', 'O'),
#     ('him', 'O'),
#     ('Abraham', 'PERSON'),
#     ('Lincoln', 'PERSON'),
#     ('at', 'O'),
#     ("Ford's", 'O'),
#     ('Theatre', 'O'),
#     ('on', 'O'),
#     ('the', 'O'),
#     ('night', 'O'),
#     ('of', 'O'),
#     ('his', 'O'),
#     ('assassination', 'O'),
#     ('which', 'O'),
#     ('he', 'O'),
#     ('nearly', 'O'),
#     ('avoids.', 'O'),
#     ('After', 'O'),
#     ('each', 'O'),
#     ('wish', 'O'),
#     ('is', 'O'),
#     ('renounced,', 'O'),
#     ('Elliot', 'PERSON'),
#     ('meets', 'O'),
#     ('with', 'O'),
#     ('Satan', 'PERSON'),
#     ('and', 'O'),
#     ('she', 'O'),
#     ('blames', 'O'),
#     ('him', 'O'),
#     ('for', 'O'),
#     ('not', 'O'),
#     ('being', 'O'),
#     ('specific', 'O'),
#     ('enough.', 'O'),
#     ('Eventually', 'O'),
#     ('he', 'O'),
#     ('returns', 'O'),
#     ('to', 'O'),
#     ('work,', 'O'),
#     ('thinking', 'O'),
#     ('about', 'O'),
#     ('what', 'O'),
#     ('he', 'O'),
#     ('should', 'O'),
#     ('do', 'O'),
#     ('with', 'O'),
#     ('the', 'O'),
#     ('last', 'O'),
#     ('two', 'O'),
#     ('wishes.', 'O'),
#     ('Satan', 'O'),
#     ('appears', 'O'),
#     ('on', 'O'),
#     ('the', 'O'),
#     ('computer', 'O'),
#     ('screen,', 'O'),
#     ('pointing', 'O'),
#     ('out', 'O'),
#     ('that', 'O'),
#     ('on', 'O'),
#     ('their', 'O'),
#     ('first', 'O'),
#     ('meeting', 'O'),
#     ('he', 'O'),
#     ('asked', 'O'),
#     ('for', 'O'),
#     ('a', 'O'),
#     ('Big', 'O'),
#     ('Mac', 'O'),
#     ('and', 'O'),
#     ('Coke,', 'O'),
#     ('although', 'O'),
#     ('she', 'O'),
#     ('had', 'O'),
#     ('stated', 'O'),
#     ('that', 'O'),
#     ('it', 'O'),
#     ('was', 'O'),
#     ('a', 'O'),
#     ('test', 'O'),
#     ('wish', 'O'),
#     ('and', 'O'),
#     ('granted', 'O'),
#     ('it', 'O'),
#     ('before', 'O'),
#     ('Elliot', 'PERSON'),
#     ('signed', 'O'),
#     ('the', 'O'),
#     ('contract.', 'O'),
#     ('Elliot', 'PERSON'),
#     ('loses', 'O'),
#     ('his', 'O'),
#     ('patience', 'O'),
#     ('and', 'O'),
#     ('storms', 'O'),
#     ('out', 'O'),
#     ('of', 'O'),
#     ('his', 'O'),
#     ('office.', 'O'),
#     ('Elliot', 'PERSON'),
#     ('visits', 'O'),
#     ('a', 'O'),
#     ('church', 'O'),
#     ('looking', 'O'),
#     ('for', 'O'),
#     ("God's", 'O'),
#     ('help,', 'O'),
#     ('where', 'O'),
#     ('he', 'O'),
#     ('briefly', 'O'),
#     ('confesses', 'O'),
#     ('to', 'O'),
#     ('a', 'O'),
#     ('priest', 'O'),
#     ('who', 'O'),
#     ('seems', 'O'),
#     ('sympathetic.', 'O'),
#     ('However,', 'O'),
#     ('after', 'O'),
#     ('being', 'O'),
#     ('asked', 'O'),
#     ('whether', 'O'),
#     ('he', 'O'),
#     ('thinks', 'O'),
#     ('asking', 'O'),
#     ('Satan', 'O'),
# ...
#     ('and', 'O'),
#     ('does', 'O'),
#     ('very', 'O'),
#     ('well,', 'O'),
#     ('to', 'O'),
#     ("Scrapper's", 'O'),
#     ('delight.', 'O'),
#     ('In', 'O'),
#     ("Dick's", 'O'),
#     ('senior', 'O'),
#     ('year,', 'O'),
#     ('General', 'O'),
#     ('Fitts', 'PERSON'),
#     ('is', 'O'),
#     ('appointed', 'O'),
#     ('West', 'O'),
#     ('Point', 'O'),
#     ('superintendent.', 'O'),
#     ('While', 'O'),
#     ('most', 'O'),
#     ('of', 'O'),
#     ('the', 'O'),
#     ('men', 'O'),
#     ('are', 'O'),
#     ('infatuated', 'O'),
#     ('with', 'O'),
#     ('Kit,', 'O'),
#     ('Dick', 'PERSON'),
#     ('is', 'O'),
#     ('cold', 'O'),
#     ('to', 'O'),
#     ('her.', 'O'),
#     ('Consequently,', 'O'),
#     ('he', 'O'),
#     ('is', 'O'),
#     ('not', 'O'),
#     ('very', 'O'),
#     ('happy', 'O'),
#     ('when', 'O'),
#     ('the', 'O'),
#     ('rest', 'O'),
#     ('of', 'O'),
#     ('the', 'O'),
#     ('men', 'O'),
#     ('insist', 'O'),
#     ('that', 'O'),
#     ('she', 'O'),
#     ('participate', 'O'),
#     ('in', 'O'),
#     ('the', 'O'),
#     ('traditional', 'O'),
#     ('Hundredth', 'O'),
#     ('Night', 'O'),
#     ('theatrical', 'O'),
#     ('performance.', 'O'),
#     ('Dick', 'PERSON'),
#     ('writes', 'O'),
#     ('a', 'O'),
#     ('show', 'O'),
#     ('about', 'O'),
#     ('a', 'O'),
#     ('female', 'O'),
#     ('general', 'O'),
#     ('with', 'O'),
#     ('a', 'O'),
#     ('message', 'O'),
#     ('directed', 'O'),
#     ('at', 'O'),
#     ('Kit.', 'O'),
#     ('After', 'O'),
#     ('the', 'O'),
#     ('first', 'O'),
#     ('rehearsal,', 'O'),
#     ('Kit', 'O'),
#     ('walks', 'O'),
#     ('with', 'O'),
#     ('Dick', 'PERSON'),
#     ('on', 'O'),
#     ('Flirtation', 'O'),
#     ('Walk', 'O'),
#     ('and', 'O'),
#     ('tries', 'O'),
#     ('to', 'O'),
#     ('explain', 'O'),
#     ('why', 'O'),
#     ('she', 'O'),
#     ('told', 'O'),
#     ('him', 'O'),
#     ('she', 'O'),
#     ('was', 'O'),
#     ('not', 'O'),
#     ('in', 'O'),
#     ('love', 'O'),
#     ('with', 'O'),
#     ('him.', 'O'),
#     ('Dick', 'PERSON'),
#     ('is', 'O'),
#     ('too', 'O'),
#     ('angry', 'O'),
#     ('to', 'O'),
#     ('listen', 'O'),
#     ('to', 'O'),
#     ('Kit', 'O'),
#     ('but,', 'O'),
#     ('during', 'O'),
#     ('their', 'O'),
#     ('on-stage', 'O'),
#     ('love', 'O'),
#     ('scene,', 'O'),
#     ('kisses', 'O'),
#     ('her,', 'O'),
#     ('and', 'O'),
#     ('she', 'O'),
#     ('admits', 'O'),
#     ('she', 'O'),
#     ('loves', 'O'),
#     ('him.', 'O'),
#     ('When', 'O'),
#     ('General', 'O'),
#     ('Fitts', 'PERSON'),
#     ('announces', 'O'),
#     ("Kit's", 'O'),
#     ('engagement', 'O'),
#     ('to', 'O'),
#     ('Biddle,', 'O'),
#     ('Dick', 'PERSON'),
#     ('naturally', 'O'),
#     ('is', 'O'),
#     ('confused,', 'O'),
#     ('and', 'O'),
#     ('visits', 'O'),
#     ('her', 'O'),
#     ('after', 'O'),
#     ('lights', 'O'),
#     ('out', 'O'),
#     ('to', 'O'),
#     ('talk', 'O'),
#     ('her', 'O'),
#     ('out', 'O'),
#     ('of', 'O'),
#     ('marrying', 'O'),
#     ('Biddle.', 'O'),
#     ('He', 'O'),
#     ('is', 'O'),
#     ('caught', 'O'),
#     ('and,', 'O'),
#     ('to', 'O'),
#     ('protect', 'O'),
#     ("Kit's", 'O'),
#     ('name,', 'O'),
#     ('agrees', 'O'),
#     ('to', 'O'),
#     ('resign', 'O'),
#     ('from', 'O'),
#     ('the', 'O'),
#     ('Academy.', 'O'),
#     ('Scrapper', 'O'),
#     ('arrives', 'O'),
#     ('at', 'O'),
#     ('the', 'O'),
#     ('Academy', 'O'),
#     ('to', 'O'),
#     ('see', 'O'),
#     ('Dick', 'PERSON'),
#     ('graduate', 'O'),
#     ('and', 'O'),
#     ('is', 'O'),
#     ('disappointed', 'O'),
#     ('to', 'O'),
#     ('learn', 'O'),
#     ('of', 'O'),
#     ("Dick's", 'O'),
#     ('resignation.', 'O'),
#     ('The', 'O'),
#     ('day', 'O'),
#     ('is', 'O'),
#     ('saved', 'O'),
#     ('when', 'O'),
#     ('Biddle', 'PERSON'),
#     ('tells', 'O'),
#     ('Dick', 'PERSON'),
#     ('that', 'O'),
#     ('his', 'O'),
#     ('resignation', 'O'),
#     ('was', 'O'),
#     ('not', 'O'),
#     ('accepted', 'O'),
#     ('and', 'O'),
#     ('that', 'O'),
#     ('Kit', 'PERSON'),
#     ('returned', 'O'),
#     ('his', 'O'),
#     ('ring.', 'O'),
#     ('Dick', 'PERSON'),
#     ('graduates', 'O'),
#     ('a', 'O'),
#     ('happy', 'O'),
#     ('man.', 'O')],
#    'summaries_wikipedia_pos': [[('Richard', 'NNP'),
#      ('Palmer', 'NNP'),
#      ('Grant', 'NNP'),
#      ('Dorcy', 'NNP'),
#      (',', ','),
#      ('known', 'VBN'),
#      ('as', 'IN'),
#      ('``', '``'),
#      ('Canary', 'NNP'),
#      (',', ','),
#      ("''", "''"),
#      ('is', 'VBZ'),
#      ('an', 'DT'),
#      ('enlisted', 'VBN'),
#      ('man', 'NN'),
#      ('in', 'IN'),
#      ('the', 'DT'),
#      ('United', 'NNP'),
#      ('States', 'NNPS'),
#      ('Army', 'NNP'),
#      ('.', '.')],
#     [('Currently', 'RB'),
#      ('stationed', 'VBN'),
#      ('on', 'IN'),
#      ('the', 'DT'),
#      ('Hawaiian', 'NNP'),
#      ('Islands', 'NNPS'),
#      (',', ','),
#      ('he', 'PRP'),
#      ('has', 'VBZ'),
#      ('an', 'DT'),
#      ('affectionately', 'RB'),
#      ('argumentative', 'JJ'),
#      ('relationship', 'NN'),
#      ('with', 'IN'),
#      ('his', 'PRP$'),
#      ('sergeant', 'JJ'),
#      (',', ','),
#      ('Scrapper', 'NNP'),
#      ('Thornhill', 'NNP'),
#      ('Pat', 'NNP'),
#      ("O'Brien", 'NNP'),
#      ('.', '.')],
#     [('Although', 'IN'),
#      ('he', 'PRP'),
#      ('hates', 'VBZ'),
#      ('taking', 'VBG'),
#      ('orders', 'NNS'),
#      (',', ','),
#      ('Dick', 'NNP'),
#      ('has', 'VBZ'),
#      ('no', 'DT'),
#      ('intention', 'NN'),
#      ('of', 'IN'),
#      ('becoming', 'VBG'),
#      ('an', 'DT'),
#      ('officer', 'NN'),
#      ('.', '.')],
#     [('When', 'WRB'),
#      ('General', 'NNP'),
#      ('Fitts', 'NNP'),
#      ('arrives', 'VBZ'),
#      ('at', 'IN'),
#      ('the', 'DT'),
#      ('base', 'NN'),
#      ('with', 'IN'),
#      ('his', 'PRP$'),
#      ('daughter', 'NN'),
#      ('Kit', 'NNP'),
#      (',', ','),
#      ('Dick', 'NNP'),
#      ('is', 'VBZ'),
#      ('assigned', 'VBN'),
#      ('to', 'TO'),
#      ('drive', 'VB'),
#      ('her', 'PRP$'),
#      ('to', 'TO'),
#      ('the', 'DT'),
#      ('reception', 'NN'),
#      ('that', 'IN'),
#      ('evening', 'NN'),
#      ('.', '.')],
#     [('Falling', 'VBG'),
#      ('victim', 'NN'),
#      ('to', 'TO'),
#      ('the', 'DT'),
#      ('moonlit', 'NN'),
#      ('night', 'NN'),
#      (',', ','),
#      ('Kit', 'NNP'),
#      ('and', 'CC'),
#      ('Dick', 'NNP'),
#      ('miss', 'NN'),
#      ('the', 'DT'),
#      ('reception', 'NN'),
#      ('and', 'CC'),
#      ('attend', 'NN'),
#      ('a', 'DT'),
#      ('native', 'JJ'),
#      ('luau', 'NN'),
#      ('instead', 'RB'),
#      ('.', '.')],
#     [('They', 'PRP'),
#      ('are', 'VBP'),
#      ('discovered', 'VBN'),
#      ('in', 'IN'),
#      ('each', 'DT'),
#      ('other', 'JJ'),
#      ("'s", 'POS'),
#      ('arms', 'NNS'),
#      ('by', 'IN'),
#      ('Lieutenant', 'NNP'),
#      ('Biddle', 'NNP'),
#      ('John', 'NNP'),
#      ('Eldredge', 'NNP'),
#      (',', ','),
#      ('who', 'WP'),
#      ('is', 'VBZ'),
#      ('also', 'RB'),
#      ('in', 'IN'),
#      ('love', 'NN'),
#      ('with', 'IN'),
#      ('Kit', 'NNP'),
#      ('.', '.')],
#     [('Biddle', 'NNP'),
#      ('blames', 'VBZ'),
#      ('Dick', 'NNP'),
#      ('for', 'IN'),
#      ('ruining', 'VBG'),
#      ('Kit', 'NNP'),
#      ("'s", 'POS'),
#      ('reputation', 'NN'),
#      ('and', 'CC'),
#      ('Dick', 'NNP'),
#      ('decides', 'VBZ'),
#      ('to', 'TO'),
#      ('desert', 'VB'),
#      ('.', '.')],
#     [('Scrapper', 'NNP'),
#      ('begs', 'NNS'),
#      ('Kit', 'NNP'),
#      ('to', 'TO'),
#      ('straighten', 'VB'),
#      ('things', 'NNS'),
#      ('out', 'IN'),
#      ('with', 'IN'),
#      ('Biddle', 'NNP'),
#      ('.', '.')],
#     [('To', 'TO'),
#      ('prevent', 'VB'),
#      ('Dick', 'NNP'),
#      ('from', 'IN'),
#      ('deserting', 'VBG'),
#      (',', ','),
#      ('Kit', 'NNP'),
#      ('tells', 'VBZ'),
#      ('him', 'PRP'),
#      ('that', 'IN'),
#      ('she', 'PRP'),
#      ('is', 'VBZ'),
#      ('not', 'RB'),
#      ('in', 'IN'),
#      ('love', 'NN'),
#      ('with', 'IN'),
#      ('him', 'PRP'),
#      (',', ','),
#      ('but', 'CC'),
#      ('was', 'VBD'),
#      ('responding', 'VBG'),
#      ('to', 'TO'),
#      ('a', 'DT'),
#      ('crazy', 'NN'),
#      ('impulse', 'NN'),
#      ('.', '.')],
#     [('Stung', 'NNP'),
#      ('by', 'IN'),
#      ('her', 'PRP$'),
#      ('words', 'NNS'),
#      (',', ','),
#      ('Dick', 'NNP'),
#      ('decides', 'VBZ'),
#      ('to', 'TO'),
#      ('compete', 'VB'),
#      ('with', 'IN'),
#      ('Biddle', 'NNP'),
#      ('as', 'IN'),
#      ('an', 'DT'),
#      ('equal', 'JJ'),
#      ('and', 'CC'),
#      ('applies', 'NNS'),
#      ('for', 'IN'),
#      ('West', 'NNP'),
#      ('Point', 'NNP'),
#      ('.', '.')],
#     [('He', 'PRP'),
#      ('is', 'VBZ'),
#      ('accepted', 'VBN'),
#      ('and', 'CC'),
#      ('does', 'VBZ'),
#      ('very', 'RB'),
#      ('well', 'RB'),
#      (',', ','),
#      ('to', 'TO'),
#      ('Scrapper', 'NNP'),
#      ("'s", 'POS'),
#      ('delight', 'NN'),
#      ('.', '.')],
#     [('In', 'IN'),
#      ('Dick', 'NNP'),
#      ("'s", 'POS'),
#      ('senior', 'JJ'),
#      ('year', 'NN'),
#      (',', ','),
#      ('General', 'NNP'),
#      ('Fitts', 'NNP'),
#      ('is', 'VBZ'),
#      ('appointed', 'VBN'),
#      ('West', 'JJ'),
#      ('Point', 'NNP'),
#      ('superintendent', 'NN'),
#      ('.', '.')],
#     [('While', 'IN'),
#      ('most', 'JJS'),
#      ('of', 'IN'),
#      ('the', 'DT'),
#      ('men', 'NNS'),
#      ('are', 'VBP'),
#      ('infatuated', 'VBN'),
#      ('with', 'IN'),
#      ('Kit', 'NNP'),
#      (',', ','),
#      ('Dick', 'NNP'),
#      ('is', 'VBZ'),
#      ('cold', 'VBN'),
#      ('to', 'TO'),
#      ('her', 'PRP$'),
#      ('.', '.')],
#     [('Consequently', 'RB'),
#      (',', ','),
#      ('he', 'PRP'),
#      ('is', 'VBZ'),
#      ('not', 'RB'),
#      ('very', 'RB'),
#      ('happy', 'JJ'),
#      ('when', 'WRB'),
#      ('the', 'DT'),
#      ('rest', 'NN'),
#      ('of', 'IN'),
#      ('the', 'DT'),
#      ('men', 'NNS'),
#      ('insist', 'VBP'),
#      ('that', 'IN'),
#      ('she', 'PRP'),
#      ('participate', 'VBP'),
#      ('in', 'IN'),
#      ('the', 'DT'),
#      ('traditional', 'JJ'),
#      ('Hundredth', 'NNP'),
#      ('Night', 'NNP'),
#      ('theatrical', 'JJ'),
#      ('performance', 'NN'),
#      ('.', '.')],
#     [('Dick', 'NNP'),
#      ('writes', 'VBZ'),
#      ('a', 'DT'),
#      ('show', 'NN'),
#      ('about', 'IN'),
#      ('a', 'DT'),
#      ('female', 'JJ'),
#      ('general', 'JJ'),
#      ('with', 'IN'),
#      ('a', 'DT'),
#      ('message', 'NN'),
#      ('directed', 'VBN'),
#      ('at', 'IN'),
#      ('Kit', 'NNP'),
#      ('.', '.')],
#     [('After', 'IN'),
#      ('the', 'DT'),
#      ('first', 'JJ'),
#      ('rehearsal', 'NN'),
#      (',', ','),
#      ('Kit', 'NNP'),
#      ('walks', 'NNS'),
#      ('with', 'IN'),
#      ('Dick', 'NNP'),
#      ('on', 'IN'),
#      ('Flirtation', 'NNP'),
#      ('Walk', 'NNP'),
#      ('and', 'CC'),
#      ('tries', 'NNS'),
#      ('to', 'TO'),
#      ('explain', 'VB'),
#      ('why', 'WRB'),
#      ('she', 'PRP'),
#      ('told', 'VBD'),
#      ('him', 'PRP'),
#      ('she', 'PRP'),
#      ('was', 'VBD'),
#      ('not', 'RB'),
#      ('in', 'IN'),
#      ('love', 'NN'),
#      ('with', 'IN'),
#      ('him', 'PRP'),
#      ('.', '.')],
#     [('Dick', 'NNP'),
#      ('is', 'VBZ'),
#      ('too', 'RB'),
#      ('angry', 'JJ'),
#      ('to', 'TO'),
#      ('listen', 'VB'),
#      ('to', 'TO'),
#      ('Kit', 'VB'),
#      ('but', 'CC'),
#      (',', ','),
#      ('during', 'IN'),
#      ('their', 'PRP$'),
#      ('on-stage', 'JJ'),
#      ('love', 'NN'),
#      ('scene', 'NN'),
#      (',', ','),
#      ('kisses', 'NNS'),
#      ('her', 'PRP$'),
#      (',', ','),
#      ('and', 'CC'),
#      ('she', 'PRP'),
#      ('admits', 'VBZ'),
#      ('she', 'PRP'),
#      ('loves', 'VBZ'),
#      ('him', 'PRP'),
#      ('.', '.')],
#     [('When', 'WRB'),
#      ('General', 'NNP'),
#      ('Fitts', 'NNP'),
#      ('announces', 'NNS'),
#      ('Kit', 'NNP'),
#      ("'s", 'POS'),
#      ('engagement', 'NN'),
#      ('to', 'TO'),
#      ('Biddle', 'NNP'),
#      (',', ','),
#      ('Dick', 'NNP'),
#      ('naturally', 'RB'),
#      ('is', 'VBZ'),
#      ('confused', 'VBN'),
#      (',', ','),
#      ('and', 'CC'),
#      ('visits', 'NNS'),
#      ('her', 'PRP$'),
#      ('after', 'IN'),
#      ('lights', 'NNS'),
#      ('out', 'IN'),
#      ('to', 'TO'),
#      ('talk', 'VB'),
#      ('her', 'PRP$'),
#      ('out', 'RP'),
#      ('of', 'IN'),
#      ('marrying', 'NN'),
#      ('Biddle', 'NNP'),
#      ('.', '.')],
#     [('He', 'PRP'),
#      ('is', 'VBZ'),
#      ('caught', 'VBN'),
#      ('and', 'CC'),
#      (',', ','),
#      ('to', 'TO'),
#      ('protect', 'VB'),
#      ('Kit', 'NNP'),
#      ("'s", 'POS'),
#      ('name', 'NN'),
#      (',', ','),
#      ('agrees', 'VBZ'),
#      ('to', 'TO'),
#      ('resign', 'VB'),
#      ('from', 'IN'),
#      ('the', 'DT'),
#      ('Academy', 'NNP'),
#      ('.', '.')],
#     [('Scrapper', 'NNP'),
#      ('arrives', 'VBZ'),
#      ('at', 'IN'),
#      ('the', 'DT'),
#      ('Academy', 'NNP'),
#      ('to', 'TO'),
#      ('see', 'VB'),
#      ('Dick', 'NNP'),
#      ('graduate', 'NN'),
#      ('and', 'CC'),
#      ('is', 'VBZ'),
#      ('disappointed', 'VBN'),
#      ('to', 'TO'),
#      ('learn', 'VB'),
#      ('of', 'IN'),
#      ('Dick', 'NNP'),
#      ("'s", 'POS'),
#      ('resignation', 'NN'),
#      ('.', '.')],
#     [('The', 'DT'),
#      ('day', 'NN'),
#      ('is', 'VBZ'),
#      ('saved', 'VBN'),
#      ('when', 'WRB'),
#      ('Biddle', 'NNP'),
#      ('tells', 'VBZ'),
#      ('Dick', 'NNP'),
#      ('that', 'IN'),
#      ('his', 'PRP$'),
#      ('resignation', 'NN'),
#      ('was', 'VBD'),
#      ('not', 'RB'),
#      ('accepted', 'VBN'),
#      ('and', 'CC'),
#      ('that', 'IN'),
#      ('Kit', 'NNP'),
#      ('returned', 'VBD'),
#      ('his', 'PRP$'),
#      ('ring', 'NN'),
#      ('.', '.')],
#     [('Dick', 'NNP'),
#      ('graduates', 'VBZ'),
#      ('a', 'DT'),
#      ('happy', 'NN'),
#      ('man', 'NN'),
#      ('.', '.')]],
#    'title': 'Flirtation Walk',
#    'venue': 'T',
#    'version': 'I',
#    'year': '1934'}],
#  ['kotpanum chonio.1972',
#   {'id': 53071,
#    'language': None,
#    'num_ratings': '110',
#    'ratings': '5.8',
#    'roles': [{'gender': 'F',
#      'role': 'Mother',
#      'role_pos': [[('mother', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Sun Hui',
#      'role_pos': [[('sun', 'NN'), ('hui', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Old man',
#      'role_pos': [[('old', 'JJ'), ('man', 'NN')]]},
#     {'gender': 'M', 'role': 'Koppun', 'role_pos': [[('koppun', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Chol Yong',
#      'role_pos': [[('chol', 'NN'), ('yong', 'IN')]]},
#     {'gender': 'M',
#      'role': 'Landowner',
#      'role_ne': [Tree('S', [Tree('GPE', [['Landowner', 'NN']])])],
#      'role_pos': [[['Landowner', 'NN']]]}],
#    'summaries_imdb': ['The country is occupied by the Japanese imperialists. Koppun is selling flowers at the market to get some money to buy medicine for her sick mother. Her brother is imprisoned, her father dead and her sister blind.'],
#    'summaries_imdb_ner': [('The', 'O'),
#     ('country', 'O'),
#     ('is', 'O'),
#     ('occupied', 'O'),
#     ('by', 'O'),
#     ('the', 'O'),
#     ('Japanese', 'O'),
#     ('imperialists.', 'O'),
#     ('Koppun', 'O'),
#     ('is', 'O'),
#     ('selling', 'O'),
#     ('flowers', 'O'),
#     ('at', 'O'),
#     ('the', 'O'),
#     ('market', 'O'),
#     ('to', 'O'),
#     ('get', 'O'),
#     ('some', 'O'),
#     ('money', 'O'),
#     ('to', 'O'),
#     ('buy', 'O'),
#     ('medicine', 'O'),
#     ('for', 'O'),
#     ('her', 'O'),
#     ('sick', 'O'),
#     ('mother.', 'O'),
#     ('Her', 'O'),
#     ('brother', 'O'),
#     ('is', 'O'),
#     ('imprisoned,', 'O'),
#     ('her', 'O'),
#     ('father', 'O'),
#     ('dead', 'O'),
#     ('and', 'O'),
#     ('her', 'O'),
#     ('sister', 'O'),
#     ('blind.', 'O')],
#    'summaries_imdb_pos': [[('The', 'DT'),
#      ('country', 'NN'),
#      ('is', 'VBZ'),
#      ('occupied', 'VBN'),
#      ('by', 'IN'),
#      ('the', 'DT'),
#      ('Japanese', 'JJ'),
#      ('imperialists', 'NNS'),
#      ('.', '.')],
#     [('Koppun', 'NNP'),
#      ('is', 'VBZ'),
#      ('selling', 'VBG'),
#      ('flowers', 'NNS'),
#      ('at', 'IN'),
#      ('the', 'DT'),
#      ('market', 'NN'),
#      ('to', 'TO'),
#      ('get', 'VB'),
#      ('some', 'DT'),
#      ('money', 'NN'),
#      ('to', 'TO'),
#      ('buy', 'VB'),
#      ('medicine', 'NN'),
#      ('for', 'IN'),
#      ('her', 'PRP$'),
#      ('sick', 'NN'),
#      ('mother', 'NN'),
#      ('.', '.')],
#     [('Her', 'PRP$'),
#      ('brother', 'NN'),
#      ('is', 'VBZ'),
#      ('imprisoned', 'VBN'),
#      (',', ','),
#      ('her', 'PRP$'),
#      ('father', 'NN'),
#      ('dead', 'NN'),
#      ('and', 'CC'),
#      ('her', 'PRP$'),
#      ('sister', 'NN'),
#      ('blind', 'NN'),
#      ('.', '.')]],
#    'summaries_wikipedia': [],
#    'title': 'Kotpanum chonio',
#    'venue': 'T',
#    'version': 'I',
#    'year': '1972'}]]

# %% [markdown]
# ##Experiment with customized tagger

# %%
tagged = [[('As', 'A'),
     ('Constance', 'A'),
     ('becomes', 'A'),
     ('more', 'A'),
     ('and', 'CC'),
     ('more', 'JJR'),
     ('protective', 'JJ'),
     ('of', 'IN'),
     ('little', 'JJ'),
     ('Angelica', 'NNP'),
     (',', ','),
     ('a', 'DT'),
     ('ghostly', 'RB'),
     ('predator', 'NN'),
     ('begins', 'VBZ'),
     ('to', 'TO'),
     ('make', 'VB'),
     ('its', 'PRP$'),
     ('way', 'NN'),
     ('through', 'IN'),
     ('the', 'DT'),
     ('house', 'NN'),
     ('late', 'RB'),
     ('at', 'IN'),
     ('night', 'NN'),
     ('...', ':'),
     ('ANGELICA', 'NNP'),
     ('is', 'VBZ'),
     ('a', 'DT'),
     ('spellbinding', 'NN'),
     ('ghost', 'NN'),
     ('story', 'NN'),
     ('about', 'IN'),
     ('desire', 'NN'),
     (',', ','),
     ('repression', 'NN'),
     ('and', 'CC'),
     ('its', 'PRP$'),
     ('consequences', 'NNS'),
     ('...', ':')]]

# %%
cp = nltk.RegexpParser('CHUNK: {<A>+<CC>}')
# brown = nltk.corpus.brown
for sent in tagged:
    tree = cp.parse(sent)
    for subtree in tree.subtrees():
        if subtree.label() == 'CHUNK': print(subtree)
# Out:
# (CHUNK As/A Constance/A becomes/A more/A and/CC)

# %% [markdown]
# ###experiment with NLTK Named Entity Recognition (NER)

# %%
# sent = nltk.corpus.treebank.tagged_sents()
sent = [[('Pierre', 'NNP'), ('Vinken', 'NNP'), (',', ','), ('61', 'NNP'), ('Years', 'NNS'), ('Old', 'NNP'), (',', ','), ('Will', 'NNP'), ('Join', 'NNP'), ('The', 'NNP'), ('Board', 'NNP'), ('As', 'NNP'), ('A', 'NNP'), ('Nonexecutive', 'NNP'), ('Director', 'NNP'), ('Nov.', 'NNP'), ('29', 'CD'), ('.', '.')], [('Mr.', 'NNP'), ('Vinken', 'NNP'), ('is', 'NNP'), ('chairman', 'NNP'), ('of', 'NNP'), ('Elsevier', 'NNP'), ('N.V.', 'NNP'), (',', ','), ('the', 'NNP'), ('Dutch', 'NNP'), ('publishing', 'NNP'), ('group', 'NN'), ('.', '.')], [('Rudolph', 'NNP'), ('Agnew', 'NNP'), (',', ','), ('55', 'CD'), ('years', 'NNS'), ('old', 'JJ'), ('and', 'CC'), ('former', 'JJ'), ('chairman', 'NN'), ('of', 'IN'), ('Consolidated', 'NNP'), ('Gold', 'NNP'), ('Fields', 'NNP'), ('PLC', 'NNP'), (',', ','), ('was', 'VBD'), ('named', 'VBN'), ('*-1', '-NONE-'), ('a', 'DT'), ('nonexecutive', 'JJ'), ('director', 'NN'), ('of', 'IN'), ('this', 'DT'), ('British', 'JJ'), ('industrial', 'JJ'), ('conglomerate', 'NN'), ('.', '.')]]
# print(nltk.ne_chunk(sent)
pprint([nltk.ne_chunk(pts) for pts in sent])
# Out:
# [Tree('S', [Tree('PERSON', [('Pierre', 'NNP')]), Tree('ORGANIZATION', [('Vinken', 'NNP')]), (',', ','), ('61', 'NNP'), ('Years', 'NNS'), ('Old', 'NNP'), (',', ','), Tree('PERSON', [('Will', 'NNP'), ('Join', 'NNP'), ('The', 'NNP'), ('Board', 'NNP')]), ('As', 'NNP'), ('A', 'NNP'), ('Nonexecutive', 'NNP'), ('Director', 'NNP'), ('Nov.', 'NNP'), ('29', 'CD'), ('.', '.')]),
#  Tree('S', [Tree('PERSON', [('Mr.', 'NNP')]), Tree('PERSON', [('Vinken', 'NNP')]), ('is', 'NNP'), ('chairman', 'NNP'), ('of', 'NNP'), ('Elsevier', 'NNP'), ('N.V.', 'NNP'), (',', ','), ('the', 'NNP'), Tree('PERSON', [('Dutch', 'NNP')]), ('publishing', 'NNP'), ('group', 'NN'), ('.', '.')]),
#  Tree('S', [Tree('PERSON', [('Rudolph', 'NNP')]), Tree('GPE', [('Agnew', 'NNP')]), (',', ','), ('55', 'CD'), ('years', 'NNS'), ('old', 'JJ'), ('and', 'CC'), ('former', 'JJ'), ('chairman', 'NN'), ('of', 'IN'), Tree('ORGANIZATION', [('Consolidated', 'NNP'), ('Gold', 'NNP'), ('Fields', 'NNP')]), ('PLC', 'NNP'), (',', ','), ('was', 'VBD'), ('named', 'VBN'), ('*-1', '-NONE-'), ('a', 'DT'), ('nonexecutive', 'JJ'), ('director', 'NN'), ('of', 'IN'), ('this', 'DT'), Tree('GPE', [('British', 'JJ')]), ('industrial', 'JJ'), ('conglomerate', 'NN'), ('.', '.')])]

# %%
type(sent)
# Out:
# list

# %% [markdown]
# The function below can potentially be useful.

# %%
# for n in chunked:
#     if isinstance(n, nltk.tree.Tree):               
#         if n.node == 'NP':
#             do_something_with_subtree(n)
#         else:
#             do_something_with_leaf(n)

# %%
print(sent[:3])
# Out:
# [[('Pierre', 'NNP'), ('Vinken', 'NNP'), (',', ','), ('61', 'NNP'), ('Years', 'NNS'), ('Old', 'NNP'), (',', ','), ('Will', 'NNP'), ('Join', 'NNP'), ('The', 'NNP'), ('Board', 'NNP'), ('As', 'NNP'), ('A', 'NNP'), ('Nonexecutive', 'NNP'), ('Director', 'NNP'), ('Nov.', 'NNP'), ('29', 'CD'), ('.', '.')], [('Mr.', 'NNP'), ('Vinken', 'NNP'), ('is', 'NNP'), ('chairman', 'NNP'), ('of', 'NNP'), ('Elsevier', 'NNP'), ('N.V.', 'NNP'), (',', ','), ('the', 'NNP'), ('Dutch', 'NNP'), ('publishing', 'NNP'), ('group', 'NN'), ('.', '.')], [('Rudolph', 'NNP'), ('Agnew', 'NNP'), (',', ','), ('55', 'CD'), ('years', 'NNS'), ('old', 'JJ'), ('and', 'CC'), ('former', 'JJ'), ('chairman', 'NN'), ('of', 'IN'), ('Consolidated', 'NNP'), ('Gold', 'NNP'), ('Fields', 'NNP'), ('PLC', 'NNP'), (',', ','), ('was', 'VBD'), ('named', 'VBN'), ('*-1', '-NONE-'), ('a', 'DT'), ('nonexecutive', 'JJ'), ('director', 'NN'), ('of', 'IN'), ('this', 'DT'), ('British', 'JJ'), ('industrial', 'JJ'), ('conglomerate', 'NN'), ('.', '.')]]

# %% [markdown]
# ###tag summaries with Stanford NER tagger

# %%
from nltk.tag.stanford import StanfordPOSTagger
from nltk.tag.stanford import StanfordNERTagger
#to run StanfordPostTagger and NERTagger, 
#first download these two packages from http://nlp.stanford.edu/software/CRF-NER.shtml 
#I saved the downloaded files in lib/
post = StanfordPOSTagger('lib/stanford-postagger-2014-08-27/models/english-bidirectional-distsim.tagger', 
                         'lib/stanford-postagger-2014-08-27/stanford-postagger.jar', 'utf-8') # doctest: +SKIP
# post.tag('What is the airspeed of an unladen swallow ?'.split()) # doctest: +SKIP
nert = StanfordNERTagger('lib/stanford-ner-2014-08-27/classifiers/english.all.3class.distsim.crf.ser.gz',
                         'lib/stanford-ner-2014-08-27/stanford-ner.jar', 'utf-8')

# %%
# stanford tagger doesn't tag punctuations.
post.tag(sample[1][1]["summaries_imdb"])
# Out:
# [('In', 'IN'),
#  ('Victorian', 'JJ'),
#  ('England,', 'NN'),
#  ('sexual', 'JJ'),
#  ('repression', 'NN'),
#  ('opens', 'VBZ'),
#  ('a', 'DT'),
#  ('rift', 'NN'),
#  ('between', 'IN'),
#  ('young', 'JJ'),
#  ('couple', 'NN'),
#  ('Constance', 'NNP'),
#  ('and', 'CC'),
#  ('Joseph', 'NNP'),
#  ('after', 'IN'),
#  ('the', 'DT'),
#  ('birth', 'NN'),
#  ('of', 'IN'),
#  ('their', 'PRP$'),
#  ('daughter', 'NN'),
#  ('Angelica.', 'NNP'),
#  ('As', 'IN'),
#  ('Constance', 'NNP'),
#  ('becomes', 'VBZ'),
#  ('more', 'RBR'),
#  ('and', 'CC'),
#  ('more', 'RBR'),
#  ('protective', 'JJ'),
#  ('of', 'IN'),
#  ('little', 'JJ'),
#  ('Angelica,', 'NN'),
#  ('a', 'DT'),
#  ('ghostly', 'JJ'),
#  ('predator', 'NN'),
#  ('begins', 'VBZ'),
#  ('to', 'TO'),
#  ('make', 'VB'),
#  ('its', 'PRP$'),
#  ('way', 'NN'),
#  ('through', 'IN'),
#  ('the', 'DT'),
#  ('house', 'NN'),
#  ('late', 'RB'),
#  ('at', 'IN'),
#  ('night...', 'NNP'),
#  ('ANGELICA', 'NNP'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('spellbinding', 'JJ'),
#  ('ghost', 'NN'),
#  ('story', 'NN'),
#  ('about', 'IN'),
#  ('desire,', 'NN'),
#  ('repression', 'NN'),
#  ('and', 'CC'),
#  ('its', 'PRP$'),
#  ('consequences...', 'NN'),
#  ('The', 'DT'),
#  ('new', 'JJ'),
#  ('film', 'NN'),
#  ('by', 'IN'),
#  ('Mitchell', 'NNP'),
#  ('Lichtenstein,', 'NNP'),
#  ('director', 'NN'),
#  ('of', 'IN'),
#  ('HAPPY', 'JJ'),
#  ('TEARS', 'NNS'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('cult', 'NN'),
#  ('favorite', 'JJ'),
#  ('TEETH.', 'NN')]

# %%
nert.tag(sample[1][1]["summaries_imdb"][0].split())
# nert.tag('Rami Eid is studying at Stony Brook University in NY'.split())
# Out:
# [('In', 'O'),
#  ('Victorian', 'O'),
#  ('England,', 'O'),
#  ('sexual', 'O'),
#  ('repression', 'O'),
#  ('opens', 'O'),
#  ('a', 'O'),
#  ('rift', 'O'),
#  ('between', 'O'),
#  ('young', 'O'),
#  ('couple', 'O'),
#  ('Constance', 'PERSON'),
#  ('and', 'O'),
#  ('Joseph', 'PERSON'),
#  ('after', 'O'),
#  ('the', 'O'),
#  ('birth', 'O'),
#  ('of', 'O'),
#  ('their', 'O'),
#  ('daughter', 'O'),
#  ('Angelica.', 'O'),
#  ('As', 'O'),
#  ('Constance', 'PERSON'),
#  ('becomes', 'O'),
#  ('more', 'O'),
#  ('and', 'O'),
#  ('more', 'O'),
#  ('protective', 'O'),
#  ('of', 'O'),
#  ('little', 'O'),
#  ('Angelica,', 'O'),
#  ('a', 'O'),
#  ('ghostly', 'O'),
#  ('predator', 'O'),
#  ('begins', 'O'),
#  ('to', 'O'),
#  ('make', 'O'),
#  ('its', 'O'),
#  ('way', 'O'),
#  ('through', 'O'),
#  ('the', 'O'),
#  ('house', 'O'),
#  ('late', 'O'),
#  ('at', 'O'),
#  ('night...', 'O'),
#  ('ANGELICA', 'O'),
#  ('is', 'O'),
#  ('a', 'O'),
#  ('spellbinding', 'O'),
#  ('ghost', 'O'),
#  ('story', 'O'),
#  ('about', 'O'),
#  ('desire,', 'O'),
#  ('repression', 'O'),
#  ('and', 'O'),
#  ('its', 'O'),
#  ('consequences...', 'O'),
#  ('The', 'O'),
#  ('new', 'O'),
#  ('film', 'O'),
#  ('by', 'O'),
#  ('Mitchell', 'PERSON'),
#  ('Lichtenstein,', 'O'),
#  ('director', 'O'),
#  ('of', 'O'),
#  ('HAPPY', 'O'),
#  ('TEARS', 'O'),
#  ('and', 'O'),
#  ('the', 'O'),
#  ('cult', 'O'),
#  ('favorite', 'O'),
#  ('TEETH.', 'O')]

# %%
# nert.tag(sample[2][1]["roles"][0]["role"].split())
nert.tag('Michael With Red Hair From London'.split())
# Out:
# [('Michael', 'PERSON'),
#  ('With', 'O'),
#  ('Red', 'O'),
#  ('Hair', 'O'),
#  ('From', 'O'),
#  ('London', 'LOCATION')]

# %%
# NERT doesn't tag pos tagged sentences...
sample2 = [('In', 'IN'),
 ('Victorian', 'JJ'),
 ('England,', 'NN'),
 ('sexual', 'JJ'),
 ('repression', 'NN'),
 ('opens', 'VBZ'),
 ('a', 'DT'),
 ('rift', 'NN'),
 ('between', 'IN'),
 ('young', 'JJ'),
 ('couple', 'NN'),
 ('Constance', 'NNP'),
 ('and', 'CC'),
 ('Joseph', 'NNP'),
 ('after', 'IN'),
 ('the', 'DT'),
 ('birth', 'NN'),
 ('of', 'IN'),
 ('their', 'PRP$'),
 ('daughter', 'NN'),
 ('Angelica', 'NNP'),
 (".", '.')]
nert.tag(sample2[0])
# Out:
# [('In', 'O'), ('IN', 'O')]

# %%
nert.tag(sample[1][1]["summaries_imdb"][0].split())
# nert.tag('Rami Eid is studying at Stony Brook University in NY'.split())
# Out:
# [('In', 'O'),
#  ('Victorian', 'O'),
#  ('England,', 'O'),
#  ('sexual', 'O'),
#  ('repression', 'O'),
#  ('opens', 'O'),
#  ('a', 'O'),
#  ('rift', 'O'),
#  ('between', 'O'),
#  ('young', 'O'),
#  ('couple', 'O'),
#  ('Constance', 'PERSON'),
#  ('and', 'O'),
#  ('Joseph', 'PERSON'),
#  ('after', 'O'),
#  ('the', 'O'),
#  ('birth', 'O'),
#  ('of', 'O'),
#  ('their', 'O'),
#  ('daughter', 'O'),
#  ('Angelica.', 'O'),
#  ('As', 'O'),
#  ('Constance', 'PERSON'),
#  ('becomes', 'O'),
#  ('more', 'O'),
#  ('and', 'O'),
#  ('more', 'O'),
#  ('protective', 'O'),
#  ('of', 'O'),
#  ('little', 'O'),
#  ('Angelica,', 'O'),
#  ('a', 'O'),
#  ('ghostly', 'O'),
#  ('predator', 'O'),
#  ('begins', 'O'),
#  ('to', 'O'),
#  ('make', 'O'),
#  ('its', 'O'),
#  ('way', 'O'),
#  ('through', 'O'),
#  ('the', 'O'),
#  ('house', 'O'),
#  ('late', 'O'),
#  ('at', 'O'),
#  ('night...', 'O'),
#  ('ANGELICA', 'O'),
#  ('is', 'O'),
#  ('a', 'O'),
#  ('spellbinding', 'O'),
#  ('ghost', 'O'),
#  ('story', 'O'),
#  ('about', 'O'),
#  ('desire,', 'O'),
#  ('repression', 'O'),
#  ('and', 'O'),
#  ('its', 'O'),
#  ('consequences...', 'O'),
#  ('The', 'O'),
#  ('new', 'O'),
#  ('film', 'O'),
#  ('by', 'O'),
#  ('Mitchell', 'PERSON'),
#  ('Lichtenstein,', 'O'),
#  ('director', 'O'),
#  ('of', 'O'),
#  ('HAPPY', 'O'),
#  ('TEARS', 'O'),
#  ('and', 'O'),
#  ('the', 'O'),
#  ('cult', 'O'),
#  ('favorite', 'O'),
#  ('TEETH.', 'O')]

# %%
# Punctuations 
nert.tag('Rami Eid is studying at Stony Brook University in NY , and he is a good boy . he does a lot of nice things Jasmine thought so too she lives in california'.split())
# Out:
# [('Rami', 'PERSON'),
#  ('Eid', 'PERSON'),
#  ('is', 'O'),
#  ('studying', 'O'),
#  ('at', 'O'),
#  ('Stony', 'ORGANIZATION'),
#  ('Brook', 'ORGANIZATION'),
#  ('University', 'ORGANIZATION'),
#  ('in', 'ORGANIZATION'),
#  ('NY', 'ORGANIZATION'),
#  (',', 'O'),
#  ('and', 'O'),
#  ('he', 'O'),
#  ('is', 'O'),
#  ('a', 'O'),
#  ('good', 'O'),
#  ('boy', 'O'),
#  ('.', 'O'),
#  ('he', 'O'),
#  ('does', 'O'),
#  ('a', 'O'),
#  ('lot', 'O'),
#  ('of', 'O'),
#  ('nice', 'O'),
#  ('things', 'O'),
#  ('Jasmine', 'PERSON'),
#  ('thought', 'O'),
#  ('so', 'O'),
#  ('too', 'O'),
#  ('she', 'O'),
#  ('lives', 'O'),
#  ('in', 'O'),
#  ('california', 'LOCATION')]

# %% [markdown]
# ###experiment with chunker

# %%
# Import the RegexpParser
from nltk.chunk import RegexpParser

# Define custom tagged entities - group NE's together 

def chunker_rules(values):
    # Define  custom grammar (modified to be a valid regex).
    grammar = r'''
        PERSON:
                {<PERSON><O><PERSON>+}
                {<PERSON>+}
            '''
    cp = nltk.RegexpParser(grammar) # Create an instance of your custom parser.
    return cp.parse(values)         # Parse!

def entity_chunker(tagged_docs):
    chunks = []
#     for doc in tagged_docs:
    tree = chunker_rules(tagged_docs)
    for subtree in tree.subtrees():
#             if (subtree.node == 'WIDOW'):
        leaflist = [leaf[0] for leaf in subtree.leaves()]
        chunks.append(' '.join(leaflist))
    return chunks

# %%
# TODO: need to put a " " before punctuations in order for the word before the punctuation
# to be properly detected.
example = [('Rami', 'PERSON'),
 ('Eid', 'PERSON'),
 ('is', 'O'),
 ('studying', 'O'),
 ('at', 'O'),
 ('Stony', 'ORGANIZATION'),
 ('Brook', 'ORGANIZATION'),
 ('University', 'ORGANIZATION'),
 ('in', 'ORGANIZATION'),
 ('NY', 'ORGANIZATION'),
 (',', 'O'),
 ('and', 'O'),
 ('he', 'O'),
 ('is', 'O'),
 ('a', 'O'),
 ('good', 'O'),
 ('boy', 'O'),
 ('.', 'O')]

# %%
entity_chunker(example)
# Out:
# ['Rami Eid is studying at Stony Brook University in NY , and he is a good boy .',
#  'Rami Eid']

# %%
###can chunker define alternative grammers??"
cp = nltk.RegexpParser('PERSON:{<PERSON>+}')
# brown = nltk.corpus.brown
# for sent in tagged:
tree = cp.parse(example)
for subtree in tree.subtrees():
    if subtree.label() == 'PERSON': print(subtree)
# Out:
# (PERSON Rami/PERSON Eid/PERSON)

# %%
print(tree)
# Out:
# (S
#   (PERSON Rami/PERSON Eid/PERSON)
#   is/O
#   studying/O
#   at/O
#   Stony/ORGANIZATION
#   Brook/ORGANIZATION
#   University/ORGANIZATION
#   in/ORGANIZATION
#   NY/ORGANIZATION
#   ,/O
#   and/O
#   he/O
#   is/O
#   a/O
#   good/O
#   boy/O
#   ./O)

# %% [markdown]
# ###Replace more /O with names from the SSN database.

# %% [markdown]
# ###Search for name in the roles bag of words

# %%
sample
# Out:
# [['city after dark.1980',
#   {'id': 19412,
#    'language': None,
#    'num_ratings': '94',
#    'ratings': '7.5',
#    'roles': [{'gender': 'F',
#      'role': 'Vanessa',
#      'role_pos': [[('vanessa', 'NN')]]},
#     {'gender': 'F', 'role': 'Nelie', 'role_pos': [[('nelie', 'NN')]]},
#     {'gender': 'F', 'role': 'Kano', 'role_pos': [[('kano', 'NN')]]},
#     {'gender': 'F', 'role': 'Cora', 'role_pos': [[('cora', 'NN')]]},
#     {'gender': 'F', 'role': 'Bea', 'role_pos': [[('bea', 'NN')]]},
#     {'gender': 'F', 'role': 'Gaying', 'role_pos': [[('gaying', 'VBG')]]},
#     {'gender': 'F', 'role': 'Adelina', 'role_pos': [[('adelina', 'NN')]]},
#     {'gender': 'F',
#      'role': "Vanessa's Mother",
#      'role_pos': [[('vanessa', 'NN'), ("'s", 'POS'), ('mother', 'NN')]]},
#     {'gender': 'F', 'role': 'Virgie', 'role_pos': [[('virgie', 'NN')]]},
#     {'gender': 'F', 'role': 'Baby', 'role_pos': [[('baby', 'NN')]]},
#     {'gender': 'F', 'role': 'Marichu', 'role_pos': [[('marichu', 'NN')]]},
#     {'gender': 'M',
#      'role': "Adelina's Client",
#      'role_pos': [[('adelina', 'NN'), ("'s", 'POS'), ('client', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Manay Sharon',
#      'role_pos': [[('manay', 'NN'), ('sharon', 'VBD')]]},
#     {'gender': 'M', 'role': 'Recruiter', 'role_pos': [[('recruiter', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Mall couple',
#      'role_pos': [[('mall', 'NN'), ('couple', 'NN')]]},
#     {'gender': 'M', 'role': 'Alex', 'role_pos': [[('alex', 'NN')]]},
#     {'gender': 'M', 'role': 'Pebrero', 'role_pos': [[('pebrero', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Greggy Williams',
#      'role_pos': [[('greggy', 'NN'), ('williams', 'NNS')]]},
#     {'gender': 'M',
#      'role': "Virgir's Husband",
#      'role_ne': [Tree('S', [Tree('GPE', [['Virgir', 'PRP$']]), ["'s", 'POS'], Tree('ORGANIZATION', [['Husband', 'NN']])])],
#      'role_pos': [[['Virgir', 'PRP$'], ["'s", 'POS'], ['Husband', 'NN']]]}],
#    'summaries_imdb': ["The hidden nightlife of ordinary people living in Manila unveils. Lovers and families' conflicts are radically pitted against each other as they live in the night streets rampant with drugs and prostitution. The outstanding narrative explicitly unravels the various characters and episodes. This landmark film of Ishmael Bernal depicts the darkness of city life so vividly that it was once prohibited to use the word 'Manila' on its title."],
#    'summaries_imdb_ner': [('The', 'O'),
#     ('hidden', 'O'),
#     ('nightlife', 'O'),
#     ('of', 'O'),
#     ('ordinary', 'O'),
#     ('people', 'O'),
#     ('living', 'O'),
#     ('in', 'O'),
#     ('Manila', 'LOCATION'),
#     ('unveils.', 'O'),
#     ('Lovers', 'O'),
#     ('and', 'O'),
#     ("families'", 'O'),
#     ('conflicts', 'O'),
#     ('are', 'O'),
#     ('radically', 'O'),
#     ('pitted', 'O'),
#     ('against', 'O'),
#     ('each', 'O'),
#     ('other', 'O'),
#     ('as', 'O'),
#     ('they', 'O'),
#     ('live', 'O'),
#     ('in', 'O'),
#     ('the', 'O'),
#     ('night', 'O'),
#     ('streets', 'O'),
#     ('rampant', 'O'),
#     ('with', 'O'),
#     ('drugs', 'O'),
#     ('and', 'O'),
#     ('prostitution.', 'O'),
#     ('The', 'O'),
#     ('outstanding', 'O'),
#     ('narrative', 'O'),
#     ('explicitly', 'O'),
#     ('unravels', 'O'),
#     ('the', 'O'),
#     ('various', 'O'),
#     ('characters', 'O'),
#     ('and', 'O'),
#     ('episodes.', 'O'),
#     ('This', 'O'),
#     ('landmark', 'O'),
#     ('film', 'O'),
#     ('of', 'O'),
#     ('Ishmael', 'PERSON'),
#     ('Bernal', 'PERSON'),
#     ('depicts', 'O'),
#     ('the', 'O'),
#     ('darkness', 'O'),
#     ('of', 'O'),
#     ('city', 'O'),
#     ('life', 'O'),
#     ('so', 'O'),
#     ('vividly', 'O'),
#     ('that', 'O'),
#     ('it', 'O'),
#     ('was', 'O'),
#     ('once', 'O'),
#     ('prohibited', 'O'),
#     ('to', 'O'),
#     ('use', 'O'),
#     ('the', 'O'),
#     ('word', 'O'),
#     ("'Manila'", 'O'),
#     ('on', 'O'),
#     ('its', 'O'),
#     ('title.', 'O')],
#    'summaries_imdb_pos': [[('The', 'DT'),
#      ('hidden', 'VBN'),
#      ('nightlife', 'NN'),
#      ('of', 'IN'),
#      ('ordinary', 'JJ'),
#      ('people', 'NNS'),
#      ('living', 'VBG'),
#      ('in', 'IN'),
#      ('Manila', 'NNP'),
#      ('unveils', 'NNS'),
#      ('.', '.')],
#     [('Lovers', 'NNS'),
#      ('and', 'CC'),
#      ('families', 'NNS'),
#      ("'", 'POS'),
#      ('conflicts', 'NNS'),
#      ('are', 'VBP'),
#      ('radically', 'RB'),
#      ('pitted', 'VBN'),
#      ('against', 'IN'),
#      ('each', 'DT'),
#      ('other', 'JJ'),
#      ('as', 'IN'),
#      ('they', 'PRP'),
#      ('live', 'VBP'),
#      ('in', 'IN'),
#      ('the', 'DT'),
#      ('night', 'NN'),
#      ('streets', 'NNS'),
#      ('rampant', 'VBP'),
#      ('with', 'IN'),
#      ('drugs', 'NNS'),
#      ('and', 'CC'),
#      ('prostitution', 'NN'),
#      ('.', '.')],
#     [('The', 'DT'),
#      ('outstanding', 'JJ'),
#      ('narrative', 'JJ'),
#      ('explicitly', 'RB'),
#      ('unravels', 'VBZ'),
#      ('the', 'DT'),
#      ('various', 'JJ'),
#      ('characters', 'NNS'),
#      ('and', 'CC'),
#      ('episodes', 'NNS'),
#      ('.', '.')],
#     [('This', 'DT'),
#      ('landmark', 'NN'),
#      ('film', 'NN'),
#      ('of', 'IN'),
#      ('Ishmael', 'NNP'),
#      ('Bernal', 'NNP'),
#      ('depicts', 'VBZ'),
#      ('the', 'DT'),
#      ('darkness', 'NN'),
#      ('of', 'IN'),
#      ('city', 'NN'),
#      ('life', 'NN'),
#      ('so', 'RB'),
#      ('vividly', 'RB'),
#      ('that', 'IN'),
#      ('it', 'PRP'),
#      ('was', 'VBD'),
#      ('once', 'RB'),
#      ('prohibited', 'VBN'),
#      ('to', 'TO'),
#      ('use', 'VB'),
#      ('the', 'DT'),
#      ('word', 'NN'),
#      ("'Manila", 'NN'),
#      ("'", "''"),
#      ('on', 'IN'),
#      ('its', 'PRP$'),
#      ('title', 'NN'),
#      ('.', '.')]],
#    'summaries_wikipedia': [],
#    'title': 'City After Dark',
#    'venue': 'T',
#    'version': 'I',
#    'year': '1980'}],
#  ['angelica.2015',
#   {'id': 7054,
#    'language': None,
#    'num_ratings': '60',
#    'ratings': '5.8',
#    'roles': [{'gender': 'F',
#      'role': 'Midwife',
#      'role_pos': [[('midwife', 'NN')]]},
#     {'gender': 'F', 'role': 'Angelica', 'role_pos': [[('angelica', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Snobby Woman',
#      'role_pos': [[('snobby', 'NN'), ('woman', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Lady in Park',
#      'role_pos': [[('lady', 'NN'), ('in', 'IN'), ('park', 'NN')]]},
#     {'gender': 'F', 'role': 'Nora', 'role_pos': [[('nora', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Beggar girl',
#      'role_pos': [[('beggar', 'NN'), ('girl', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Young Angelica',
#      'role_pos': [[('young', 'JJ'), ('angelica', 'NN')]]},
#     {'gender': 'F', 'role': 'Constance', 'role_pos': [[('constance', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Anne Montague',
#      'role_pos': [[('anne', 'NN'), ('montague', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Older Constance',
#      'role_pos': [[('older', 'JJR'), ('constance', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Spirit Girl',
#      'role_pos': [[('spirit', 'NN'), ('girl', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Unnamed Scientist',
#      'role_pos': [[('unnamed', 'VBD'), ('scientist', 'VBN')]]},
#     {'gender': 'M',
#      'role': 'Unnamed Scientist',
#      'role_pos': [[('unnamed', 'VBD'), ('scientist', 'VBN')]]},
#     {'gender': 'M',
#      'role': 'Medical Student',
#      'role_pos': [[('medical', 'JJ'), ('student', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Mr. Pendleton',
#      'role_pos': [[('mr.', 'NNP'), ('pendleton', 'VBD')]]},
#     {'gender': 'M',
#      'role': 'Spirit Boy',
#      'role_pos': [[('spirit', 'NN'), ('boy', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Unnamed Scientist',
#      'role_pos': [[('unnamed', 'VBD'), ('scientist', 'VBN')]]},
#     {'gender': 'M',
#      'role': 'Bookseller',
#      'role_pos': [[('bookseller', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Dr. Joseph Barton',
#      'role_ne': [Tree('S', [['Dr.', 'NNP'], ['Joseph', 'VBP'], Tree('PERSON', [['Barton', 'NN']])])],
#      'role_pos': [[['Dr.', 'NNP'], ['Joseph', 'VBP'], ['Barton', 'NN']]]}],
#    'summaries_imdb': ['In Victorian England, sexual repression opens a rift between young couple Constance and Joseph after the birth of their daughter Angelica. As Constance becomes more and more protective of little Angelica, a ghostly predator begins to make its way through the house late at night... ANGELICA is a spellbinding ghost story about desire, repression and its consequences... The new film by Mitchell Lichtenstein, director of HAPPY TEARS and the cult favorite TEETH.'],
#    'summaries_imdb_ner': [('In', 'O'),
#     ('Victorian', 'O'),
#     ('England,', 'O'),
#     ('sexual', 'O'),
#     ('repression', 'O'),
#     ('opens', 'O'),
#     ('a', 'O'),
#     ('rift', 'O'),
#     ('between', 'O'),
#     ('young', 'O'),
#     ('couple', 'O'),
#     ('Constance', 'PERSON'),
#     ('and', 'O'),
#     ('Joseph', 'PERSON'),
#     ('after', 'O'),
#     ('the', 'O'),
#     ('birth', 'O'),
#     ('of', 'O'),
#     ('their', 'O'),
#     ('daughter', 'O'),
#     ('Angelica.', 'O'),
#     ('As', 'O'),
#     ('Constance', 'PERSON'),
#     ('becomes', 'O'),
#     ('more', 'O'),
#     ('and', 'O'),
#     ('more', 'O'),
#     ('protective', 'O'),
#     ('of', 'O'),
#     ('little', 'O'),
#     ('Angelica,', 'O'),
#     ('a', 'O'),
#     ('ghostly', 'O'),
#     ('predator', 'O'),
#     ('begins', 'O'),
#     ('to', 'O'),
#     ('make', 'O'),
#     ('its', 'O'),
#     ('way', 'O'),
#     ('through', 'O'),
#     ('the', 'O'),
#     ('house', 'O'),
#     ('late', 'O'),
#     ('at', 'O'),
#     ('night...', 'O'),
#     ('ANGELICA', 'O'),
#     ('is', 'O'),
#     ('a', 'O'),
#     ('spellbinding', 'O'),
#     ('ghost', 'O'),
#     ('story', 'O'),
#     ('about', 'O'),
#     ('desire,', 'O'),
#     ('repression', 'O'),
#     ('and', 'O'),
#     ('its', 'O'),
#     ('consequences...', 'O'),
#     ('The', 'O'),
#     ('new', 'O'),
#     ('film', 'O'),
#     ('by', 'O'),
#     ('Mitchell', 'PERSON'),
#     ('Lichtenstein,', 'O'),
#     ('director', 'O'),
#     ('of', 'O'),
#     ('HAPPY', 'O'),
#     ('TEARS', 'O'),
#     ('and', 'O'),
#     ('the', 'O'),
#     ('cult', 'O'),
#     ('favorite', 'O'),
#     ('TEETH.', 'O')],
#    'summaries_imdb_pos': [[('In', 'IN'),
#      ('Victorian', 'NNP'),
#      ('England', 'NNP'),
#      (',', ','),
#      ('sexual', 'JJ'),
#      ('repression', 'NN'),
#      ('opens', 'NNS'),
#      ('a', 'DT'),
#      ('rift', 'NN'),
#      ('between', 'IN'),
#      ('young', 'JJ'),
#      ('couple', 'NN'),
#      ('Constance', 'NNP'),
#      ('and', 'CC'),
#      ('Joseph', 'NNP'),
#      ('after', 'IN'),
#      ('the', 'DT'),
#      ('birth', 'NN'),
#      ('of', 'IN'),
#      ('their', 'PRP$'),
#      ('daughter', 'NN'),
#      ('Angelica', 'NNP'),
#      ('.', '.')],
#     [('As', 'IN'),
#      ('Constance', 'NNP'),
#      ('becomes', 'VBZ'),
#      ('more', 'JJR'),
#      ('and', 'CC'),
#      ('more', 'JJR'),
#      ('protective', 'JJ'),
#      ('of', 'IN'),
#      ('little', 'JJ'),
#      ('Angelica', 'NNP'),
#      (',', ','),
#      ('a', 'DT'),
#      ('ghostly', 'RB'),
#      ('predator', 'NN'),
#      ('begins', 'VBZ'),
#      ('to', 'TO'),
#      ('make', 'VB'),
#      ('its', 'PRP$'),
#      ('way', 'NN'),
#      ('through', 'IN'),
#      ('the', 'DT'),
#      ('house', 'NN'),
#      ('late', 'RB'),
#      ('at', 'IN'),
#      ('night', 'NN'),
#      ('...', ':'),
#      ('ANGELICA', 'NNP'),
#      ('is', 'VBZ'),
#      ('a', 'DT'),
#      ('spellbinding', 'NN'),
#      ('ghost', 'NN'),
#      ('story', 'NN'),
#      ('about', 'IN'),
#      ('desire', 'NN'),
#      (',', ','),
#      ('repression', 'NN'),
#      ('and', 'CC'),
#      ('its', 'PRP$'),
#      ('consequences', 'NNS'),
#      ('...', ':')],
#     [('The', 'DT'),
#      ('new', 'JJ'),
#      ('film', 'NN'),
#      ('by', 'IN'),
#      ('Mitchell', 'NNP'),
#      ('Lichtenstein', 'NNP'),
#      (',', ','),
#      ('director', 'NN'),
#      ('of', 'IN'),
#      ('HAPPY', 'NNP'),
#      ('TEARS', 'NNP'),
#      ('and', 'CC'),
#      ('the', 'DT'),
#      ('cult', 'NN'),
#      ('favorite', 'JJ'),
#      ('TEETH', 'NNP'),
#      ('.', '.')]],
#    'summaries_wikipedia': [],
#    'title': 'Angelica',
#    'venue': 'T',
#    'version': 'I',
#    'year': '2015'}],
#  ['bedazzled.2000',
#   {'id': 11106,
#    'language': None,
#    'num_ratings': '78401',
#    'ratings': '5.9',
#    'roles': [{'gender': 'F',
#      'role': 'DV8 Clubgoer',
#      'role_pos': [[('dv8', 'NNP'), ('clubgoer', 'NN')]]},
#     {'gender': 'F',
#      'role': 'DV8 Clubgoer',
#      'role_pos': [[('dv8', 'NNP'), ('clubgoer', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Cheerleader/Dancer',
#      'role_pos': [[('cheerleader/dancer', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Cheerleader/Dancer',
#      'role_pos': [[('cheerleader/dancer', 'NN')]]},
#     {'gender': 'F',
#      'role': 'DV8 Waitress',
#      'role_pos': [[('dv8', 'NNP'), ('waitress', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Cheerleader/Dancer',
#      'role_pos': [[('cheerleader/dancer', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Churchgoer',
#      'role_pos': [[('churchgoer', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Cheerleader/Dancer',
#      'role_pos': [[('cheerleader/dancer', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Caged Go-Go Dancer',
#      'role_pos': [[('caged', 'VBD'), ('go-go', 'JJ'), ('dancer', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Tech Support Advisor',
#      'role_pos': [[('tech', 'NN'), ('support', 'NN'), ('advisor', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Play Actor',
#      'role_pos': [[('play', 'NN'), ('actor', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Cheerleader/Dancer',
#      'role_pos': [[('cheerleader/dancer', 'NN')]]},
#     {'gender': 'F',
#      'role': 'The Devil',
#      'role_pos': [[('the', 'DT'), ('devil', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Fly Girl',
#      'role_pos': [[('fly', 'RB'), ('girl', 'VBP')]]},
#     {'gender': 'F',
#      'role': 'DV8 Clubgoer',
#      'role_pos': [[('dv8', 'NNP'), ('clubgoer', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Cheerleader/Dancer',
#      'role_pos': [[('cheerleader/dancer', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Alison/Nicole',
#      'role_pos': [[('alison/nicole', 'JJ')]]},
#     {'gender': 'F',
#      'role': 'DV8 Clubgoer',
#      'role_pos': [[('dv8', 'NNP'), ('clubgoer', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Fly Girl',
#      'role_pos': [[('fly', 'RB'), ('girl', 'VBP')]]},
#     {'gender': 'F',
#      'role': 'Cheerleader/Dancer',
#      'role_pos': [[('cheerleader/dancer', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Cheerleader/Dancer',
#      'role_pos': [[('cheerleader/dancer', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Carol/Penthouse Hostess',
#      'role_pos': [[('carol/penthouse', 'NN'), ('hostess', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Girl at Beer Garden',
#      'role_pos': [[('girl', 'NN'),
#        ('at', 'IN'),
#        ('beer', 'NN'),
#        ('garden', 'NNS')]]},
#     {'gender': 'F',
#      'role': 'Girl at Beer Garden',
#      'role_pos': [[('girl', 'NN'),
#        ('at', 'IN'),
#        ('beer', 'NN'),
#        ('garden', 'NNS')]]},
#     {'gender': 'F',
#      'role': 'Fly Girl',
#      'role_pos': [[('fly', 'RB'), ('girl', 'VBP')]]},
#     {'gender': 'F',
#      'role': 'Restaurant Customer',
#      'role_pos': [[('restaurant', 'NN'), ('customer', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Cheerleader/Dancer',
#      'role_pos': [[('cheerleader/dancer', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Tech Support Advisor',
#      'role_pos': [[('tech', 'NN'), ('support', 'NN'), ('advisor', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Tech Support Advisor',
#      'role_pos': [[('tech', 'NN'), ('support', 'NN'), ('advisor', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Demonic Waitress',
#      'role_pos': [[('demonic', 'JJ'), ('waitress', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Cheerleader/Dancer',
#      'role_pos': [[('cheerleader/dancer', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Bob/Roberto/Beach Jock/Sportscaster/Lincoln Aide',
#      'role_pos': [[('bob/roberto/beach', 'JJ'),
#        ('jock/sportscaster/lincoln', 'JJ'),
#        ('aide', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Tech Support Advisor',
#      'role_pos': [[('tech', 'NN'), ('support', 'NN'), ('advisor', 'NN')]]},
#     {'gender': 'M',
#      'role': "McDonald's Employee",
#      'role_pos': [[('mcdonald', 'NN'), ("'s", 'POS'), ('employee', 'NN')]]},
#     {'gender': 'M',
#      'role': 'DV8 Clubgoer',
#      'role_pos': [[('dv8', 'NNP'), ('clubgoer', 'NN')]]},
#     {'gender': 'M', 'role': 'Prisoner', 'role_pos': [[('prisoner', 'NN')]]},
#     {'gender': 'M',
#      'role': "Elliot's Cellmate",
#      'role_pos': [[('elliot', 'NN'), ("'s", 'POS'), ('cellmate', 'NN')]]},
#     {'gender': 'M',
#      'role': 'San Francisco Pedestrian',
#      'role_pos': [[('san', 'NN'),
#        ('francisco', 'VBD'),
#        ('pedestrian', 'JJ')]]},
#     {'gender': 'M',
#      'role': 'Tech Support Advisor',
#      'role_pos': [[('tech', 'NN'), ('support', 'NN'), ('advisor', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Cornell, Peter (II)',
#      'role_pos': [[('cornell', 'NN'),
#        (',', ','),
#        ('peter', 'NN'),
#        ('(', ':'),
#        ('ii', 'NN'),
#        (')', ':')]]},
#     {'gender': 'M',
#      'role': 'Businessman #1',
#      'role_pos': [[('businessman', 'NN'), ('#', '#'), ('1', 'CD')]]},
#     {'gender': 'M',
#      'role': 'Desk Sergeant',
#      'role_pos': [[('desk', 'NN'), ('sergeant', 'VBD')]]},
#     {'gender': 'M', 'role': 'Priest', 'role_pos': [[('priest', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Ivan the Russian',
#      'role_pos': [[('ivan', 'NN'), ('the', 'DT'), ('russian', 'JJ')]]},
#     {'gender': 'M',
#      'role': 'John Wilkes Booth',
#      'role_pos': [[('john', 'NN'), ('wilkes', 'VBZ'), ('booth', 'NN')]]},
#     {'gender': 'M', 'role': 'Elliot', 'role_pos': [[('elliot', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Man in Park',
#      'role_pos': [[('man', 'NN'), ('in', 'IN'), ('park', 'NN')]]},
#     {'gender': 'M', 'role': 'Mover', 'role_pos': [[('mover', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Play Actor',
#      'role_pos': [[('play', 'NN'), ('actor', 'NN')]]},
#     {'gender': 'M', 'role': 'Pablito', 'role_pos': [[('pablito', 'IN')]]},
#     {'gender': 'M',
#      'role': 'Diablos Fan #4',
#      'role_pos': [[('diablos', 'NNS'),
#        ('fan', 'VBP'),
#        ('#', '#'),
#        ('4', 'CD')]]},
#     {'gender': 'M',
#      'role': 'DV8 Clubgoer',
#      'role_pos': [[('dv8', 'NNP'), ('clubgoer', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Diablos Fan #3',
#      'role_pos': [[('diablos', 'NNS'),
#        ('fan', 'VBP'),
#        ('#', '#'),
#        ('3', 'CD')]]},
#     {'gender': 'M',
#      'role': 'Jerry/Alejandro/Beach Jock/Sportscaster/Lance',
#      'role_pos': [[('jerry/alejandro/beach', 'JJ'),
#        ('jock/sportscaster/lance', 'NN')]]},
#     {'gender': 'M',
#      'role': 'NBA Player #10',
#      'role_pos': [[('nba', 'NN'),
#        ('player', 'NN'),
#        ('#', '#'),
#        ('10', 'CD')]]},
#     {'gender': 'M',
#      'role': 'Dan/Esteban/Beach Jock/Sportscaster/African Party Guest',
#      'role_pos': [[('dan/esteban/beach', 'JJ'),
#        ('jock/sportscaster/african', 'JJ'),
#        ('party', 'NN'),
#        ('guest', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Club DV8 Patron',
#      'role_pos': [[('club', 'NN'), ('dv8', 'NNP'), ('patron', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Synedyne Supervisor',
#      'role_pos': [[('synedyne', 'NN'), ('supervisor', 'NN')]]},
#     {'gender': 'M', 'role': 'Eduardo', 'role_pos': [[('eduardo', 'NN')]]},
#     {'gender': 'M', 'role': 'Raoul', 'role_pos': [[('raoul', 'NN')]]},
#     {'gender': 'M',
#      'role': 'DV8 Bouncer',
#      'role_pos': [[('dv8', 'NNP'), ('bouncer', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Russian Drug Dealer',
#      'role_pos': [[('russian', 'JJ'), ('drug', 'NN'), ('dealer', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Club DV8 Dancer',
#      'role_pos': [[('club', 'NN'), ('dv8', 'NNP'), ('dancer', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Raging Fan',
#      'role_pos': [[('raging', 'VBG'), ('fan', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Office worker',
#      'role_pos': [[('office', 'NN'), ('worker', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Play Actor',
#      'role_pos': [[('play', 'NN'), ('actor', 'NN')]]},
#     {'gender': 'M', 'role': 'Extra', 'role_pos': [[('extra', 'NN')]]},
#     {'gender': 'M', 'role': 'Surfer', 'role_pos': [[('surfer', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Club Dancer',
#      'role_pos': [[('club', 'NN'), ('dancer', 'NN')]]},
#     {'gender': 'M',
#      'role': 'NBA Player #30',
#      'role_pos': [[('nba', 'NN'),
#        ('player', 'NN'),
#        ('#', '#'),
#        ('30', 'CD')]]},
#     {'gender': 'M',
#      'role': "Devil's Lawyer",
#      'role_pos': [[('devil', 'NN'), ("'s", 'POS'), ('lawyer', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Play Actor',
#      'role_pos': [[('play', 'NN'), ('actor', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Club DV8 Goth',
#      'role_pos': [[('club', 'NN'), ('dv8', 'NNP'), ('goth', 'NN')]]},
#     {'gender': 'M', 'role': 'Usher', 'role_pos': [[('usher', 'PRP$')]]},
#     {'gender': 'M',
#      'role': 'Elegant Devil',
#      'role_pos': [[('elegant', 'NN'), ('devil', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Police Officer',
#      'role_pos': [[('police', 'NN'), ('officer', 'NN')]]},
#     {'gender': 'M',
#      'role': 'DV8 Clubgoer',
#      'role_pos': [[('dv8', 'NNP'), ('clubgoer', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Cafe Patron at the Car Crash',
#      'role_pos': [[('cafe', 'NN'),
#        ('patron', 'VBD'),
#        ('at', 'IN'),
#        ('the', 'DT'),
#        ('car', 'NN'),
#        ('crash', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Drug Factory Foreman',
#      'role_pos': [[('drug', 'NN'), ('factory', 'NN'), ('foreman', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Columbian Soldier',
#      'role_pos': [[('columbian', 'JJ'), ('soldier', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Security Guard (Rock Fantasy)',
#      'role_pos': [[('security', 'NN'),
#        ('guard', 'VBD'),
#        ('(', 'CD'),
#        ('rock', 'NN'),
#        ('fantasy', 'NN'),
#        (')', ':')]]},
#     {'gender': 'M',
#      'role': 'Biggest Devil',
#      'role_ne': [Tree('S', [Tree('GPE', [['Biggest', 'JJS']]), Tree('ORGANIZATION', [['Devil', 'NN']])])],
#      'role_pos': [[['Biggest', 'JJS'], ['Devil', 'NN']]]}],
#    'summaries_imdb': ['Elliot Richardson, a socially awkward IT worker, is given seven wishes to get the girl of his dreams when he meets up with a very seductive Satan. The catch: his soul. Some of his wishes include being a 7 foot basketball star, a wealthy, powerful man, and a sensitive caring guy. But, as could be expected, the Devil must put her own little twist on each his fantasies. Elliot Richards, a socially incompetent technical advisor working at a call-center, has had a crush on Alison Gardner for nearly four years. One evening, which already started particularly bad for Elliot, she ditches him. Elliot wishes for her to be in his life with all his heart - and is heard. An incredibly beautiful young lady addresses Elliot, and after introducing herself as the Devil, Lucifer, the Princess of Darkness, she offers him a deal: Seven wishes for him, his Soul for her. Quickly, Elliot is convinced and accepts. But every wish he gets fulfilled has massive disadvantages as well, and soon Elliot wants to get out of the contract. The only thing that matters to him now is being able to take his chances by himself.'],
#    'summaries_imdb_ner': [('Elliot', 'PERSON'),
#     ('Richardson,', 'O'),
#     ('a', 'O'),
#     ('socially', 'O'),
#     ('awkward', 'O'),
#     ('IT', 'O'),
#     ('worker,', 'O'),
#     ('is', 'O'),
#     ('given', 'O'),
#     ('seven', 'O'),
#     ('wishes', 'O'),
#     ('to', 'O'),
#     ('get', 'O'),
#     ('the', 'O'),
#     ('girl', 'O'),
#     ('of', 'O'),
#     ('his', 'O'),
#     ('dreams', 'O'),
#     ('when', 'O'),
#     ('he', 'O'),
#     ('meets', 'O'),
#     ('up', 'O'),
#     ('with', 'O'),
#     ('a', 'O'),
#     ('very', 'O'),
#     ('seductive', 'O'),
#     ('Satan.', 'O'),
#     ('The', 'O'),
#     ('catch:', 'O'),
#     ('his', 'O'),
#     ('soul.', 'O'),
#     ('Some', 'O'),
#     ('of', 'O'),
#     ('his', 'O'),
#     ('wishes', 'O'),
#     ('include', 'O'),
#     ('being', 'O'),
#     ('a', 'O'),
#     ('7', 'O'),
#     ('foot', 'O'),
#     ('basketball', 'O'),
#     ('star,', 'O'),
#     ('a', 'O'),
#     ('wealthy,', 'O'),
#     ('powerful', 'O'),
#     ('man,', 'O'),
#     ('and', 'O'),
#     ('a', 'O'),
#     ('sensitive', 'O'),
#     ('caring', 'O'),
#     ('guy.', 'O'),
#     ('But,', 'O'),
#     ('as', 'O'),
#     ('could', 'O'),
#     ('be', 'O'),
#     ('expected,', 'O'),
#     ('the', 'O'),
#     ('Devil', 'O'),
#     ('must', 'O'),
#     ('put', 'O'),
#     ('her', 'O'),
#     ('own', 'O'),
#     ('little', 'O'),
#     ('twist', 'O'),
#     ('on', 'O'),
#     ('each', 'O'),
#     ('his', 'O'),
#     ('fantasies.', 'O'),
#     ('Elliot', 'PERSON'),
#     ('Richards,', 'O'),
#     ('a', 'O'),
#     ('socially', 'O'),
#     ('incompetent', 'O'),
#     ('technical', 'O'),
#     ('advisor', 'O'),
#     ('working', 'O'),
#     ('at', 'O'),
#     ('a', 'O'),
#     ('call-center,', 'O'),
#     ('has', 'O'),
#     ('had', 'O'),
#     ('a', 'O'),
#     ('crush', 'O'),
#     ('on', 'O'),
#     ('Alison', 'PERSON'),
#     ('Gardner', 'PERSON'),
#     ('for', 'O'),
#     ('nearly', 'O'),
#     ('four', 'O'),
#     ('years.', 'O'),
#     ('One', 'O'),
#     ('evening,', 'O'),
#     ('which', 'O'),
#     ('already', 'O'),
#     ('started', 'O'),
#     ('particularly', 'O'),
#     ('bad', 'O'),
#     ('for', 'O'),
#     ('Elliot,', 'O'),
#     ('she', 'O'),
#     ('ditches', 'O'),
#     ('him.', 'O'),
#     ('Elliot', 'PERSON'),
#     ('wishes', 'O'),
#     ('for', 'O'),
#     ('her', 'O'),
#     ('to', 'O'),
#     ('be', 'O'),
#     ('in', 'O'),
#     ('his', 'O'),
#     ('life', 'O'),
#     ('with', 'O'),
#     ('all', 'O'),
#     ('his', 'O'),
#     ('heart', 'O'),
#     ('-', 'O'),
#     ('and', 'O'),
#     ('is', 'O'),
#     ('heard.', 'O'),
#     ('An', 'O'),
#     ('incredibly', 'O'),
#     ('beautiful', 'O'),
#     ('young', 'O'),
#     ('lady', 'O'),
#     ('addresses', 'O'),
#     ('Elliot,', 'O'),
#     ('and', 'O'),
#     ('after', 'O'),
#     ('introducing', 'O'),
#     ('herself', 'O'),
#     ('as', 'O'),
#     ('the', 'O'),
#     ('Devil,', 'O'),
#     ('Lucifer,', 'O'),
#     ('the', 'O'),
#     ('Princess', 'O'),
#     ('of', 'O'),
#     ('Darkness,', 'O'),
#     ('she', 'O'),
#     ('offers', 'O'),
#     ('him', 'O'),
#     ('a', 'O'),
#     ('deal:', 'O'),
#     ('Seven', 'O'),
#     ('wishes', 'O'),
#     ('for', 'O'),
#     ('him,', 'O'),
#     ('his', 'O'),
#     ('Soul', 'O'),
#     ('for', 'O'),
#     ('her.', 'O'),
#     ('Quickly,', 'O'),
#     ('Elliot', 'PERSON'),
#     ('is', 'O'),
#     ('convinced', 'O'),
#     ('and', 'O'),
#     ('accepts.', 'O'),
#     ('But', 'O'),
#     ('every', 'O'),
#     ('wish', 'O'),
#     ('he', 'O'),
#     ('gets', 'O'),
#     ('fulfilled', 'O'),
#     ('has', 'O'),
#     ('massive', 'O'),
#     ('disadvantages', 'O'),
#     ('as', 'O'),
#     ('well,', 'O'),
#     ('and', 'O'),
#     ('soon', 'O'),
#     ('Elliot', 'PERSON'),
#     ('wants', 'O'),
#     ('to', 'O'),
#     ('get', 'O'),
#     ('out', 'O'),
#     ('of', 'O'),
#     ('the', 'O'),
#     ('contract.', 'O'),
#     ('The', 'O'),
#     ('only', 'O'),
#     ('thing', 'O'),
#     ('that', 'O'),
#     ('matters', 'O'),
#     ('to', 'O'),
#     ('him', 'O'),
#     ('now', 'O'),
#     ('is', 'O'),
#     ('being', 'O'),
#     ('able', 'O'),
#     ('to', 'O'),
#     ('take', 'O'),
#     ('his', 'O'),
#     ('chances', 'O'),
#     ('by', 'O'),
#     ('himself.', 'O')],
#    'summaries_imdb_pos': [[('Elliot', 'NNP'),
#      ('Richardson', 'NNP'),
#      (',', ','),
#      ('a', 'DT'),
#      ('socially', 'RB'),
#      ('awkward', 'JJ'),
#      ('IT', 'PRP'),
#      ('worker', 'NN'),
#      (',', ','),
#      ('is', 'VBZ'),
#      ('given', 'VBN'),
#      ('seven', 'CD'),
#      ('wishes', 'NNS'),
#      ('to', 'TO'),
#      ('get', 'VB'),
#      ('the', 'DT'),
#      ('girl', 'NN'),
#      ('of', 'IN'),
#      ('his', 'PRP$'),
#      ('dreams', 'NNS'),
#      ('when', 'WRB'),
#      ('he', 'PRP'),
#      ('meets', 'VBZ'),
#      ('up', 'RP'),
#      ('with', 'IN'),
#      ('a', 'DT'),
#      ('very', 'RB'),
#      ('seductive', 'JJ'),
#      ('Satan', 'NNP'),
#      ('.', '.')],
#     [('The', 'DT'),
#      ('catch', 'NN'),
#      (':', ':'),
#      ('his', 'PRP$'),
#      ('soul', 'NN'),
#      ('.', '.')],
#     [('Some', 'DT'),
#      ('of', 'IN'),
#      ('his', 'PRP$'),
#      ('wishes', 'NNS'),
#      ('include', 'VBP'),
#      ('being', 'VBG'),
#      ('a', 'DT'),
#      ('7', 'CD'),
#      ('foot', 'NN'),
#      ('basketball', 'NN'),
#      ('star', 'NN'),
#      (',', ','),
#      ('a', 'DT'),
#      ('wealthy', 'JJ'),
#      (',', ','),
#      ('powerful', 'JJ'),
#      ('man', 'NN'),
#      (',', ','),
#      ('and', 'CC'),
#      ('a', 'DT'),
#      ('sensitive', 'JJ'),
#      ('caring', 'NN'),
#      ('guy', 'NN'),
#      ('.', '.')],
#     [('But', 'CC'),
#      (',', ','),
#      ('as', 'IN'),
#      ('could', 'MD'),
#      ('be', 'VB'),
#      ('expected', 'VBN'),
#      (',', ','),
#      ('the', 'DT'),
#      ('Devil', 'NNP'),
#      ('must', 'MD'),
#      ('put', 'VB'),
#      ('her', 'PRP'),
#      ('own', 'VB'),
#      ('little', 'JJ'),
#      ('twist', 'NN'),
#      ('on', 'IN'),
#      ('each', 'DT'),
#      ('his', 'PRP$'),
#      ('fantasies', 'NNS'),
#      ('.', '.')],
#     [('Elliot', 'NNP'),
#      ('Richards', 'NNP'),
#      (',', ','),
#      ('a', 'DT'),
#      ('socially', 'RB'),
#      ('incompetent', 'JJ'),
#      ('technical', 'JJ'),
#      ('advisor', 'NN'),
#      ('working', 'VBG'),
#      ('at', 'IN'),
#      ('a', 'DT'),
#      ('call-center', 'JJ'),
#      (',', ','),
#      ('has', 'VBZ'),
#      ('had', 'VBN'),
#      ('a', 'DT'),
#      ('crush', 'JJ'),
#      ('on', 'IN'),
#      ('Alison', 'NNP'),
#      ('Gardner', 'NNP'),
#      ('for', 'IN'),
#      ('nearly', 'RB'),
#      ('four', 'CD'),
#      ('years', 'NNS'),
#      ('.', '.')],
#     [('One', 'CD'),
#      ('evening', 'NN'),
#      (',', ','),
#      ('which', 'WDT'),
#      ('already', 'RB'),
#      ('started', 'VBD'),
#      ('particularly', 'RB'),
#      ('bad', 'JJ'),
#      ('for', 'IN'),
#      ('Elliot', 'NNP'),
#      (',', ','),
#      ('she', 'PRP'),
#      ('ditches', 'VBZ'),
#      ('him', 'PRP'),
#      ('.', '.')],
#     [('Elliot', 'NNP'),
#      ('wishes', 'VBZ'),
#      ('for', 'IN'),
#      ('her', 'PRP$'),
#      ('to', 'TO'),
#      ('be', 'VB'),
#      ('in', 'IN'),
#      ('his', 'PRP$'),
#      ('life', 'NN'),
#      ('with', 'IN'),
#      ('all', 'DT'),
#      ('his', 'PRP$'),
#      ('heart', 'NN'),
#      ('-', ':'),
#      ('and', 'CC'),
#      ('is', 'VBZ'),
#      ('heard', 'VBN'),
#      ('.', '.')],
#     [('An', 'DT'),
#      ('incredibly', 'RB'),
#      ('beautiful', 'JJ'),
#      ('young', 'JJ'),
#      ('lady', 'NN'),
#      ('addresses', 'NNS'),
#      ('Elliot', 'NNP'),
#      (',', ','),
#      ('and', 'CC'),
#      ('after', 'IN'),
#      ('introducing', 'VBG'),
#      ('herself', 'PRP'),
#      ('as', 'IN'),
#      ('the', 'DT'),
#      ('Devil', 'NNP'),
#      (',', ','),
#      ('Lucifer', 'NNP'),
#      (',', ','),
#      ('the', 'DT'),
#      ('Princess', 'NNP'),
#      ('of', 'IN'),
#      ('Darkness', 'NNP'),
#      (',', ','),
#      ('she', 'PRP'),
#      ('offers', 'VBZ'),
#      ('him', 'PRP'),
#      ('a', 'DT'),
#      ('deal', 'NN'),
#      (':', ':'),
#      ('Seven', 'CD'),
#      ('wishes', 'NNS'),
#      ('for', 'IN'),
#      ('him', 'PRP'),
#      (',', ','),
#      ('his', 'PRP$'),
#      ('Soul', 'NNP'),
#      ('for', 'IN'),
#      ('her', 'PRP'),
#      ('.', '.')],
#     [('Quickly', 'RB'),
#      (',', ','),
#      ('Elliot', 'NNP'),
#      ('is', 'VBZ'),
#      ('convinced', 'VBN'),
#      ('and', 'CC'),
#      ('accepts', 'NNS'),
#      ('.', '.')],
#     [('But', 'CC'),
#      ('every', 'DT'),
#      ('wish', 'NN'),
#      ('he', 'PRP'),
#      ('gets', 'VBZ'),
#      ('fulfilled', 'VBN'),
#      ('has', 'VBZ'),
#      ('massive', 'JJ'),
#      ('disadvantages', 'NNS'),
#      ('as', 'IN'),
#      ('well', 'RB'),
#      (',', ','),
#      ('and', 'CC'),
#      ('soon', 'RB'),
#      ('Elliot', 'NNP'),
#      ('wants', 'VBZ'),
#      ('to', 'TO'),
#      ('get', 'VB'),
#      ('out', 'IN'),
#      ('of', 'IN'),
#      ('the', 'DT'),
#      ('contract', 'NN'),
#      ('.', '.')],
#     [('The', 'DT'),
#      ('only', 'JJ'),
#      ('thing', 'NN'),
#      ('that', 'WDT'),
#      ('matters', 'NNS'),
#      ('to', 'TO'),
#      ('him', 'PRP'),
#      ('now', 'RB'),
#      ('is', 'VBZ'),
#      ('being', 'VBG'),
#      ('able', 'JJ'),
#      ('to', 'TO'),
#      ('take', 'VB'),
#      ('his', 'PRP$'),
#      ('chances', 'NNS'),
#      ('by', 'IN'),
#      ('himself', 'PRP'),
#      ('.', '.')]],
#    'summaries_wikipedia': ['Elliot Richards  is a geeky, over-zealous man working a dead-end technical support job in a San Francisco computer company. He has no friends and his co-workers use him, knowing he will do anything for acceptance. He has a crush on his colleague, Alison Gardner , but lacks the courage to ask her out. After Elliot is again ditched by his co-workers, at a bar while trying to talk to Alison, he says to himself that he would give anything for Alison to be with him. Satan , in the form of a beautiful woman, overhears him and offers to give Elliot seven wishes in return for his soul. As a test, he wishes for a Big Mac and Coke. Satan takes him to McDonald\'s and places the order. Elliot has to pay for it, because, "there ain\'t no such thing as a free lunch." After taking Elliot to her office, based at a nightclub in Oakland, Satan convinces Elliot to sign her contract, and delivers further wishes. Each wish has Elliot living them out with Alison and his co-workers in surrogate roles. However, he doesn\'t know that Satan will always spoil his wishes by adding something he doesn\'t want. Elliot wishes to be rich and powerful, with Alison as his wife. Satan makes him a Colombian drug lord whose wife despises him and cheats on him with Raul, his co-worker, who is secretly planning to get rid of Elliot and take his position and property. Soon after there is a firefight between his and Raul\'s people where Elliot "dies". When he returns to the real world, Satan points out that he never wished for Alison to love him. Secondly, Elliot wishes to be emotionally sensitive so he will understand the needs and desires of women. Satan makes him so sensitive that he spends most of his time crying over how beautiful the world is, and constantly asks Alison, his girlfriend of "three magical weeks," whether he has hurt her or if she needs anything. Alison says she has had enough of it and wants to be with a man who is strong and shallow. She then leaves Elliot for a man who is strong, rude and completely different from the romantic and emotionally sensitive Elliot. Elliot then wishes to be a superstar athlete who would be a woman magnet. Satan makes him a clich̩-spewing NBA star, but also gives him a small penis and a low IQ, which causes Alison, a sports reporter, to lose interest in him shortly after they meet. He then wishes to be intelligent, witty and well-endowed. Satan grants this by making him a famous writer whom Alison falls in love with at a cocktail party. When they arrive at Elliot\'s home to make love it is revealed that Elliot is gay and living with a flamboyant male partner. Lastly, Elliot wishes to be President of the United States to try to improve the world and get Alison to take him seriously. Satan makes him Abraham Lincoln at Ford\'s Theatre on the night of his assassination which he nearly avoids. After each wish is renounced, Elliot meets with Satan and she blames him for not being specific enough. Eventually he returns to work, thinking about what he should do with the last two wishes. Satan appears on the computer screen, pointing out that on their first meeting he asked for a Big Mac and Coke, although she had stated that it was a test wish and granted it before Elliot signed the contract. Elliot loses his patience and storms out of his office. Elliot visits a church looking for God\'s help, where he briefly confesses to a priest who seems sympathetic. However, after being asked whether he thinks asking Satan for a Big Mac and Coke counts as a wish, the priest, believing he is drunk, has Elliot arrested. The sergeant books him, and Satan, dressed as a police officer, throws him in a cell, telling him that she does like him, and it would not hurt to have her as a friend. Elliot\'s cellmate  tells him that he cannot possibly sell his soul as it belongs to God, and although Satan may try to confuse him, in the end he will realise who he truly is, and what his purpose is. Elliot questions the man as ...
#    'summaries_wikipedia_ner': [('Elliot', 'PERSON'),
#     ('Richards', 'PERSON'),
#     ('is', 'O'),
#     ('a', 'O'),
#     ('geeky,', 'O'),
#     ('over-zealous', 'O'),
#     ('man', 'O'),
#     ('working', 'O'),
#     ('a', 'O'),
#     ('dead-end', 'O'),
#     ('technical', 'O'),
#     ('support', 'O'),
#     ('job', 'O'),
#     ('in', 'O'),
#     ('a', 'O'),
#     ('San', 'LOCATION'),
#     ('Francisco', 'LOCATION'),
#     ('computer', 'O'),
#     ('company.', 'O'),
#     ('He', 'O'),
#     ('has', 'O'),
#     ('no', 'O'),
#     ('friends', 'O'),
#     ('and', 'O'),
#     ('his', 'O'),
#     ('co-workers', 'O'),
#     ('use', 'O'),
#     ('him,', 'O'),
#     ('knowing', 'O'),
#     ('he', 'O'),
#     ('will', 'O'),
#     ('do', 'O'),
#     ('anything', 'O'),
#     ('for', 'O'),
#     ('acceptance.', 'O'),
#     ('He', 'O'),
#     ('has', 'O'),
#     ('a', 'O'),
#     ('crush', 'O'),
#     ('on', 'O'),
#     ('his', 'O'),
#     ('colleague,', 'O'),
#     ('Alison', 'PERSON'),
#     ('Gardner', 'PERSON'),
#     (',', 'O'),
#     ('but', 'O'),
#     ('lacks', 'O'),
#     ('the', 'O'),
#     ('courage', 'O'),
#     ('to', 'O'),
#     ('ask', 'O'),
#     ('her', 'O'),
#     ('out.', 'O'),
#     ('After', 'O'),
#     ('Elliot', 'PERSON'),
#     ('is', 'O'),
#     ('again', 'O'),
#     ('ditched', 'O'),
#     ('by', 'O'),
#     ('his', 'O'),
#     ('co-workers,', 'O'),
#     ('at', 'O'),
#     ('a', 'O'),
#     ('bar', 'O'),
#     ('while', 'O'),
#     ('trying', 'O'),
#     ('to', 'O'),
#     ('talk', 'O'),
#     ('to', 'O'),
#     ('Alison,', 'O'),
#     ('he', 'O'),
#     ('says', 'O'),
#     ('to', 'O'),
#     ('himself', 'O'),
#     ('that', 'O'),
#     ('he', 'O'),
#     ('would', 'O'),
#     ('give', 'O'),
#     ('anything', 'O'),
#     ('for', 'O'),
#     ('Alison', 'PERSON'),
#     ('to', 'O'),
#     ('be', 'O'),
#     ('with', 'O'),
#     ('him.', 'O'),
#     ('Satan', 'O'),
#     (',', 'O'),
#     ('in', 'O'),
#     ('the', 'O'),
#     ('form', 'O'),
#     ('of', 'O'),
#     ('a', 'O'),
#     ('beautiful', 'O'),
#     ('woman,', 'O'),
#     ('overhears', 'O'),
#     ('him', 'O'),
#     ('and', 'O'),
#     ('offers', 'O'),
#     ('to', 'O'),
#     ('give', 'O'),
#     ('Elliot', 'PERSON'),
#     ('seven', 'O'),
#     ('wishes', 'O'),
#     ('in', 'O'),
#     ('return', 'O'),
#     ('for', 'O'),
#     ('his', 'O'),
#     ('soul.', 'O'),
#     ('As', 'O'),
#     ('a', 'O'),
#     ('test,', 'O'),
#     ('he', 'O'),
#     ('wishes', 'O'),
#     ('for', 'O'),
#     ('a', 'O'),
#     ('Big', 'O'),
#     ('Mac', 'O'),
#     ('and', 'O'),
#     ('Coke.', 'O'),
#     ('Satan', 'PERSON'),
#     ('takes', 'O'),
#     ('him', 'O'),
#     ('to', 'O'),
#     ("McDonald's", 'O'),
#     ('and', 'O'),
#     ('places', 'O'),
#     ('the', 'O'),
#     ('order.', 'O'),
#     ('Elliot', 'PERSON'),
#     ('has', 'O'),
#     ('to', 'O'),
#     ('pay', 'O'),
#     ('for', 'O'),
#     ('it,', 'O'),
#     ('because,', 'O'),
#     ('"there', 'O'),
#     ("ain't", 'O'),
#     ('no', 'O'),
#     ('such', 'O'),
#     ('thing', 'O'),
#     ('as', 'O'),
#     ('a', 'O'),
#     ('free', 'O'),
#     ('lunch."', 'O'),
#     ('After', 'O'),
#     ('taking', 'O'),
#     ('Elliot', 'PERSON'),
#     ('to', 'O'),
#     ('her', 'O'),
#     ('office,', 'O'),
#     ('based', 'O'),
#     ('at', 'O'),
#     ('a', 'O'),
#     ('nightclub', 'O'),
#     ('in', 'O'),
#     ('Oakland,', 'O'),
#     ('Satan', 'O'),
#     ('convinces', 'O'),
#     ('Elliot', 'PERSON'),
#     ('to', 'O'),
#     ('sign', 'O'),
#     ('her', 'O'),
#     ('contract,', 'O'),
#     ('and', 'O'),
#     ('delivers', 'O'),
#     ('further', 'O'),
#     ('wishes.', 'O'),
#     ('Each', 'O'),
#     ('wish', 'O'),
#     ('has', 'O'),
#     ('Elliot', 'PERSON'),
#     ('living', 'O'),
#     ('them', 'O'),
#     ('out', 'O'),
#     ('with', 'O'),
#     ('Alison', 'PERSON'),
#     ('and', 'O'),
#     ('his', 'O'),
#     ('co-workers', 'O'),
#     ('in', 'O'),
#     ('surrogate', 'O'),
#     ('roles.', 'O'),
#     ('However,', 'O'),
#     ('he', 'O'),
#     ("doesn't", 'O'),
#     ('know', 'O'),
#     ('that', 'O'),
#     ('Satan', 'O'),
#     ('will', 'O'),
#     ('always', 'O'),
#     ('spoil', 'O'),
#     ('his', 'O'),
#     ('wishes', 'O'),
#     ('by', 'O'),
#     ('adding', 'O'),
#     ('something', 'O'),
#     ('he', 'O'),
#     ("doesn't", 'O'),
#     ('want.', 'O'),
#     ('Elliot', 'PERSON'),
#     ('wishes', 'O'),
#     ('to', 'O'),
#     ('be', 'O'),
#     ('rich', 'O'),
#     ('and', 'O'),
#     ('powerful,', 'O'),
#     ('with', 'O'),
#     ('Alison', 'PERSON'),
#     ('as', 'O'),
#     ('his', 'O'),
#     ('wife.', 'O'),
#     ('Satan', 'O'),
#     ('makes', 'O'),
#     ('him', 'O'),
#     ('a', 'O'),
#     ('Colombian', 'O'),
#     ('drug', 'O'),
#     ('lord', 'O'),
#     ('whose', 'O'),
#     ('wife', 'O'),
#     ('despises', 'O'),
#     ('him', 'O'),
#     ('and', 'O'),
#     ('cheats', 'O'),
#     ('on', 'O'),
#     ('him', 'O'),
#     ('with', 'O'),
#     ('Raul,', 'O'),
#     ('his', 'O'),
#     ('co-worker,', 'O'),
#     ('who', 'O'),
#     ('is', 'O'),
#     ('secretly', 'O'),
#     ('planning', 'O'),
#     ('to', 'O'),
#     ('get', 'O'),
#     ('rid', 'O'),
#     ('of', 'O'),
#     ('Elliot', 'PERSON'),
#     ('and', 'O'),
#     ('take', 'O'),
#     ('his', 'O'),
#     ('position', 'O'),
#     ('and', 'O'),
#     ('property.', 'O'),
#     ('Soon', 'O'),
#     ('after', 'O'),
#     ('there', 'O'),
#     ('is', 'O'),
#     ('a', 'O'),
#     ('firefight', 'O'),
#     ('between', 'O'),
#     ('his', 'O'),
#     ('and', 'O'),
#     ("Raul's", 'O'),
#     ('people', 'O'),
#     ('where', 'O'),
#     ('Elliot', 'PERSON'),
#     ('"dies".', 'O'),
#     ('When', 'O'),
#     ('he', 'O'),
#     ('returns', 'O'),
#     ('to', 'O'),
#     ('the', 'O'),
#     ('real', 'O'),
#     ('world,', 'O'),
#     ('Satan', 'O'),
#     ('points', 'O'),
#     ('out', 'O'),
#     ('that', 'O'),
#     ('he', 'O'),
#     ('never', 'O'),
#     ('wished', 'O'),
#     ('for', 'O'),
#     ('Alison', 'PERSON'),
#     ('to', 'O'),
#     ('love', 'O'),
#     ('him.', 'O'),
#     ('Secondly,', 'O'),
#     ('Elliot', 'PERSON'),
#     ('wishes', 'O'),
#     ('to', 'O'),
#     ('be', 'O'),
#     ('emotionally', 'O'),
#     ('sensitive', 'O'),
#     ('so', 'O'),
#     ('he', 'O'),
#     ('will', 'O'),
#     ('understand', 'O'),
#     ('the', 'O'),
#     ('needs', 'O'),
#     ('and', 'O'),
#     ('desires', 'O'),
#     ('of', 'O'),
#     ('women.', 'O'),
#     ('Satan', 'O'),
#     ('makes', 'O'),
#     ('him', 'O'),
#     ('so', 'O'),
#     ('sensitive', 'O'),
#     ('that', 'O'),
#     ('he', 'O'),
#     ('spends', 'O'),
#     ('most', 'O'),
#     ('of', 'O'),
#     ('his', 'O'),
#     ('time', 'O'),
#     ('crying', 'O'),
#     ('over', 'O'),
#     ('how', 'O'),
#     ('beautiful', 'O'),
#     ('the', 'O'),
#     ('world', 'O'),
#     ('is,', 'O'),
#     ('and', 'O'),
#     ('constantly', 'O'),
#     ('asks', 'O'),
#     ('Alison,', 'O'),
#     ('his', 'O'),
#     ('girlfriend', 'O'),
#     ('of', 'O'),
#     ('"three', 'O'),
#     ('magical', 'O'),
#     ('weeks,"', 'O'),
#     ('whether', 'O'),
#     ('he', 'O'),
#     ('has', 'O'),
#     ('hurt', 'O'),
#     ('her', 'O'),
#     ('or', 'O'),
#     ('if', 'O'),
#     ('she', 'O'),
#     ('needs', 'O'),
#     ('anything.', 'O'),
#     ('Alison', 'PERSON'),
#     ('says', 'O'),
#     ('she', 'O'),
#     ('has', 'O'),
#     ('had', 'O'),
#     ('enough', 'O'),
#     ('of', 'O'),
#     ('it', 'O'),
#     ('and', 'O'),
#     ('wants', 'O'),
#     ('to', 'O'),
#     ('be', 'O'),
#     ('with', 'O'),
#     ('a', 'O'),
#     ('man', 'O'),
#     ('who', 'O'),
#     ('is', 'O'),
#     ('strong', 'O'),
#     ('and', 'O'),
#     ('shallow.', 'O'),
#     ('She', 'O'),
#     ('then', 'O'),
#     ('leaves', 'O'),
#     ('Elliot', 'PERSON'),
#     ('for', 'O'),
#     ('a', 'O'),
#     ('man', 'O'),
#     ('who', 'O'),
#     ('is', 'O'),
#     ('strong,', 'O'),
#     ('rude', 'O'),
#     ('and', 'O'),
#     ('completely', 'O'),
#     ('different', 'O'),
#     ('from', 'O'),
#     ('the', 'O'),
#     ('romantic', 'O'),
#     ('and', 'O'),
#     ('emotionally', 'O'),
#     ('sensitive', 'O'),
#     ('Elliot.', 'O'),
#     ('Elliot', 'PERSON'),
#     ('then', 'O'),
#     ('wishes', 'O'),
#     ('to', 'O'),
#     ('be', 'O'),
#     ('a', 'O'),
#     ('superstar', 'O'),
#     ('athlete', 'O'),
#     ('who', 'O'),
#     ('would', 'O'),
#     ('be', 'O'),
#     ('a', 'O'),
#     ('woman', 'O'),
#     ('magnet.', 'O'),
#     ('Satan', 'O'),
#     ('makes', 'O'),
#     ('him', 'O'),
#     ('a', 'O'),
#     ('clich̩-spewing', 'O'),
#     ('NBA', 'O'),
#     ('star,', 'O'),
#     ('but', 'O'),
#     ('also', 'O'),
#     ('gives', 'O'),
#     ('him', 'O'),
#     ('a', 'O'),
#     ('small', 'O'),
#     ('penis', 'O'),
#     ('and', 'O'),
#     ('a', 'O'),
#     ('low', 'O'),
#     ('IQ,', 'O'),
#     ('which', 'O'),
#     ('causes', 'O'),
#     ('Alison,', 'O'),
#     ('a', 'O'),
#     ('sports', 'O'),
#     ('reporter,', 'O'),
#     ('to', 'O'),
#     ('lose', 'O'),
#     ('interest', 'O'),
#     ('in', 'O'),
#     ('him', 'O'),
#     ('shortly', 'O'),
#     ('after', 'O'),
#     ('they', 'O'),
#     ('meet.', 'O'),
#     ('He', 'O'),
#     ('then', 'O'),
#     ('wishes', 'O'),
#     ('to', 'O'),
#     ('be', 'O'),
#     ('intelligent,', 'O'),
#     ('witty', 'O'),
#     ('and', 'O'),
#     ('well-endowed.', 'O'),
#     ('Satan', 'O'),
#     ('grants', 'O'),
#     ('this', 'O'),
#     ('by', 'O'),
#     ('making', 'O'),
#     ('him', 'O'),
#     ('a', 'O'),
#     ('famous', 'O'),
#     ('writer', 'O'),
#     ('whom', 'O'),
#     ('Alison', 'PERSON'),
#     ('falls', 'O'),
#     ('in', 'O'),
#     ('love', 'O'),
#     ('with', 'O'),
#     ('at', 'O'),
#     ('a', 'O'),
#     ('cocktail', 'O'),
#     ('party.', 'O'),
#     ('When', 'O'),
#     ('they', 'O'),
#     ('arrive', 'O'),
#     ('at', 'O'),
#     ("Elliot's", 'O'),
#     ('home', 'O'),
#     ('to', 'O'),
#     ('make', 'O'),
#     ('love', 'O'),
#     ('it', 'O'),
#     ('is', 'O'),
#     ('revealed', 'O'),
#     ('that', 'O'),
#     ('Elliot', 'PERSON'),
#     ('is', 'O'),
#     ('gay', 'O'),
#     ('and', 'O'),
#     ('living', 'O'),
#     ('with', 'O'),
#     ('a', 'O'),
#     ('flamboyant', 'O'),
#     ('male', 'O'),
#     ('partner.', 'O'),
#     ('Lastly,', 'O'),
#     ('Elliot', 'PERSON'),
#     ('wishes', 'O'),
#     ('to', 'O'),
#     ('be', 'O'),
#     ('President', 'O'),
#     ('of', 'O'),
#     ('the', 'O'),
#     ('United', 'LOCATION'),
#     ('States', 'LOCATION'),
#     ('to', 'O'),
#     ('try', 'O'),
#     ('to', 'O'),
#     ('improve', 'O'),
#     ('the', 'O'),
#     ('world', 'O'),
#     ('and', 'O'),
#     ('get', 'O'),
#     ('Alison', 'PERSON'),
#     ('to', 'O'),
#     ('take', 'O'),
#     ('him', 'O'),
#     ('seriously.', 'O'),
#     ('Satan', 'O'),
#     ('makes', 'O'),
#     ('him', 'O'),
#     ('Abraham', 'PERSON'),
#     ('Lincoln', 'PERSON'),
#     ('at', 'O'),
#     ("Ford's", 'O'),
#     ('Theatre', 'O'),
#     ('on', 'O'),
#     ('the', 'O'),
#     ('night', 'O'),
#     ('of', 'O'),
#     ('his', 'O'),
#     ('assassination', 'O'),
#     ('which', 'O'),
#     ('he', 'O'),
#     ('nearly', 'O'),
#     ('avoids.', 'O'),
#     ('After', 'O'),
#     ('each', 'O'),
#     ('wish', 'O'),
#     ('is', 'O'),
#     ('renounced,', 'O'),
#     ('Elliot', 'PERSON'),
#     ('meets', 'O'),
#     ('with', 'O'),
#     ('Satan', 'PERSON'),
#     ('and', 'O'),
#     ('she', 'O'),
#     ('blames', 'O'),
#     ('him', 'O'),
#     ('for', 'O'),
#     ('not', 'O'),
#     ('being', 'O'),
#     ('specific', 'O'),
#     ('enough.', 'O'),
#     ('Eventually', 'O'),
#     ('he', 'O'),
#     ('returns', 'O'),
#     ('to', 'O'),
#     ('work,', 'O'),
#     ('thinking', 'O'),
#     ('about', 'O'),
#     ('what', 'O'),
#     ('he', 'O'),
#     ('should', 'O'),
#     ('do', 'O'),
#     ('with', 'O'),
#     ('the', 'O'),
#     ('last', 'O'),
#     ('two', 'O'),
#     ('wishes.', 'O'),
#     ('Satan', 'O'),
#     ('appears', 'O'),
#     ('on', 'O'),
#     ('the', 'O'),
#     ('computer', 'O'),
#     ('screen,', 'O'),
#     ('pointing', 'O'),
#     ('out', 'O'),
#     ('that', 'O'),
#     ('on', 'O'),
#     ('their', 'O'),
#     ('first', 'O'),
#     ('meeting', 'O'),
#     ('he', 'O'),
#     ('asked', 'O'),
#     ('for', 'O'),
#     ('a', 'O'),
#     ('Big', 'O'),
#     ('Mac', 'O'),
#     ('and', 'O'),
#     ('Coke,', 'O'),
#     ('although', 'O'),
#     ('she', 'O'),
#     ('had', 'O'),
#     ('stated', 'O'),
#     ('that', 'O'),
#     ('it', 'O'),
#     ('was', 'O'),
#     ('a', 'O'),
#     ('test', 'O'),
#     ('wish', 'O'),
#     ('and', 'O'),
#     ('granted', 'O'),
#     ('it', 'O'),
#     ('before', 'O'),
#     ('Elliot', 'PERSON'),
#     ('signed', 'O'),
#     ('the', 'O'),
#     ('contract.', 'O'),
#     ('Elliot', 'PERSON'),
#     ('loses', 'O'),
#     ('his', 'O'),
#     ('patience', 'O'),
#     ('and', 'O'),
#     ('storms', 'O'),
#     ('out', 'O'),
#     ('of', 'O'),
#     ('his', 'O'),
#     ('office.', 'O'),
#     ('Elliot', 'PERSON'),
#     ('visits', 'O'),
#     ('a', 'O'),
#     ('church', 'O'),
#     ('looking', 'O'),
#     ('for', 'O'),
#     ("God's", 'O'),
#     ('help,', 'O'),
#     ('where', 'O'),
#     ('he', 'O'),
#     ('briefly', 'O'),
#     ('confesses', 'O'),
#     ('to', 'O'),
#     ('a', 'O'),
#     ('priest', 'O'),
#     ('who', 'O'),
#     ('seems', 'O'),
#     ('sympathetic.', 'O'),
#     ('However,', 'O'),
#     ('after', 'O'),
#     ('being', 'O'),
#     ('asked', 'O'),
#     ('whether', 'O'),
#     ('he', 'O'),
#     ('thinks', 'O'),
#     ('asking', 'O'),
#     ('Satan', 'O'),
# ...
#     ('and', 'O'),
#     ('does', 'O'),
#     ('very', 'O'),
#     ('well,', 'O'),
#     ('to', 'O'),
#     ("Scrapper's", 'O'),
#     ('delight.', 'O'),
#     ('In', 'O'),
#     ("Dick's", 'O'),
#     ('senior', 'O'),
#     ('year,', 'O'),
#     ('General', 'O'),
#     ('Fitts', 'PERSON'),
#     ('is', 'O'),
#     ('appointed', 'O'),
#     ('West', 'O'),
#     ('Point', 'O'),
#     ('superintendent.', 'O'),
#     ('While', 'O'),
#     ('most', 'O'),
#     ('of', 'O'),
#     ('the', 'O'),
#     ('men', 'O'),
#     ('are', 'O'),
#     ('infatuated', 'O'),
#     ('with', 'O'),
#     ('Kit,', 'O'),
#     ('Dick', 'PERSON'),
#     ('is', 'O'),
#     ('cold', 'O'),
#     ('to', 'O'),
#     ('her.', 'O'),
#     ('Consequently,', 'O'),
#     ('he', 'O'),
#     ('is', 'O'),
#     ('not', 'O'),
#     ('very', 'O'),
#     ('happy', 'O'),
#     ('when', 'O'),
#     ('the', 'O'),
#     ('rest', 'O'),
#     ('of', 'O'),
#     ('the', 'O'),
#     ('men', 'O'),
#     ('insist', 'O'),
#     ('that', 'O'),
#     ('she', 'O'),
#     ('participate', 'O'),
#     ('in', 'O'),
#     ('the', 'O'),
#     ('traditional', 'O'),
#     ('Hundredth', 'O'),
#     ('Night', 'O'),
#     ('theatrical', 'O'),
#     ('performance.', 'O'),
#     ('Dick', 'PERSON'),
#     ('writes', 'O'),
#     ('a', 'O'),
#     ('show', 'O'),
#     ('about', 'O'),
#     ('a', 'O'),
#     ('female', 'O'),
#     ('general', 'O'),
#     ('with', 'O'),
#     ('a', 'O'),
#     ('message', 'O'),
#     ('directed', 'O'),
#     ('at', 'O'),
#     ('Kit.', 'O'),
#     ('After', 'O'),
#     ('the', 'O'),
#     ('first', 'O'),
#     ('rehearsal,', 'O'),
#     ('Kit', 'O'),
#     ('walks', 'O'),
#     ('with', 'O'),
#     ('Dick', 'PERSON'),
#     ('on', 'O'),
#     ('Flirtation', 'O'),
#     ('Walk', 'O'),
#     ('and', 'O'),
#     ('tries', 'O'),
#     ('to', 'O'),
#     ('explain', 'O'),
#     ('why', 'O'),
#     ('she', 'O'),
#     ('told', 'O'),
#     ('him', 'O'),
#     ('she', 'O'),
#     ('was', 'O'),
#     ('not', 'O'),
#     ('in', 'O'),
#     ('love', 'O'),
#     ('with', 'O'),
#     ('him.', 'O'),
#     ('Dick', 'PERSON'),
#     ('is', 'O'),
#     ('too', 'O'),
#     ('angry', 'O'),
#     ('to', 'O'),
#     ('listen', 'O'),
#     ('to', 'O'),
#     ('Kit', 'O'),
#     ('but,', 'O'),
#     ('during', 'O'),
#     ('their', 'O'),
#     ('on-stage', 'O'),
#     ('love', 'O'),
#     ('scene,', 'O'),
#     ('kisses', 'O'),
#     ('her,', 'O'),
#     ('and', 'O'),
#     ('she', 'O'),
#     ('admits', 'O'),
#     ('she', 'O'),
#     ('loves', 'O'),
#     ('him.', 'O'),
#     ('When', 'O'),
#     ('General', 'O'),
#     ('Fitts', 'PERSON'),
#     ('announces', 'O'),
#     ("Kit's", 'O'),
#     ('engagement', 'O'),
#     ('to', 'O'),
#     ('Biddle,', 'O'),
#     ('Dick', 'PERSON'),
#     ('naturally', 'O'),
#     ('is', 'O'),
#     ('confused,', 'O'),
#     ('and', 'O'),
#     ('visits', 'O'),
#     ('her', 'O'),
#     ('after', 'O'),
#     ('lights', 'O'),
#     ('out', 'O'),
#     ('to', 'O'),
#     ('talk', 'O'),
#     ('her', 'O'),
#     ('out', 'O'),
#     ('of', 'O'),
#     ('marrying', 'O'),
#     ('Biddle.', 'O'),
#     ('He', 'O'),
#     ('is', 'O'),
#     ('caught', 'O'),
#     ('and,', 'O'),
#     ('to', 'O'),
#     ('protect', 'O'),
#     ("Kit's", 'O'),
#     ('name,', 'O'),
#     ('agrees', 'O'),
#     ('to', 'O'),
#     ('resign', 'O'),
#     ('from', 'O'),
#     ('the', 'O'),
#     ('Academy.', 'O'),
#     ('Scrapper', 'O'),
#     ('arrives', 'O'),
#     ('at', 'O'),
#     ('the', 'O'),
#     ('Academy', 'O'),
#     ('to', 'O'),
#     ('see', 'O'),
#     ('Dick', 'PERSON'),
#     ('graduate', 'O'),
#     ('and', 'O'),
#     ('is', 'O'),
#     ('disappointed', 'O'),
#     ('to', 'O'),
#     ('learn', 'O'),
#     ('of', 'O'),
#     ("Dick's", 'O'),
#     ('resignation.', 'O'),
#     ('The', 'O'),
#     ('day', 'O'),
#     ('is', 'O'),
#     ('saved', 'O'),
#     ('when', 'O'),
#     ('Biddle', 'PERSON'),
#     ('tells', 'O'),
#     ('Dick', 'PERSON'),
#     ('that', 'O'),
#     ('his', 'O'),
#     ('resignation', 'O'),
#     ('was', 'O'),
#     ('not', 'O'),
#     ('accepted', 'O'),
#     ('and', 'O'),
#     ('that', 'O'),
#     ('Kit', 'PERSON'),
#     ('returned', 'O'),
#     ('his', 'O'),
#     ('ring.', 'O'),
#     ('Dick', 'PERSON'),
#     ('graduates', 'O'),
#     ('a', 'O'),
#     ('happy', 'O'),
#     ('man.', 'O')],
#    'summaries_wikipedia_pos': [[('Richard', 'NNP'),
#      ('Palmer', 'NNP'),
#      ('Grant', 'NNP'),
#      ('Dorcy', 'NNP'),
#      (',', ','),
#      ('known', 'VBN'),
#      ('as', 'IN'),
#      ('``', '``'),
#      ('Canary', 'NNP'),
#      (',', ','),
#      ("''", "''"),
#      ('is', 'VBZ'),
#      ('an', 'DT'),
#      ('enlisted', 'VBN'),
#      ('man', 'NN'),
#      ('in', 'IN'),
#      ('the', 'DT'),
#      ('United', 'NNP'),
#      ('States', 'NNPS'),
#      ('Army', 'NNP'),
#      ('.', '.')],
#     [('Currently', 'RB'),
#      ('stationed', 'VBN'),
#      ('on', 'IN'),
#      ('the', 'DT'),
#      ('Hawaiian', 'NNP'),
#      ('Islands', 'NNPS'),
#      (',', ','),
#      ('he', 'PRP'),
#      ('has', 'VBZ'),
#      ('an', 'DT'),
#      ('affectionately', 'RB'),
#      ('argumentative', 'JJ'),
#      ('relationship', 'NN'),
#      ('with', 'IN'),
#      ('his', 'PRP$'),
#      ('sergeant', 'JJ'),
#      (',', ','),
#      ('Scrapper', 'NNP'),
#      ('Thornhill', 'NNP'),
#      ('Pat', 'NNP'),
#      ("O'Brien", 'NNP'),
#      ('.', '.')],
#     [('Although', 'IN'),
#      ('he', 'PRP'),
#      ('hates', 'VBZ'),
#      ('taking', 'VBG'),
#      ('orders', 'NNS'),
#      (',', ','),
#      ('Dick', 'NNP'),
#      ('has', 'VBZ'),
#      ('no', 'DT'),
#      ('intention', 'NN'),
#      ('of', 'IN'),
#      ('becoming', 'VBG'),
#      ('an', 'DT'),
#      ('officer', 'NN'),
#      ('.', '.')],
#     [('When', 'WRB'),
#      ('General', 'NNP'),
#      ('Fitts', 'NNP'),
#      ('arrives', 'VBZ'),
#      ('at', 'IN'),
#      ('the', 'DT'),
#      ('base', 'NN'),
#      ('with', 'IN'),
#      ('his', 'PRP$'),
#      ('daughter', 'NN'),
#      ('Kit', 'NNP'),
#      (',', ','),
#      ('Dick', 'NNP'),
#      ('is', 'VBZ'),
#      ('assigned', 'VBN'),
#      ('to', 'TO'),
#      ('drive', 'VB'),
#      ('her', 'PRP$'),
#      ('to', 'TO'),
#      ('the', 'DT'),
#      ('reception', 'NN'),
#      ('that', 'IN'),
#      ('evening', 'NN'),
#      ('.', '.')],
#     [('Falling', 'VBG'),
#      ('victim', 'NN'),
#      ('to', 'TO'),
#      ('the', 'DT'),
#      ('moonlit', 'NN'),
#      ('night', 'NN'),
#      (',', ','),
#      ('Kit', 'NNP'),
#      ('and', 'CC'),
#      ('Dick', 'NNP'),
#      ('miss', 'NN'),
#      ('the', 'DT'),
#      ('reception', 'NN'),
#      ('and', 'CC'),
#      ('attend', 'NN'),
#      ('a', 'DT'),
#      ('native', 'JJ'),
#      ('luau', 'NN'),
#      ('instead', 'RB'),
#      ('.', '.')],
#     [('They', 'PRP'),
#      ('are', 'VBP'),
#      ('discovered', 'VBN'),
#      ('in', 'IN'),
#      ('each', 'DT'),
#      ('other', 'JJ'),
#      ("'s", 'POS'),
#      ('arms', 'NNS'),
#      ('by', 'IN'),
#      ('Lieutenant', 'NNP'),
#      ('Biddle', 'NNP'),
#      ('John', 'NNP'),
#      ('Eldredge', 'NNP'),
#      (',', ','),
#      ('who', 'WP'),
#      ('is', 'VBZ'),
#      ('also', 'RB'),
#      ('in', 'IN'),
#      ('love', 'NN'),
#      ('with', 'IN'),
#      ('Kit', 'NNP'),
#      ('.', '.')],
#     [('Biddle', 'NNP'),
#      ('blames', 'VBZ'),
#      ('Dick', 'NNP'),
#      ('for', 'IN'),
#      ('ruining', 'VBG'),
#      ('Kit', 'NNP'),
#      ("'s", 'POS'),
#      ('reputation', 'NN'),
#      ('and', 'CC'),
#      ('Dick', 'NNP'),
#      ('decides', 'VBZ'),
#      ('to', 'TO'),
#      ('desert', 'VB'),
#      ('.', '.')],
#     [('Scrapper', 'NNP'),
#      ('begs', 'NNS'),
#      ('Kit', 'NNP'),
#      ('to', 'TO'),
#      ('straighten', 'VB'),
#      ('things', 'NNS'),
#      ('out', 'IN'),
#      ('with', 'IN'),
#      ('Biddle', 'NNP'),
#      ('.', '.')],
#     [('To', 'TO'),
#      ('prevent', 'VB'),
#      ('Dick', 'NNP'),
#      ('from', 'IN'),
#      ('deserting', 'VBG'),
#      (',', ','),
#      ('Kit', 'NNP'),
#      ('tells', 'VBZ'),
#      ('him', 'PRP'),
#      ('that', 'IN'),
#      ('she', 'PRP'),
#      ('is', 'VBZ'),
#      ('not', 'RB'),
#      ('in', 'IN'),
#      ('love', 'NN'),
#      ('with', 'IN'),
#      ('him', 'PRP'),
#      (',', ','),
#      ('but', 'CC'),
#      ('was', 'VBD'),
#      ('responding', 'VBG'),
#      ('to', 'TO'),
#      ('a', 'DT'),
#      ('crazy', 'NN'),
#      ('impulse', 'NN'),
#      ('.', '.')],
#     [('Stung', 'NNP'),
#      ('by', 'IN'),
#      ('her', 'PRP$'),
#      ('words', 'NNS'),
#      (',', ','),
#      ('Dick', 'NNP'),
#      ('decides', 'VBZ'),
#      ('to', 'TO'),
#      ('compete', 'VB'),
#      ('with', 'IN'),
#      ('Biddle', 'NNP'),
#      ('as', 'IN'),
#      ('an', 'DT'),
#      ('equal', 'JJ'),
#      ('and', 'CC'),
#      ('applies', 'NNS'),
#      ('for', 'IN'),
#      ('West', 'NNP'),
#      ('Point', 'NNP'),
#      ('.', '.')],
#     [('He', 'PRP'),
#      ('is', 'VBZ'),
#      ('accepted', 'VBN'),
#      ('and', 'CC'),
#      ('does', 'VBZ'),
#      ('very', 'RB'),
#      ('well', 'RB'),
#      (',', ','),
#      ('to', 'TO'),
#      ('Scrapper', 'NNP'),
#      ("'s", 'POS'),
#      ('delight', 'NN'),
#      ('.', '.')],
#     [('In', 'IN'),
#      ('Dick', 'NNP'),
#      ("'s", 'POS'),
#      ('senior', 'JJ'),
#      ('year', 'NN'),
#      (',', ','),
#      ('General', 'NNP'),
#      ('Fitts', 'NNP'),
#      ('is', 'VBZ'),
#      ('appointed', 'VBN'),
#      ('West', 'JJ'),
#      ('Point', 'NNP'),
#      ('superintendent', 'NN'),
#      ('.', '.')],
#     [('While', 'IN'),
#      ('most', 'JJS'),
#      ('of', 'IN'),
#      ('the', 'DT'),
#      ('men', 'NNS'),
#      ('are', 'VBP'),
#      ('infatuated', 'VBN'),
#      ('with', 'IN'),
#      ('Kit', 'NNP'),
#      (',', ','),
#      ('Dick', 'NNP'),
#      ('is', 'VBZ'),
#      ('cold', 'VBN'),
#      ('to', 'TO'),
#      ('her', 'PRP$'),
#      ('.', '.')],
#     [('Consequently', 'RB'),
#      (',', ','),
#      ('he', 'PRP'),
#      ('is', 'VBZ'),
#      ('not', 'RB'),
#      ('very', 'RB'),
#      ('happy', 'JJ'),
#      ('when', 'WRB'),
#      ('the', 'DT'),
#      ('rest', 'NN'),
#      ('of', 'IN'),
#      ('the', 'DT'),
#      ('men', 'NNS'),
#      ('insist', 'VBP'),
#      ('that', 'IN'),
#      ('she', 'PRP'),
#      ('participate', 'VBP'),
#      ('in', 'IN'),
#      ('the', 'DT'),
#      ('traditional', 'JJ'),
#      ('Hundredth', 'NNP'),
#      ('Night', 'NNP'),
#      ('theatrical', 'JJ'),
#      ('performance', 'NN'),
#      ('.', '.')],
#     [('Dick', 'NNP'),
#      ('writes', 'VBZ'),
#      ('a', 'DT'),
#      ('show', 'NN'),
#      ('about', 'IN'),
#      ('a', 'DT'),
#      ('female', 'JJ'),
#      ('general', 'JJ'),
#      ('with', 'IN'),
#      ('a', 'DT'),
#      ('message', 'NN'),
#      ('directed', 'VBN'),
#      ('at', 'IN'),
#      ('Kit', 'NNP'),
#      ('.', '.')],
#     [('After', 'IN'),
#      ('the', 'DT'),
#      ('first', 'JJ'),
#      ('rehearsal', 'NN'),
#      (',', ','),
#      ('Kit', 'NNP'),
#      ('walks', 'NNS'),
#      ('with', 'IN'),
#      ('Dick', 'NNP'),
#      ('on', 'IN'),
#      ('Flirtation', 'NNP'),
#      ('Walk', 'NNP'),
#      ('and', 'CC'),
#      ('tries', 'NNS'),
#      ('to', 'TO'),
#      ('explain', 'VB'),
#      ('why', 'WRB'),
#      ('she', 'PRP'),
#      ('told', 'VBD'),
#      ('him', 'PRP'),
#      ('she', 'PRP'),
#      ('was', 'VBD'),
#      ('not', 'RB'),
#      ('in', 'IN'),
#      ('love', 'NN'),
#      ('with', 'IN'),
#      ('him', 'PRP'),
#      ('.', '.')],
#     [('Dick', 'NNP'),
#      ('is', 'VBZ'),
#      ('too', 'RB'),
#      ('angry', 'JJ'),
#      ('to', 'TO'),
#      ('listen', 'VB'),
#      ('to', 'TO'),
#      ('Kit', 'VB'),
#      ('but', 'CC'),
#      (',', ','),
#      ('during', 'IN'),
#      ('their', 'PRP$'),
#      ('on-stage', 'JJ'),
#      ('love', 'NN'),
#      ('scene', 'NN'),
#      (',', ','),
#      ('kisses', 'NNS'),
#      ('her', 'PRP$'),
#      (',', ','),
#      ('and', 'CC'),
#      ('she', 'PRP'),
#      ('admits', 'VBZ'),
#      ('she', 'PRP'),
#      ('loves', 'VBZ'),
#      ('him', 'PRP'),
#      ('.', '.')],
#     [('When', 'WRB'),
#      ('General', 'NNP'),
#      ('Fitts', 'NNP'),
#      ('announces', 'NNS'),
#      ('Kit', 'NNP'),
#      ("'s", 'POS'),
#      ('engagement', 'NN'),
#      ('to', 'TO'),
#      ('Biddle', 'NNP'),
#      (',', ','),
#      ('Dick', 'NNP'),
#      ('naturally', 'RB'),
#      ('is', 'VBZ'),
#      ('confused', 'VBN'),
#      (',', ','),
#      ('and', 'CC'),
#      ('visits', 'NNS'),
#      ('her', 'PRP$'),
#      ('after', 'IN'),
#      ('lights', 'NNS'),
#      ('out', 'IN'),
#      ('to', 'TO'),
#      ('talk', 'VB'),
#      ('her', 'PRP$'),
#      ('out', 'RP'),
#      ('of', 'IN'),
#      ('marrying', 'NN'),
#      ('Biddle', 'NNP'),
#      ('.', '.')],
#     [('He', 'PRP'),
#      ('is', 'VBZ'),
#      ('caught', 'VBN'),
#      ('and', 'CC'),
#      (',', ','),
#      ('to', 'TO'),
#      ('protect', 'VB'),
#      ('Kit', 'NNP'),
#      ("'s", 'POS'),
#      ('name', 'NN'),
#      (',', ','),
#      ('agrees', 'VBZ'),
#      ('to', 'TO'),
#      ('resign', 'VB'),
#      ('from', 'IN'),
#      ('the', 'DT'),
#      ('Academy', 'NNP'),
#      ('.', '.')],
#     [('Scrapper', 'NNP'),
#      ('arrives', 'VBZ'),
#      ('at', 'IN'),
#      ('the', 'DT'),
#      ('Academy', 'NNP'),
#      ('to', 'TO'),
#      ('see', 'VB'),
#      ('Dick', 'NNP'),
#      ('graduate', 'NN'),
#      ('and', 'CC'),
#      ('is', 'VBZ'),
#      ('disappointed', 'VBN'),
#      ('to', 'TO'),
#      ('learn', 'VB'),
#      ('of', 'IN'),
#      ('Dick', 'NNP'),
#      ("'s", 'POS'),
#      ('resignation', 'NN'),
#      ('.', '.')],
#     [('The', 'DT'),
#      ('day', 'NN'),
#      ('is', 'VBZ'),
#      ('saved', 'VBN'),
#      ('when', 'WRB'),
#      ('Biddle', 'NNP'),
#      ('tells', 'VBZ'),
#      ('Dick', 'NNP'),
#      ('that', 'IN'),
#      ('his', 'PRP$'),
#      ('resignation', 'NN'),
#      ('was', 'VBD'),
#      ('not', 'RB'),
#      ('accepted', 'VBN'),
#      ('and', 'CC'),
#      ('that', 'IN'),
#      ('Kit', 'NNP'),
#      ('returned', 'VBD'),
#      ('his', 'PRP$'),
#      ('ring', 'NN'),
#      ('.', '.')],
#     [('Dick', 'NNP'),
#      ('graduates', 'VBZ'),
#      ('a', 'DT'),
#      ('happy', 'NN'),
#      ('man', 'NN'),
#      ('.', '.')]],
#    'title': 'Flirtation Walk',
#    'venue': 'T',
#    'version': 'I',
#    'year': '1934'}],
#  ['kotpanum chonio.1972',
#   {'id': 53071,
#    'language': None,
#    'num_ratings': '110',
#    'ratings': '5.8',
#    'roles': [{'gender': 'F',
#      'role': 'Mother',
#      'role_pos': [[('mother', 'NN')]]},
#     {'gender': 'F',
#      'role': 'Sun Hui',
#      'role_pos': [[('sun', 'NN'), ('hui', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Old man',
#      'role_pos': [[('old', 'JJ'), ('man', 'NN')]]},
#     {'gender': 'M', 'role': 'Koppun', 'role_pos': [[('koppun', 'NN')]]},
#     {'gender': 'M',
#      'role': 'Chol Yong',
#      'role_pos': [[('chol', 'NN'), ('yong', 'IN')]]},
#     {'gender': 'M',
#      'role': 'Landowner',
#      'role_ne': [Tree('S', [Tree('GPE', [['Landowner', 'NN']])])],
#      'role_pos': [[['Landowner', 'NN']]]}],
#    'summaries_imdb': ['The country is occupied by the Japanese imperialists. Koppun is selling flowers at the market to get some money to buy medicine for her sick mother. Her brother is imprisoned, her father dead and her sister blind.'],
#    'summaries_imdb_ner': [('The', 'O'),
#     ('country', 'O'),
#     ('is', 'O'),
#     ('occupied', 'O'),
#     ('by', 'O'),
#     ('the', 'O'),
#     ('Japanese', 'O'),
#     ('imperialists.', 'O'),
#     ('Koppun', 'O'),
#     ('is', 'O'),
#     ('selling', 'O'),
#     ('flowers', 'O'),
#     ('at', 'O'),
#     ('the', 'O'),
#     ('market', 'O'),
#     ('to', 'O'),
#     ('get', 'O'),
#     ('some', 'O'),
#     ('money', 'O'),
#     ('to', 'O'),
#     ('buy', 'O'),
#     ('medicine', 'O'),
#     ('for', 'O'),
#     ('her', 'O'),
#     ('sick', 'O'),
#     ('mother.', 'O'),
#     ('Her', 'O'),
#     ('brother', 'O'),
#     ('is', 'O'),
#     ('imprisoned,', 'O'),
#     ('her', 'O'),
#     ('father', 'O'),
#     ('dead', 'O'),
#     ('and', 'O'),
#     ('her', 'O'),
#     ('sister', 'O'),
#     ('blind.', 'O')],
#    'summaries_imdb_pos': [[('The', 'DT'),
#      ('country', 'NN'),
#      ('is', 'VBZ'),
#      ('occupied', 'VBN'),
#      ('by', 'IN'),
#      ('the', 'DT'),
#      ('Japanese', 'JJ'),
#      ('imperialists', 'NNS'),
#      ('.', '.')],
#     [('Koppun', 'NNP'),
#      ('is', 'VBZ'),
#      ('selling', 'VBG'),
#      ('flowers', 'NNS'),
#      ('at', 'IN'),
#      ('the', 'DT'),
#      ('market', 'NN'),
#      ('to', 'TO'),
#      ('get', 'VB'),
#      ('some', 'DT'),
#      ('money', 'NN'),
#      ('to', 'TO'),
#      ('buy', 'VB'),
#      ('medicine', 'NN'),
#      ('for', 'IN'),
#      ('her', 'PRP$'),
#      ('sick', 'NN'),
#      ('mother', 'NN'),
#      ('.', '.')],
#     [('Her', 'PRP$'),
#      ('brother', 'NN'),
#      ('is', 'VBZ'),
#      ('imprisoned', 'VBN'),
#      (',', ','),
#      ('her', 'PRP$'),
#      ('father', 'NN'),
#      ('dead', 'NN'),
#      ('and', 'CC'),
#      ('her', 'PRP$'),
#      ('sister', 'NN'),
#      ('blind', 'NN'),
#      ('.', '.')]],
#    'summaries_wikipedia': [],
#    'title': 'Kotpanum chonio',
#    'venue': 'T',
#    'version': 'I',
#    'year': '1972'}]]

# %%
# This part will later be replayed by linking appropirate summary data to roles data.
roles_bag =[]
for i in range(len(sample)):
    roles = sample[i][1]['roles']
    for j in range(len(roles)):
        roles_bag.extend(roles[j]['role'].split())

# %%
roles_bag = [i.lower() for i in roles_bag]
roles_bag
# Out:
# ['vanessa',
#  'nelie',
#  'kano',
#  'cora',
#  'bea',
#  'gaying',
#  'adelina',
#  "vanessa's",
#  'mother',
#  'virgie',
#  'baby',
#  'marichu',
#  "adelina's",
#  'client',
#  'manay',
#  'sharon',
#  'recruiter',
#  'mall',
#  'couple',
#  'alex',
#  'pebrero',
#  'greggy',
#  'williams',
#  "virgir's",
#  'husband',
#  'midwife',
#  'angelica',
#  'snobby',
#  'woman',
#  'lady',
#  'in',
#  'park',
#  'nora',
#  'beggar',
#  'girl',
#  'young',
#  'angelica',
#  'constance',
#  'anne',
#  'montague',
#  'older',
#  'constance',
#  'spirit',
#  'girl',
#  'unnamed',
#  'scientist',
#  'unnamed',
#  'scientist',
#  'medical',
#  'student',
#  'mr.',
#  'pendleton',
#  'spirit',
#  'boy',
#  'unnamed',
#  'scientist',
#  'bookseller',
#  'dr.',
#  'joseph',
#  'barton',
#  'dv8',
#  'clubgoer',
#  'dv8',
#  'clubgoer',
#  'cheerleader/dancer',
#  'cheerleader/dancer',
#  'dv8',
#  'waitress',
#  'cheerleader/dancer',
#  'churchgoer',
#  'cheerleader/dancer',
#  'caged',
#  'go-go',
#  'dancer',
#  'tech',
#  'support',
#  'advisor',
#  'play',
#  'actor',
#  'cheerleader/dancer',
#  'the',
#  'devil',
#  'fly',
#  'girl',
#  'dv8',
#  'clubgoer',
#  'cheerleader/dancer',
#  'alison/nicole',
#  'dv8',
#  'clubgoer',
#  'fly',
#  'girl',
#  'cheerleader/dancer',
#  'cheerleader/dancer',
#  'carol/penthouse',
#  'hostess',
#  'girl',
#  'at',
#  'beer',
#  'garden',
#  'girl',
#  'at',
#  'beer',
#  'garden',
#  'fly',
#  'girl',
#  'restaurant',
#  'customer',
#  'cheerleader/dancer',
#  'tech',
#  'support',
#  'advisor',
#  'tech',
#  'support',
#  'advisor',
#  'demonic',
#  'waitress',
#  'cheerleader/dancer',
#  'bob/roberto/beach',
#  'jock/sportscaster/lincoln',
#  'aide',
#  'tech',
#  'support',
#  'advisor',
#  "mcdonald's",
#  'employee',
#  'dv8',
#  'clubgoer',
#  'prisoner',
#  "elliot's",
#  'cellmate',
#  'san',
#  'francisco',
#  'pedestrian',
#  'tech',
#  'support',
#  'advisor',
#  'cornell,',
#  'peter',
#  '(ii)',
#  'businessman',
#  '#1',
#  'desk',
#  'sergeant',
#  'priest',
#  'ivan',
#  'the',
#  'russian',
#  'john',
#  'wilkes',
#  'booth',
#  'elliot',
#  'man',
#  'in',
#  'park',
#  'mover',
#  'play',
#  'actor',
#  'pablito',
#  'diablos',
#  'fan',
#  '#4',
#  'dv8',
#  'clubgoer',
#  'diablos',
#  'fan',
#  '#3',
#  'jerry/alejandro/beach',
#  'jock/sportscaster/lance',
#  'nba',
#  'player',
#  '#10',
#  'dan/esteban/beach',
#  'jock/sportscaster/african',
#  'party',
#  'guest',
#  'club',
#  'dv8',
#  'patron',
#  'synedyne',
#  'supervisor',
#  'eduardo',
#  'raoul',
#  'dv8',
#  'bouncer',
#  'russian',
#  'drug',
#  'dealer',
#  'club',
#  'dv8',
#  'dancer',
#  'raging',
#  'fan',
#  'office',
#  'worker',
#  'play',
#  'actor',
#  'extra',
#  'surfer',
#  'club',
#  'dancer',
#  'nba',
#  'player',
#  '#30',
#  "devil's",
#  'lawyer',
#  'play',
#  'actor',
#  'club',
#  'dv8',
#  'goth',
#  'usher',
#  'elegant',
#  'devil',
#  'police',
#  'officer',
#  'dv8',
#  'clubgoer',
#  'cafe',
#  'patron',
#  'at',
#  'the',
#  'car',
#  'crash',
#  'drug',
#  'factory',
#  'foreman',
#  'columbian',
#  'soldier',
#  'security',
#  'guard',
#  '(rock',
#  'fantasy)',
#  'biggest',
#  'devil',
#  'chorus',
#  'girl',
#  'chorus',
#  'girl',
#  'dowager',
#  'at',
#  'show',
#  'redhead',
#  'chorus',
#  'girl',
#  "'kit'",
#  'fitts',
#  'blonde',
#  'chorus',
#  'girl',
#  'girl',
#  'chorus',
#  'girl',
#  "'oskie'",
#  "'spike'",
#  'cadet',
#  "'eight",
#  "ball'",
#  'native',
#  'leader',
#  'gen.',
#  'landacre',
#  'cadet',
#  'chase',
#  "fitts'",
#  'butler',
#  'lieut.',
#  'biddle',
#  'bandleader',
#  'cadet',
#  'superintendent',
#  "'scrapper'",
#  'thornhhill',
#  'gen.',
#  'fitts',
#  'dick',
#  "'canary'",
#  'dorcy',
#  'cadet',
#  "'sleepy'",
#  'cadet',
#  'mother',
#  'sun',
#  'hui',
#  'old',
#  'man',
#  'koppun',
#  'chol',
#  'yong',
#  'landowner']

# %%
# combine wiki_ner and imdb_ner
for i in range(len(sample)):
#     summaries_imdb_ner is indeed a list
    summaries_imdb_ner = sample[i][1]["summaries_imdb_ner"]
    if 'summaries_wikipedia_ner' in sample[i][1]:
        summaries_wiki_ner = sample[i][1]['summaries_wikipedia_ner']
    else: summaries_wiki_ner = []
    summaries_imdb_ner.extend(summaries_wiki_ner)
    sample[i][1]['summaries_combined_ner'] = summaries_imdb_ner

# %%
sample[2][1]['summaries_combined_ner']
# Out:
# [('Elliot', 'PERSON'),
#  ('Richardson,', 'O'),
#  ('a', 'O'),
#  ('socially', 'O'),
#  ('awkward', 'O'),
#  ('IT', 'O'),
#  ('worker,', 'O'),
#  ('is', 'O'),
#  ('given', 'O'),
#  ('seven', 'O'),
#  ('wishes', 'O'),
#  ('to', 'O'),
#  ('get', 'O'),
#  ('the', 'O'),
#  ('girl', 'O'),
#  ('of', 'O'),
#  ('his', 'O'),
#  ('dreams', 'O'),
#  ('when', 'O'),
#  ('he', 'O'),
#  ('meets', 'O'),
#  ('up', 'O'),
#  ('with', 'O'),
#  ('a', 'O'),
#  ('very', 'O'),
#  ('seductive', 'O'),
#  ('Satan.', 'O'),
#  ('The', 'O'),
#  ('catch:', 'O'),
#  ('his', 'O'),
#  ('soul.', 'O'),
#  ('Some', 'O'),
#  ('of', 'O'),
#  ('his', 'O'),
#  ('wishes', 'O'),
#  ('include', 'O'),
#  ('being', 'O'),
#  ('a', 'O'),
#  ('7', 'O'),
#  ('foot', 'O'),
#  ('basketball', 'O'),
#  ('star,', 'O'),
#  ('a', 'O'),
#  ('wealthy,', 'O'),
#  ('powerful', 'O'),
#  ('man,', 'O'),
#  ('and', 'O'),
#  ('a', 'O'),
#  ('sensitive', 'O'),
#  ('caring', 'O'),
#  ('guy.', 'O'),
#  ('But,', 'O'),
#  ('as', 'O'),
#  ('could', 'O'),
#  ('be', 'O'),
#  ('expected,', 'O'),
#  ('the', 'O'),
#  ('Devil', 'O'),
#  ('must', 'O'),
#  ('put', 'O'),
#  ('her', 'O'),
#  ('own', 'O'),
#  ('little', 'O'),
#  ('twist', 'O'),
#  ('on', 'O'),
#  ('each', 'O'),
#  ('his', 'O'),
#  ('fantasies.', 'O'),
#  ('Elliot', 'PERSON'),
#  ('Richards,', 'O'),
#  ('a', 'O'),
#  ('socially', 'O'),
#  ('incompetent', 'O'),
#  ('technical', 'O'),
#  ('advisor', 'O'),
#  ('working', 'O'),
#  ('at', 'O'),
#  ('a', 'O'),
#  ('call-center,', 'O'),
#  ('has', 'O'),
#  ('had', 'O'),
#  ('a', 'O'),
#  ('crush', 'O'),
#  ('on', 'O'),
#  ('Alison', 'PERSON'),
#  ('Gardner', 'PERSON'),
#  ('for', 'O'),
#  ('nearly', 'O'),
#  ('four', 'O'),
#  ('years.', 'O'),
#  ('One', 'O'),
#  ('evening,', 'O'),
#  ('which', 'O'),
#  ('already', 'O'),
#  ('started', 'O'),
#  ('particularly', 'O'),
#  ('bad', 'O'),
#  ('for', 'O'),
#  ('Elliot,', 'O'),
#  ('she', 'O'),
#  ('ditches', 'O'),
#  ('him.', 'O'),
#  ('Elliot', 'PERSON'),
#  ('wishes', 'O'),
#  ('for', 'O'),
#  ('her', 'O'),
#  ('to', 'O'),
#  ('be', 'O'),
#  ('in', 'O'),
#  ('his', 'O'),
#  ('life', 'O'),
#  ('with', 'O'),
#  ('all', 'O'),
#  ('his', 'O'),
#  ('heart', 'O'),
#  ('-', 'O'),
#  ('and', 'O'),
#  ('is', 'O'),
#  ('heard.', 'O'),
#  ('An', 'O'),
#  ('incredibly', 'O'),
#  ('beautiful', 'O'),
#  ('young', 'O'),
#  ('lady', 'O'),
#  ('addresses', 'O'),
#  ('Elliot,', 'O'),
#  ('and', 'O'),
#  ('after', 'O'),
#  ('introducing', 'O'),
#  ('herself', 'O'),
#  ('as', 'O'),
#  ('the', 'O'),
#  ('Devil,', 'O'),
#  ('Lucifer,', 'O'),
#  ('the', 'O'),
#  ('Princess', 'O'),
#  ('of', 'O'),
#  ('Darkness,', 'O'),
#  ('she', 'O'),
#  ('offers', 'O'),
#  ('him', 'O'),
#  ('a', 'O'),
#  ('deal:', 'O'),
#  ('Seven', 'O'),
#  ('wishes', 'O'),
#  ('for', 'O'),
#  ('him,', 'O'),
#  ('his', 'O'),
#  ('Soul', 'O'),
#  ('for', 'O'),
#  ('her.', 'O'),
#  ('Quickly,', 'O'),
#  ('Elliot', 'PERSON'),
#  ('is', 'O'),
#  ('convinced', 'O'),
#  ('and', 'O'),
#  ('accepts.', 'O'),
#  ('But', 'O'),
#  ('every', 'O'),
#  ('wish', 'O'),
#  ('he', 'O'),
#  ('gets', 'O'),
#  ('fulfilled', 'O'),
#  ('has', 'O'),
#  ('massive', 'O'),
#  ('disadvantages', 'O'),
#  ('as', 'O'),
#  ('well,', 'O'),
#  ('and', 'O'),
#  ('soon', 'O'),
#  ('Elliot', 'PERSON'),
#  ('wants', 'O'),
#  ('to', 'O'),
#  ('get', 'O'),
#  ('out', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('contract.', 'O'),
#  ('The', 'O'),
#  ('only', 'O'),
#  ('thing', 'O'),
#  ('that', 'O'),
#  ('matters', 'O'),
#  ('to', 'O'),
#  ('him', 'O'),
#  ('now', 'O'),
#  ('is', 'O'),
#  ('being', 'O'),
#  ('able', 'O'),
#  ('to', 'O'),
#  ('take', 'O'),
#  ('his', 'O'),
#  ('chances', 'O'),
#  ('by', 'O'),
#  ('himself.', 'O'),
#  ('Elliot', 'PERSON'),
#  ('Richards', 'PERSON'),
#  ('is', 'O'),
#  ('a', 'O'),
#  ('geeky,', 'O'),
#  ('over-zealous', 'O'),
#  ('man', 'O'),
#  ('working', 'O'),
#  ('a', 'O'),
#  ('dead-end', 'O'),
#  ('technical', 'O'),
#  ('support', 'O'),
#  ('job', 'O'),
#  ('in', 'O'),
#  ('a', 'O'),
#  ('San', 'LOCATION'),
#  ('Francisco', 'LOCATION'),
#  ('computer', 'O'),
#  ('company.', 'O'),
#  ('He', 'O'),
#  ('has', 'O'),
#  ('no', 'O'),
#  ('friends', 'O'),
#  ('and', 'O'),
#  ('his', 'O'),
#  ('co-workers', 'O'),
#  ('use', 'O'),
#  ('him,', 'O'),
#  ('knowing', 'O'),
#  ('he', 'O'),
#  ('will', 'O'),
#  ('do', 'O'),
#  ('anything', 'O'),
#  ('for', 'O'),
#  ('acceptance.', 'O'),
#  ('He', 'O'),
#  ('has', 'O'),
#  ('a', 'O'),
#  ('crush', 'O'),
#  ('on', 'O'),
#  ('his', 'O'),
#  ('colleague,', 'O'),
#  ('Alison', 'PERSON'),
#  ('Gardner', 'PERSON'),
#  (',', 'O'),
#  ('but', 'O'),
#  ('lacks', 'O'),
#  ('the', 'O'),
#  ('courage', 'O'),
#  ('to', 'O'),
#  ('ask', 'O'),
#  ('her', 'O'),
#  ('out.', 'O'),
#  ('After', 'O'),
#  ('Elliot', 'PERSON'),
#  ('is', 'O'),
#  ('again', 'O'),
#  ('ditched', 'O'),
#  ('by', 'O'),
#  ('his', 'O'),
#  ('co-workers,', 'O'),
#  ('at', 'O'),
#  ('a', 'O'),
#  ('bar', 'O'),
#  ('while', 'O'),
#  ('trying', 'O'),
#  ('to', 'O'),
#  ('talk', 'O'),
#  ('to', 'O'),
#  ('Alison,', 'O'),
#  ('he', 'O'),
#  ('says', 'O'),
#  ('to', 'O'),
#  ('himself', 'O'),
#  ('that', 'O'),
#  ('he', 'O'),
#  ('would', 'O'),
#  ('give', 'O'),
#  ('anything', 'O'),
#  ('for', 'O'),
#  ('Alison', 'PERSON'),
#  ('to', 'O'),
#  ('be', 'O'),
#  ('with', 'O'),
#  ('him.', 'O'),
#  ('Satan', 'O'),
#  (',', 'O'),
#  ('in', 'O'),
#  ('the', 'O'),
#  ('form', 'O'),
#  ('of', 'O'),
#  ('a', 'O'),
#  ('beautiful', 'O'),
#  ('woman,', 'O'),
#  ('overhears', 'O'),
#  ('him', 'O'),
#  ('and', 'O'),
#  ('offers', 'O'),
#  ('to', 'O'),
#  ('give', 'O'),
#  ('Elliot', 'PERSON'),
#  ('seven', 'O'),
#  ('wishes', 'O'),
#  ('in', 'O'),
#  ('return', 'O'),
#  ('for', 'O'),
#  ('his', 'O'),
#  ('soul.', 'O'),
#  ('As', 'O'),
#  ('a', 'O'),
#  ('test,', 'O'),
#  ('he', 'O'),
#  ('wishes', 'O'),
#  ('for', 'O'),
#  ('a', 'O'),
#  ('Big', 'O'),
#  ('Mac', 'O'),
#  ('and', 'O'),
#  ('Coke.', 'O'),
#  ('Satan', 'PERSON'),
#  ('takes', 'O'),
#  ('him', 'O'),
#  ('to', 'O'),
#  ("McDonald's", 'O'),
#  ('and', 'O'),
#  ('places', 'O'),
#  ('the', 'O'),
#  ('order.', 'O'),
#  ('Elliot', 'PERSON'),
#  ('has', 'O'),
#  ('to', 'O'),
#  ('pay', 'O'),
#  ('for', 'O'),
#  ('it,', 'O'),
#  ('because,', 'O'),
#  ('"there', 'O'),
#  ("ain't", 'O'),
#  ('no', 'O'),
#  ('such', 'O'),
#  ('thing', 'O'),
#  ('as', 'O'),
#  ('a', 'O'),
#  ('free', 'O'),
#  ('lunch."', 'O'),
#  ('After', 'O'),
#  ('taking', 'O'),
#  ('Elliot', 'PERSON'),
#  ('to', 'O'),
#  ('her', 'O'),
#  ('office,', 'O'),
#  ('based', 'O'),
#  ('at', 'O'),
#  ('a', 'O'),
#  ('nightclub', 'O'),
#  ('in', 'O'),
#  ('Oakland,', 'O'),
#  ('Satan', 'O'),
#  ('convinces', 'O'),
#  ('Elliot', 'PERSON'),
#  ('to', 'O'),
#  ('sign', 'O'),
#  ('her', 'O'),
#  ('contract,', 'O'),
#  ('and', 'O'),
#  ('delivers', 'O'),
#  ('further', 'O'),
#  ('wishes.', 'O'),
#  ('Each', 'O'),
#  ('wish', 'O'),
#  ('has', 'O'),
#  ('Elliot', 'PERSON'),
#  ('living', 'O'),
#  ('them', 'O'),
#  ('out', 'O'),
#  ('with', 'O'),
#  ('Alison', 'PERSON'),
#  ('and', 'O'),
#  ('his', 'O'),
#  ('co-workers', 'O'),
#  ('in', 'O'),
#  ('surrogate', 'O'),
#  ('roles.', 'O'),
#  ('However,', 'O'),
#  ('he', 'O'),
#  ("doesn't", 'O'),
#  ('know', 'O'),
#  ('that', 'O'),
#  ('Satan', 'O'),
#  ('will', 'O'),
#  ('always', 'O'),
#  ('spoil', 'O'),
#  ('his', 'O'),
#  ('wishes', 'O'),
#  ('by', 'O'),
#  ('adding', 'O'),
#  ('something', 'O'),
#  ('he', 'O'),
#  ("doesn't", 'O'),
#  ('want.', 'O'),
#  ('Elliot', 'PERSON'),
#  ('wishes', 'O'),
#  ('to', 'O'),
#  ('be', 'O'),
#  ('rich', 'O'),
#  ('and', 'O'),
#  ('powerful,', 'O'),
#  ('with', 'O'),
#  ('Alison', 'PERSON'),
#  ('as', 'O'),
#  ('his', 'O'),
#  ('wife.', 'O'),
#  ('Satan', 'O'),
#  ('makes', 'O'),
#  ('him', 'O'),
#  ('a', 'O'),
#  ('Colombian', 'O'),
#  ('drug', 'O'),
#  ('lord', 'O'),
#  ('whose', 'O'),
#  ('wife', 'O'),
#  ('despises', 'O'),
#  ('him', 'O'),
#  ('and', 'O'),
#  ('cheats', 'O'),
#  ('on', 'O'),
#  ('him', 'O'),
#  ('with', 'O'),
#  ('Raul,', 'O'),
#  ('his', 'O'),
#  ('co-worker,', 'O'),
#  ('who', 'O'),
#  ('is', 'O'),
#  ('secretly', 'O'),
#  ('planning', 'O'),
#  ('to', 'O'),
#  ('get', 'O'),
#  ('rid', 'O'),
#  ('of', 'O'),
#  ('Elliot', 'PERSON'),
#  ('and', 'O'),
#  ('take', 'O'),
#  ('his', 'O'),
#  ('position', 'O'),
#  ('and', 'O'),
#  ('property.', 'O'),
#  ('Soon', 'O'),
#  ('after', 'O'),
#  ('there', 'O'),
#  ('is', 'O'),
#  ('a', 'O'),
#  ('firefight', 'O'),
#  ('between', 'O'),
#  ('his', 'O'),
#  ('and', 'O'),
#  ("Raul's", 'O'),
#  ('people', 'O'),
#  ('where', 'O'),
#  ('Elliot', 'PERSON'),
#  ('"dies".', 'O'),
#  ('When', 'O'),
#  ('he', 'O'),
#  ('returns', 'O'),
#  ('to', 'O'),
#  ('the', 'O'),
#  ('real', 'O'),
#  ('world,', 'O'),
#  ('Satan', 'O'),
#  ('points', 'O'),
#  ('out', 'O'),
#  ('that', 'O'),
#  ('he', 'O'),
#  ('never', 'O'),
#  ('wished', 'O'),
#  ('for', 'O'),
#  ('Alison', 'PERSON'),
#  ('to', 'O'),
#  ('love', 'O'),
#  ('him.', 'O'),
#  ('Secondly,', 'O'),
#  ('Elliot', 'PERSON'),
#  ('wishes', 'O'),
#  ('to', 'O'),
#  ('be', 'O'),
#  ('emotionally', 'O'),
#  ('sensitive', 'O'),
#  ('so', 'O'),
#  ('he', 'O'),
#  ('will', 'O'),
#  ('understand', 'O'),
#  ('the', 'O'),
#  ('needs', 'O'),
#  ('and', 'O'),
#  ('desires', 'O'),
#  ('of', 'O'),
#  ('women.', 'O'),
#  ('Satan', 'O'),
#  ('makes', 'O'),
#  ('him', 'O'),
#  ('so', 'O'),
#  ('sensitive', 'O'),
#  ('that', 'O'),
#  ('he', 'O'),
#  ('spends', 'O'),
#  ('most', 'O'),
#  ('of', 'O'),
#  ('his', 'O'),
#  ('time', 'O'),
#  ('crying', 'O'),
#  ('over', 'O'),
#  ('how', 'O'),
#  ('beautiful', 'O'),
#  ('the', 'O'),
#  ('world', 'O'),
#  ('is,', 'O'),
#  ('and', 'O'),
#  ('constantly', 'O'),
#  ('asks', 'O'),
#  ('Alison,', 'O'),
#  ('his', 'O'),
#  ('girlfriend', 'O'),
#  ('of', 'O'),
#  ('"three', 'O'),
#  ('magical', 'O'),
#  ('weeks,"', 'O'),
#  ('whether', 'O'),
#  ('he', 'O'),
#  ('has', 'O'),
#  ('hurt', 'O'),
#  ('her', 'O'),
#  ('or', 'O'),
#  ('if', 'O'),
#  ('she', 'O'),
#  ('needs', 'O'),
#  ('anything.', 'O'),
#  ('Alison', 'PERSON'),
#  ('says', 'O'),
#  ('she', 'O'),
#  ('has', 'O'),
#  ('had', 'O'),
#  ('enough', 'O'),
#  ('of', 'O'),
#  ('it', 'O'),
#  ('and', 'O'),
#  ('wants', 'O'),
#  ('to', 'O'),
#  ('be', 'O'),
#  ('with', 'O'),
#  ('a', 'O'),
#  ('man', 'O'),
#  ('who', 'O'),
#  ('is', 'O'),
#  ('strong', 'O'),
#  ('and', 'O'),
#  ('shallow.', 'O'),
#  ('She', 'O'),
#  ('then', 'O'),
#  ('leaves', 'O'),
#  ('Elliot', 'PERSON'),
#  ('for', 'O'),
#  ('a', 'O'),
#  ('man', 'O'),
#  ('who', 'O'),
#  ('is', 'O'),
#  ('strong,', 'O'),
#  ('rude', 'O'),
#  ('and', 'O'),
#  ('completely', 'O'),
#  ('different', 'O'),
#  ('from', 'O'),
#  ('the', 'O'),
#  ('romantic', 'O'),
#  ('and', 'O'),
#  ('emotionally', 'O'),
#  ('sensitive', 'O'),
#  ('Elliot.', 'O'),
#  ('Elliot', 'PERSON'),
#  ('then', 'O'),
#  ('wishes', 'O'),
#  ('to', 'O'),
#  ('be', 'O'),
#  ('a', 'O'),
#  ('superstar', 'O'),
#  ('athlete', 'O'),
#  ('who', 'O'),
#  ('would', 'O'),
#  ('be', 'O'),
#  ('a', 'O'),
#  ('woman', 'O'),
#  ('magnet.', 'O'),
#  ('Satan', 'O'),
#  ('makes', 'O'),
#  ('him', 'O'),
#  ('a', 'O'),
#  ('clich̩-spewing', 'O'),
#  ('NBA', 'O'),
#  ('star,', 'O'),
#  ('but', 'O'),
#  ('also', 'O'),
#  ('gives', 'O'),
#  ('him', 'O'),
#  ('a', 'O'),
#  ('small', 'O'),
#  ('penis', 'O'),
#  ('and', 'O'),
#  ('a', 'O'),
#  ('low', 'O'),
#  ('IQ,', 'O'),
#  ('which', 'O'),
#  ('causes', 'O'),
#  ('Alison,', 'O'),
#  ('a', 'O'),
#  ('sports', 'O'),
#  ('reporter,', 'O'),
#  ('to', 'O'),
#  ('lose', 'O'),
#  ('interest', 'O'),
#  ('in', 'O'),
#  ('him', 'O'),
#  ('shortly', 'O'),
#  ('after', 'O'),
#  ('they', 'O'),
#  ('meet.', 'O'),
#  ('He', 'O'),
#  ('then', 'O'),
#  ('wishes', 'O'),
#  ('to', 'O'),
#  ('be', 'O'),
#  ('intelligent,', 'O'),
#  ('witty', 'O'),
#  ('and', 'O'),
#  ('well-endowed.', 'O'),
#  ('Satan', 'O'),
#  ('grants', 'O'),
#  ('this', 'O'),
#  ('by', 'O'),
#  ('making', 'O'),
#  ('him', 'O'),
#  ('a', 'O'),
#  ('famous', 'O'),
#  ('writer', 'O'),
#  ('whom', 'O'),
#  ('Alison', 'PERSON'),
#  ('falls', 'O'),
#  ('in', 'O'),
#  ('love', 'O'),
#  ('with', 'O'),
#  ('at', 'O'),
#  ('a', 'O'),
#  ('cocktail', 'O'),
#  ('party.', 'O'),
#  ('When', 'O'),
#  ('they', 'O'),
#  ('arrive', 'O'),
#  ('at', 'O'),
#  ("Elliot's", 'O'),
#  ('home', 'O'),
#  ('to', 'O'),
#  ('make', 'O'),
#  ('love', 'O'),
#  ('it', 'O'),
#  ('is', 'O'),
#  ('revealed', 'O'),
#  ('that', 'O'),
#  ('Elliot', 'PERSON'),
#  ('is', 'O'),
#  ('gay', 'O'),
#  ('and', 'O'),
#  ('living', 'O'),
#  ('with', 'O'),
#  ('a', 'O'),
#  ('flamboyant', 'O'),
#  ('male', 'O'),
#  ('partner.', 'O'),
#  ('Lastly,', 'O'),
#  ('Elliot', 'PERSON'),
#  ('wishes', 'O'),
#  ('to', 'O'),
#  ('be', 'O'),
#  ('President', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('United', 'LOCATION'),
#  ('States', 'LOCATION'),
#  ('to', 'O'),
#  ('try', 'O'),
#  ('to', 'O'),
#  ('improve', 'O'),
#  ('the', 'O'),
#  ('world', 'O'),
#  ('and', 'O'),
#  ('get', 'O'),
#  ('Alison', 'PERSON'),
#  ('to', 'O'),
#  ('take', 'O'),
#  ('him', 'O'),
#  ('seriously.', 'O'),
#  ('Satan', 'O'),
#  ('makes', 'O'),
#  ('him', 'O'),
#  ('Abraham', 'PERSON'),
#  ('Lincoln', 'PERSON'),
#  ('at', 'O'),
#  ("Ford's", 'O'),
#  ('Theatre', 'O'),
#  ('on', 'O'),
#  ('the', 'O'),
#  ('night', 'O'),
#  ('of', 'O'),
#  ('his', 'O'),
#  ('assassination', 'O'),
#  ('which', 'O'),
#  ('he', 'O'),
#  ('nearly', 'O'),
#  ('avoids.', 'O'),
#  ('After', 'O'),
#  ('each', 'O'),
#  ('wish', 'O'),
#  ('is', 'O'),
#  ('renounced,', 'O'),
#  ('Elliot', 'PERSON'),
#  ('meets', 'O'),
#  ('with', 'O'),
#  ('Satan', 'PERSON'),
#  ('and', 'O'),
#  ('she', 'O'),
#  ('blames', 'O'),
#  ('him', 'O'),
#  ('for', 'O'),
#  ('not', 'O'),
#  ('being', 'O'),
#  ('specific', 'O'),
#  ('enough.', 'O'),
#  ('Eventually', 'O'),
#  ('he', 'O'),
#  ('returns', 'O'),
#  ('to', 'O'),
#  ('work,', 'O'),
#  ('thinking', 'O'),
#  ('about', 'O'),
#  ('what', 'O'),
#  ('he', 'O'),
#  ('should', 'O'),
#  ('do', 'O'),
#  ('with', 'O'),
#  ('the', 'O'),
#  ('last', 'O'),
#  ('two', 'O'),
#  ('wishes.', 'O'),
#  ('Satan', 'O'),
#  ('appears', 'O'),
#  ('on', 'O'),
#  ('the', 'O'),
#  ('computer', 'O'),
#  ('screen,', 'O'),
#  ('pointing', 'O'),
#  ('out', 'O'),
#  ('that', 'O'),
#  ('on', 'O'),
#  ('their', 'O'),
#  ('first', 'O'),
#  ('meeting', 'O'),
#  ('he', 'O'),
#  ('asked', 'O'),
#  ('for', 'O'),
#  ('a', 'O'),
#  ('Big', 'O'),
#  ('Mac', 'O'),
#  ('and', 'O'),
#  ('Coke,', 'O'),
#  ('although', 'O'),
#  ('she', 'O'),
#  ('had', 'O'),
#  ('stated', 'O'),
#  ('that', 'O'),
#  ('it', 'O'),
#  ('was', 'O'),
#  ('a', 'O'),
#  ('test', 'O'),
#  ('wish', 'O'),
#  ('and', 'O'),
#  ('granted', 'O'),
#  ('it', 'O'),
#  ('before', 'O'),
#  ('Elliot', 'PERSON'),
#  ('signed', 'O'),
#  ('the', 'O'),
#  ('contract.', 'O'),
#  ('Elliot', 'PERSON'),
#  ('loses', 'O'),
#  ('his', 'O'),
#  ('patience', 'O'),
#  ('and', 'O'),
#  ('storms', 'O'),
#  ('out', 'O'),
#  ('of', 'O'),
#  ('his', 'O'),
#  ('office.', 'O'),
#  ('Elliot', 'PERSON'),
#  ('visits', 'O'),
#  ('a', 'O'),
#  ('church', 'O'),
#  ('looking', 'O'),
#  ('for', 'O'),
#  ("God's", 'O'),
#  ('help,', 'O'),
#  ('where', 'O'),
#  ('he', 'O'),
#  ('briefly', 'O'),
#  ('confesses', 'O'),
#  ('to', 'O'),
#  ('a', 'O'),
#  ('priest', 'O'),
#  ('who', 'O'),
#  ('seems', 'O'),
#  ('sympathetic.', 'O'),
#  ('However,', 'O'),
#  ('after', 'O'),
#  ('being', 'O'),
#  ('asked', 'O'),
#  ('whether', 'O'),
#  ('he', 'O'),
#  ('thinks', 'O'),
#  ('asking', 'O'),
#  ('Satan', 'O'),
#  ('for', 'O'),
#  ('a', 'O'),
#  ('Big', 'O'),
#  ('Mac', 'O'),
#  ('and', 'O'),
#  ('Coke', 'ORGANIZATION'),
#  ('counts', 'O'),
#  ('as', 'O'),
#  ('a', 'O'),
#  ('wish,', 'O'),
#  ('the', 'O'),
#  ('priest,', 'O'),
#  ('believing', 'O'),
#  ('he', 'O'),
#  ('is', 'O'),
#  ('drunk,', 'O'),
#  ('has', 'O'),
#  ('Elliot', 'PERSON'),
#  ('arrested.', 'O'),
#  ('The', 'O'),
#  ('sergeant', 'O'),
#  ('books', 'O'),
#  ('him,', 'O'),
#  ('and', 'O'),
#  ('Satan,', 'O'),
#  ('dressed', 'O'),
#  ('as', 'O'),
#  ('a', 'O'),
#  ('police', 'O'),
#  ('officer,', 'O'),
#  ('throws', 'O'),
#  ('him', 'O'),
#  ('in', 'O'),
#  ('a', 'O'),
#  ('cell,', 'O'),
#  ('telling', 'O'),
#  ('him', 'O'),
#  ('that', 'O'),
#  ('she', 'O'),
#  ('does', 'O'),
#  ('like', 'O'),
#  ('him,', 'O'),
#  ('and', 'O'),
#  ('it', 'O'),
#  ('would', 'O'),
#  ('not', 'O'),
#  ('hurt', 'O'),
#  ('to', 'O'),
#  ('have', 'O'),
#  ('her', 'O'),
#  ('as', 'O'),
#  ('a', 'O'),
#  ('friend.', 'O'),
#  ("Elliot's", 'O'),
#  ('cellmate', 'O'),
#  ('tells', 'O'),
#  ('him', 'O'),
#  ('that', 'O'),
#  ('he', 'O'),
#  ('cannot', 'O'),
#  ('possibly', 'O'),
#  ('sell', 'O'),
#  ('his', 'O'),
#  ('soul', 'O'),
#  ('as', 'O'),
#  ('it', 'O'),
#  ('belongs', 'O'),
#  ('to', 'O'),
#  ('God,', 'O'),
#  ('and', 'O'),
#  ('although', 'O'),
#  ('Satan', 'O'),
#  ('may', 'O'),
#  ('try', 'O'),
#  ('to', 'O'),
#  ('confuse', 'O'),
#  ('him,', 'O'),
#  ('in', 'O'),
#  ('the', 'O'),
#  ('end', 'O'),
#  ('he', 'O'),
#  ('will', 'O'),
#  ('realise', 'O'),
#  ('who', 'O'),
#  ('he', 'O'),
#  ('truly', 'O'),
#  ('is,', 'O'),
#  ('and', 'O'),
#  ('what', 'O'),
#  ('his', 'O'),
#  ('purpose', 'O'),
#  ('is.', 'O'),
#  ('Elliot', 'PERSON'),
#  ('questions', 'O'),
#  ('the', 'O'),
#  ('man', 'O'),
#  ('as', 'O'),
#  ('to', 'O'),
#  ('his', 'O'),
#  ('identity,', 'O'),
#  ('but', 'O'),
#  ('the', 'O'),
#  ('response', 'O'),
#  ('is', 'O'),
#  ('simply', 'O'),
#  ('"a', 'O'),
#  ('really', 'O'),
#  ('good', 'O'),
#  ('friend".', 'O'),
#  ('Elliot', 'PERSON'),
#  ('asks', 'O'),
#  ('Satan', 'O'),
#  ('to', 'O'),
#  ('cancel', 'O'),
#  ('their', 'O'),
#  ('contract.', 'O'),
#  ('When', 'O'),
#  ('Satan', 'O'),
#  ('refuses,', 'O'),
#  ('Elliot', 'PERSON'),
#  ('states', 'O'),
#  ('he', 'O'),
#  ('will', 'O'),
#  ('not', 'O'),
#  ('use', 'O'),
#  ('his', 'O'),
#  ('final', 'O'),
#  ('wish.', 'O'),
#  ('Satan', 'O'),
#  ('teleports', 'O'),
#  ('them', 'O'),
#  ('to', 'O'),
#  ('Hell,', 'O'),
#  ('where', 'O'),
#  ('she', 'O'),
#  ('transforms', 'O'),
#  ('first', 'O'),
#  ('into', 'O'),
#  ('a', 'O'),
#  ('black', 'O'),
#  ('horned', 'O'),
#  ('monster,', 'O'),
#  ('then', 'O'),
#  ('into', 'O'),
#  ('a', 'O'),
#  ('giant.', 'O'),
#  ('When', 'O'),
#  ('Satan', 'PERSON'),
#  ('pushes', 'O'),
#  ('him', 'O'),
#  ('to', 'O'),
#  ('make', 'O'),
#  ('a', 'O'),
#  ('final', 'O'),
#  ('wish,', 'O'),
#  ('Elliot', 'PERSON'),
#  ('wishes', 'O'),
#  ('that', 'O'),
#  ('Alison', 'PERSON'),
#  ('could', 'O'),
#  ('have', 'O'),
#  ('a', 'O'),
#  ('happy', 'O'),
#  ('life', 'O'),
#  ('-', 'O'),
#  ('with', 'O'),
#  ('or', 'O'),
#  ('without', 'O'),
#  ('him.', 'O'),
#  ('Satan', 'O'),
#  ('sighs', 'O'),
#  ('and', 'O'),
#  ('Elliot', 'PERSON'),
#  ('falls', 'O'),
#  ('into', 'O'),
#  ('the', 'O'),
#  ('depths', 'O'),
#  ('of', 'O'),
#  ('Hell.', 'O'),
#  ('Elliot', 'PERSON'),
#  ('wakes', 'O'),
#  ...]

# %%
# Import the RegexpParser
from nltk.chunk import RegexpParser

# Define custom tagged entities - group NE's together 

def chunker_rules(values):
    # Define  custom grammar (modified to be a valid regex).
    grammar = r'''
        PERSON:
                {<PERSON>+}
            '''
    cp = nltk.RegexpParser(grammar) # Create an instance of your custom parser.
    return cp.parse(values)         # Parse!

def entity_chunker(tagged_docs):
    chunks = []
#     for doc in tagged_docs:
    tree = chunker_rules(tagged_docs)
    for subtree in tree.subtrees():
#             if (subtree.node == 'WIDOW'):
        leaflist = [leaf[0] for leaf in subtree.leaves()]
        chunks.append(' '.join(leaflist))
    return chunks

# %%
entity_chunker(example)
# Out:
# ['Rami Eid is studying at Stony Brook University in NY , and he is a good boy .',
#  'Rami Eid']

# %% [markdown]
# ###Run chuncker to lift out names from summaries

# %%
# creating a new dict called sum_and_char to store summaries and corresponding characters
sum_and_char = {}
for i in range(len(sample)):
#     making a bag of words for roles
    roles_bag = []
    roles = sample[i][1]['roles']
    for j in range(len(roles)):
        roles_bag.append(roles[j]['role'])
    str = " ".join(roles_bag)
#     split roles on space, /, ' or "
    roles_bag = re.split(r' |/|\'|\"', str)
#     roles_bag = [i.lower() for i in roles_bag]
#     sorting entity_chuncking results into summaries and characters
    result = entity_chunker(sample[i][1]['summaries_combined_ner'])
    movie_name = sample[i][0]
    if len(result) <= 1:
        char_data = {}
    else:
        char_data = set(result[1:])
    sum_and_char[movie_name] = {"sum": result[0], \
                                "char_raw": char_data,\
                                "roles_bag": set(roles_bag)}
pprint(sum_and_char)
# Out:
# {'angelica.2015': {'char_raw': {'Constance', 'Joseph', 'Mitchell'},
#                    'roles_bag': {'Angelica',
#                                  'Anne',
#                                  'Barton',
#                                  'Beggar',
#                                  'Bookseller',
#                                  'Boy',
#                                  'Constance',
#                                  'Dr.',
#                                  'Girl',
#                                  'Joseph',
#                                  'Lady',
#                                  'Medical',
#                                  'Midwife',
#                                  'Montague',
#                                  'Mr.',
#                                  'Nora',
#                                  'Older',
#                                  'Park',
#                                  'Pendleton',
#                                  'Scientist',
#                                  'Snobby',
#                                  'Spirit',
#                                  'Student',
#                                  'Unnamed',
#                                  'Woman',
#                                  'Young',
#                                  'girl',
#                                  'in'},
#                    'sum': 'In Victorian England, sexual repression opens a '
#                           'rift between young couple Constance and Joseph '
#                           'after the birth of their daughter Angelica. As '
#                           'Constance becomes more and more protective of '
#                           'little Angelica, a ghostly predator begins to '
#                           'make its way through the house late at night... '
#                           'ANGELICA is a spellbinding ghost story about '
#                           'desire, repression and its consequences... The '
#                           'new film by Mitchell Lichtenstein, director of '
#                           'HAPPY TEARS and the cult favorite TEETH.'},
#  'bedazzled.2000': {'char_raw': {'Abraham Lincoln',
#                                  'Alison',
#                                  'Alison Gardner',
#                                  'Bob',
#                                  'Elliot',
#                                  'Elliot Richards',
#                                  'Nicole Delarusso',
#                                  'Satan'},
#                     'roles_bag': {'#1',
#                                   '#10',
#                                   '#3',
#                                   '#30',
#                                   '#4',
#                                   '(II)',
#                                   '(Rock',
#                                   'Actor',
#                                   'Advisor',
#                                   'African',
#                                   'Aide',
#                                   'Alejandro',
#                                   'Alison',
#                                   'Beach',
#                                   'Beer',
#                                   'Biggest',
#                                   'Bob',
#                                   'Booth',
#                                   'Bouncer',
#                                   'Businessman',
#                                   'Cafe',
#                                   'Caged',
#                                   'Car',
#                                   'Carol',
#                                   'Cellmate',
#                                   'Cheerleader',
#                                   'Churchgoer',
#                                   'Club',
#                                   'Clubgoer',
#                                   'Columbian',
#                                   'Cornell,',
#                                   'Crash',
#                                   'Customer',
#                                   'DV8',
#                                   'Dan',
#                                   'Dancer',
#                                   'Dealer',
#                                   'Demonic',
#                                   'Desk',
#                                   'Devil',
#                                   'Diablos',
#                                   'Drug',
#                                   'Eduardo',
#                                   'Elegant',
#                                   'Elliot',
#                                   'Employee',
#                                   'Esteban',
#                                   'Extra',
#                                   'Factory',
#                                   'Fan',
#                                   'Fantasy)',
#                                   'Fly',
#                                   'Foreman',
#                                   'Francisco',
#                                   'Garden',
#                                   'Girl',
#                                   'Go-Go',
#                                   'Goth',
#                                   'Guard',
#                                   'Guest',
#                                   'Hostess',
#                                   'Ivan',
#                                   'Jerry',
#                                   'Jock',
#                                   'John',
#                                   'Lance',
#                                   'Lawyer',
#                                   'Lincoln',
#                                   'Man',
#                                   'McDonald',
#                                   'Mover',
#                                   'NBA',
#                                   'Nicole',
#                                   'Office',
#                                   'Officer',
#                                   'Pablito',
#                                   'Park',
#                                   'Party',
#                                   'Patron',
#                                   'Pedestrian',
#                                   'Penthouse',
#                                   'Peter',
#                                   'Play',
#                                   'Player',
#                                   'Police',
#                                   'Priest',
#                                   'Prisoner',
#                                   'Raging',
#                                   'Raoul',
#                                   'Restaurant',
#                                   'Roberto',
#                                   'Russian',
#                                   'San',
#                                   'Security',
#                                   'Sergeant',
#                                   'Soldier',
#                                   'Sportscaster',
#                                   'Supervisor',
#                                   'Support',
#                                   'Surfer',
#                                   'Synedyne',
#                                   'Tech',
#                                   'The',
#                                   'Usher',
#                                   'Waitress',
#                                   'Wilkes',
#                                   'at',
#                                   'in',
#                                   's',
#                                   'the',
#                                   'worker'},
#                     'sum': 'Elliot Richardson, a socially awkward IT '
#                            'worker, is given seven wishes to get the girl '
#                            'of his dreams when he meets up with a very '
#                            'seductive Satan. The catch: his soul. Some of '
#                            'his wishes include being a 7 foot basketball '
#                            'star, a wealthy, powerful man, and a sensitive '
#                            'caring guy. But, as could be expected, the '
#                            'Devil must put her own little twist on each his '
#                            'fantasies. Elliot Richards, a socially '
#                            'incompetent technical advisor working at a '
#                            'call-center, has had a crush on Alison Gardner '
#                            'for nearly four years. One evening, which '
#                            'already started particularly bad for Elliot, '
#                            'she ditches him. Elliot wishes for her to be in '
#                            'his life with all his heart - and is heard. An '
#                            'incredibly beautiful young lady addresses '
#                            'Elliot, and after introducing herself as the '
#                            'Devil, Lucifer, the Princess of Darkness, she '
#                            'offers him a deal: Seven wishes for him, his '
#                            'Soul for her. Quickly, Elliot is convinced and '
#                            'accepts. But every wish he gets fulfilled has '
#                            'massive disadvantages as well, and soon Elliot '
#                            'wants to get out of the contract. The only '
#                            'thing that matters to him now is being able to '
#                            'take his chances by himself. Elliot Richards is '
#                            'a geeky, over-zealous man working a dead-end '
#                            'technical support job in a San Francisco '
#                            'computer company. He has no friends and his '
#                            'co-workers use him, knowing he will do anything '
#                            'for acceptance. He has a crush on his '
#                            'colleague, Alison Gardner , but lacks the '
#                            'courage to ask her out. After Elliot is again '
#                            'ditched by his co-workers, at a bar while '
#                            'trying to talk to Alison, he says to himself '
#                            'that he would give anything for Alison to be '
#                            'with him. Satan , in the form of a beautiful '
#                            'woman, overhears him and offers to give Elliot '
#                            'seven wishes in return for his soul. As a test, '
#                            'he wishes for a Big Mac and Coke. Satan takes '
#                            "him to McDonald's and places the order. Elliot "
#                            'has to pay for it, because, "there ain\'t no '
#                            'such thing as a free lunch." After taking '
#                            'Elliot to her office, based at a nightclub in '
#                            'Oakland, Satan convinces Elliot to sign her '
#                            'contract, and delivers further wishes. Each '
#                            'wish has Elliot living them out with Alison and '
#                            'his co-workers in surrogate roles. However, he '
#                            "doesn't know that Satan will always spoil his "
#                            "wishes by adding something he doesn't want. "
#                            'Elliot wishes to be rich and powerful, with '
#                            'Alison as his wife. Satan makes him a Colombian '
#                            'drug lord whose wife despises him and cheats on '
#                            'him with Raul, his co-worker, who is secretly '
#                            'planning to get rid of Elliot and take his '
#                            'position and property. Soon after there is a '
#                            "firefight between his and Raul's people where "
#                            'Elliot "dies". When he returns to the real '
#                            'world, Satan points out that he never wished '
#                            'for Alison to love him. Secondly, Elliot wishes '
#                            'to be emotionally sensitive so he will '
#                            'understand the needs and desires of women. '
#                            'Satan makes him so sensitive that he spends '
#                            'most of his time crying over how beautiful the '
#                            'world is, and constantly asks Alison, his '
#                            'girlfriend of "three magical weeks," whether he '
#                            'has hurt her or if she needs anything. Alison '
#                            'says she has had enough of it and wants to be '
#                            'with a man who is strong and shallow. She then '
#                            'leaves Elliot for a man who is strong, rude and '
#                            'completely different from the romantic and '
#                            'emotionally sensitive Elliot. Elliot then '
#                            'wishes to be a superstar athlete who would be a '
#                            'woman magnet. Satan makes him a clich̩-spewing '
#                            'NBA star, but also gives him a small penis and '
#                            'a low IQ, which causes Alison, a sports '
#                            'reporter, to lose interest in him shortly after '
#                            'they meet. He then wishes to be intelligent, '
#                            'witty and well-endowed. Satan grants this by '
#                            'making him a famous writer whom Alison falls in '
#                            'love with at a cocktail party. When they arrive '
#                            "at Elliot's home to make love it is revealed "
#                            'that Elliot is gay and living with a flamboyant '
#                            'male partner. Lastly, Elliot wishes to be '
#                            'President of the United States to try to '
#                            'improve the world and get Alison to take him '
#                            'seriously. Satan makes him Abraham Lincoln at '
#                            "Ford's Theatre on the night of his "
#                            'assassination which he nearly avoids. After '
#                            'each wish is renounced, Elliot meets with Satan '
#                            'and she blames him for not being specific '
#                            'enough. Eventually he returns to work, thinking '
#                            'about what he should do with the last two '
#                            'wishes. Satan appears on the computer screen, '
#                            'pointing out that on their first meeting he '
#                            'asked for a Big Mac and Coke, although she had '
#                            'stated that it was a test wish and granted it '
#                            'before Elliot signed the contract. Elliot loses '
#                            'his patience and storms out of his office. '
#                            "Elliot visits a church looking for God's help, "
#                            'where he briefly confesses to a priest who '
#                            'seems sympathetic. However, after being asked '
#                            'whether he thinks asking Satan for a Big Mac '
#                            'and Coke counts as a wish, the priest, '
#                            'believing he is drunk, has Elliot arrested. The '
#                            'sergeant books him, and Satan, dressed as a '
#                            'police officer, throws him in a cell, telling '
#                            'him that she does like him, and it would not '
#                            "hurt to have her as a friend. Elliot's cellmate "
#                            'tells him that he cannot possibly sell his soul '
#                            'as it belongs to God, and although Satan may '
#                            'try to confuse him, in the end he will realise '
#                            'who he truly is, and what his purpose is. '
#                            'Elliot questions the man as to his identity, '
#                            'but the response is simply "a really good '
#                            'friend". Elliot asks Satan to cancel their '
#                            'contract. When Satan refuses, Elliot states he '
#                            'will not use his final wish. Satan teleports '
#                            'them to Hell, where she transforms first into a '
#                            'black horned monster, then into a giant. When '
#                            'Satan pushes him to make a final wish, Elliot '
#                            'wishes that Alison could have a happy life - '
#                            'with or without him. Satan sighs and Elliot '
#                            'falls into the depths of Hell. Elliot wakes up '
#                            'on a marble staircase, wondering if it is '
#                            'Heaven. Satan tells him that it is a courthouse '
#                            'and that a selfless wish voids the contract, so '
#                            'he keeps his soul. Elliot admits that despite '
#                            'her manipulation of him he has come to like '
#                            'Satan and regards her as a friend, something '
#                            'she does not object to. She replies that Heaven '
#                            'and Hell can be found on Earth; it is up to '
#                            'humans to choose. Elliot asks Alison out, only '
#                            'to learn that she is already dating somebody. '
#                            'He continues with his life, but with a better '
#                            'understanding of who he is. Later Elliot is '
#                            'confronted by Bob, one of his co-workers, who '
#                            'starts ridiculing Elliot at the encouragement '
#                            'of his co-workers. Elliot loses his temper and '
#                            'grabs a terrified Bob by the shirt, but lets '
#                            'go, simply saying, "Nice talking to you." A '
#                            'threatening look sends his other co-workers '
#                            'scurrying away in fear. At home, he meets a new '
#                            'neighbor, Nicole Delarusso , whose looks '
#                            "resemble Alison's and has personality, "
#                            'interests and dressing styles similar to his. '
#                            'He offers to help her unpack and they '
#                            'presumably begin a relationship. While the two '
#                            "walk along a boulevard, Satan and Elliot's "
#                            'cellmate, both dressed in white, are seen '
#                            'playing chess, looking at Elliot and his new '
#                            'girlfriend revealing the cellmate is God. The '
#                            "scene ends by listing foibles of Nicole's and "
#                            "Elliot's, which they both tolerate."},
#  'city after dark.1980': {'char_raw': {'Ishmael Bernal'},
#                           'roles_bag': {'Adelina',
#                                         'Alex',
#                                         'Baby',
#                                         'Bea',
#                                         'Client',
#                                         'Cora',
#                                         'Gaying',
#                                         'Greggy',
#                                         'Husband',
#                                         'Kano',
#                                         'Mall',
#                                         'Manay',
#                                         'Marichu',
#                                         'Mother',
#                                         'Nelie',
#                                         'Pebrero',
#                                         'Recruiter',
#                                         'Sharon',
#                                         'Vanessa',
#                                         'Virgie',
#                                         'Virgir',
#                                         'Williams',
#                                         'couple',
#                                         's'},
#                           'sum': 'The hidden nightlife of ordinary people '
#                                  'living in Manila unveils. Lovers and '
#                                  "families' conflicts are radically pitted "
#                                  'against each other as they live in the '
#                                  'night streets rampant with drugs and '
#                                  'prostitution. The outstanding narrative '
#                                  'explicitly unravels the various '
#                                  'characters and episodes. This landmark '
#                                  'film of Ishmael Bernal depicts the '
#                                  'darkness of city life so vividly that it '
#                                  'was once prohibited to use the word '
#                                  "'Manila' on its title."},
#  'flirtation walk.1934': {'char_raw': {'Biddle',
#                                        'Biddle John Eldredge',
#                                        'Dick',
#                                        'Dick Powell',
#                                        'Fitts',
#                                        'Kit',
#                                        'Richard Palmer Grant',
#                                        "Scrapper Thornhill Pat O'Brien"},
#                           'roles_bag': {'',
#                                         'Ball',
#                                         'Bandleader',
#                                         'Biddle',
#                                         'Blonde',
#                                         'Butler',
#                                         'Cadet',
#                                         'Canary',
#                                         'Chase',
#                                         'Chorus',
#                                         'Dick',
#                                         'Dorcy',
#                                         'Dowager',
#                                         'Eight',
#                                         'Fitts',
#                                         'Gen.',
#                                         'Girl',
#                                         'Kit',
#                                         'Landacre',
#                                         'Leader',
#                                         'Lieut.',
#                                         'Native',
#                                         'Oskie',
#                                         'Redhead',
#                                         'Scrapper',
#                                         'Show',
#                                         'Sleepy',
#                                         'Spike',
#                                         'Superintendent',
#                                         'Thornhhill',
#                                         'at'},
#                           'sum': 'A Musical-romance with Dick Powell as a '
#                                  'private stationed in Hawaii who gets '
#                                  "involved with Ruby Keeler, the general's "
#                                  'engaged daughter. In order to avoid a '
#                                  'scandal, the pair break up, but meet '
#                                  "again years later when Powell's at West "
#                                  'Point producing the annual play that '
#                                  'turns out to star Keeler. Richard Palmer '
#                                  'Grant Dorcy, known as "Canary," is an '
#                                  'enlisted man in the United States Army. '
#                                  'Currently stationed on the Hawaiian '
#                                  'Islands, he has an affectionately '
#                                  'argumentative relationship with his '
#                                  "sergeant, Scrapper Thornhill Pat O'Brien "
#                                  '. Although he hates taking orders, Dick '
#                                  'has no intention of becoming an officer. '
#                                  'When General Fitts arrives at the base '
#                                  'with his daughter Kit , Dick is assigned '
#                                  'to drive her to the reception that '
#                                  'evening. Falling victim to the moonlit '
#                                  'night, Kit and Dick miss the reception '
#                                  'and attend a native luau instead. They '
#                                  "are discovered in each other's arms by "
#                                  'Lieutenant Biddle John Eldredge , who is '
#                                  'also in love with Kit. Biddle blames Dick '
#                                  "for ruining Kit's reputation and Dick "
#                                  'decides to desert. Scrapper begs Kit to '
#                                  'straighten things out with Biddle. To '
#                                  'prevent Dick from deserting, Kit tells '
#                                  'him that she is not in love with him, but '
#                                  'was responding to a crazy impulse. Stung '
#                                  'by her words, Dick decides to compete '
#                                  'with Biddle as an equal and applies for '
#                                  'West Point. He is accepted and does very '
#                                  "well, to Scrapper's delight. In Dick's "
#                                  'senior year, General Fitts is appointed '
#                                  'West Point superintendent. While most of '
#                                  'the men are infatuated with Kit, Dick is '
#                                  'cold to her. Consequently, he is not very '
#                                  'happy when the rest of the men insist '
#                                  'that she participate in the traditional '
#                                  'Hundredth Night theatrical performance. '
#                                  'Dick writes a show about a female general '
#                                  'with a message directed at Kit. After the '
#                                  'first rehearsal, Kit walks with Dick on '
#                                  'Flirtation Walk and tries to explain why '
#                                  'she told him she was not in love with '
#                                  'him. Dick is too angry to listen to Kit '
#                                  'but, during their on-stage love scene, '
#                                  'kisses her, and she admits she loves him. '
#                                  "When General Fitts announces Kit's "
#                                  'engagement to Biddle, Dick naturally is '
#                                  'confused, and visits her after lights out '
#                                  'to talk her out of marrying Biddle. He is '
#                                  "caught and, to protect Kit's name, agrees "
#                                  'to resign from the Academy. Scrapper '
#                                  'arrives at the Academy to see Dick '
#                                  'graduate and is disappointed to learn of '
#                                  "Dick's resignation. The day is saved when "
#                                  'Biddle tells Dick that his resignation '
#                                  'was not accepted and that Kit returned '
#                                  'his ring. Dick graduates a happy man.'},
#  'kotpanum chonio.1972': {'char_raw': {},
#                           'roles_bag': {'Chol',
#                                         'Hui',
#                                         'Koppun',
#                                         'Landowner',
#                                         'Mother',
#                                         'Old',
#                                         'Sun',
#                                         'Yong',
#                                         'man'},
#                           'sum': 'The country is occupied by the Japanese '
#                                  'imperialists. Koppun is selling flowers '
#                                  'at the market to get some money to buy '
#                                  'medicine for her sick mother. Her brother '
#                                  'is imprisoned, her father dead and her '
#                                  'sister blind.'}}

# %% [markdown]
# ###Check characters against roles for filtering

# %%
print("*************************")
print("filtered character list")
print("*************************")

for key, value in sum_and_char.items():
    sum_and_char[key]['char_filtered'] = []
    for char in value['char_raw']:
        flag = False
        char_split = char.split()
        for elem in char_split:
            if elem in value['roles_bag']:
                flag = True
        if flag == True:
            sum_and_char[key]['char_filtered'].append(char)
    print(sum_and_char[key]['char_filtered'])
            
# compare with the raw list of characters before filtering
# "dorcy" is not captured from richard palmer grant
# TODO: capture capitalized word right after the character name and make it part of the character name.
print("*************************")
print("raw character list")
print("*************************")

for value in sum_and_char.values():
#     pprint(values):
    for char in value['char_raw']:
        print(char)
# Out:
# *************************
# filtered character list
# *************************
# []
# ['Constance', 'Joseph']
# ['Dick Powell', "Scrapper Thornhill Pat O'Brien", 'Kit', 'Biddle John Eldredge', 'Fitts', 'Biddle', 'Dick']
# []
# ['Elliot', 'Abraham Lincoln', 'Bob', 'Alison Gardner', 'Elliot Richards', 'Alison', 'Nicole Delarusso']
# *************************
# raw character list
# *************************
# Constance
# Joseph
# Mitchell
# Dick Powell
# Scrapper Thornhill Pat O'Brien
# Kit
# Biddle John Eldredge
# Richard Palmer Grant
# Fitts
# Biddle
# Dick
# Ishmael Bernal
# Elliot
# Abraham Lincoln
# Satan
# Bob
# Alison Gardner
# Elliot Richards
# Alison
# Nicole Delarusso

# %%
sum_and_char
# Out:
# {'angelica.2015': {'char_filtered': ['Constance', 'Joseph'],
#   'char_raw': {'Constance', 'Joseph', 'Mitchell'},
#   'roles_bag': {'Angelica',
#    'Anne',
#    'Barton',
#    'Beggar',
#    'Bookseller',
#    'Boy',
#    'Constance',
#    'Dr.',
#    'Girl',
#    'Joseph',
#    'Lady',
#    'Medical',
#    'Midwife',
#    'Montague',
#    'Mr.',
#    'Nora',
#    'Older',
#    'Park',
#    'Pendleton',
#    'Scientist',
#    'Snobby',
#    'Spirit',
#    'Student',
#    'Unnamed',
#    'Woman',
#    'Young',
#    'girl',
#    'in'},
#   'sum': 'In Victorian England, sexual repression opens a rift between young couple Constance and Joseph after the birth of their daughter Angelica. As Constance becomes more and more protective of little Angelica, a ghostly predator begins to make its way through the house late at night... ANGELICA is a spellbinding ghost story about desire, repression and its consequences... The new film by Mitchell Lichtenstein, director of HAPPY TEARS and the cult favorite TEETH.'},
#  'bedazzled.2000': {'char_filtered': ['Elliot',
#    'Abraham Lincoln',
#    'Bob',
#    'Alison Gardner',
#    'Elliot Richards',
#    'Alison',
#    'Nicole Delarusso'],
#   'char_raw': {'Abraham Lincoln',
#    'Alison',
#    'Alison Gardner',
#    'Bob',
#    'Elliot',
#    'Elliot Richards',
#    'Nicole Delarusso',
#    'Satan'},
#   'roles_bag': {'#1',
#    '#10',
#    '#3',
#    '#30',
#    '#4',
#    '(II)',
#    '(Rock',
#    'Actor',
#    'Advisor',
#    'African',
#    'Aide',
#    'Alejandro',
#    'Alison',
#    'Beach',
#    'Beer',
#    'Biggest',
#    'Bob',
#    'Booth',
#    'Bouncer',
#    'Businessman',
#    'Cafe',
#    'Caged',
#    'Car',
#    'Carol',
#    'Cellmate',
#    'Cheerleader',
#    'Churchgoer',
#    'Club',
#    'Clubgoer',
#    'Columbian',
#    'Cornell,',
#    'Crash',
#    'Customer',
#    'DV8',
#    'Dan',
#    'Dancer',
#    'Dealer',
#    'Demonic',
#    'Desk',
#    'Devil',
#    'Diablos',
#    'Drug',
#    'Eduardo',
#    'Elegant',
#    'Elliot',
#    'Employee',
#    'Esteban',
#    'Extra',
#    'Factory',
#    'Fan',
#    'Fantasy)',
#    'Fly',
#    'Foreman',
#    'Francisco',
#    'Garden',
#    'Girl',
#    'Go-Go',
#    'Goth',
#    'Guard',
#    'Guest',
#    'Hostess',
#    'Ivan',
#    'Jerry',
#    'Jock',
#    'John',
#    'Lance',
#    'Lawyer',
#    'Lincoln',
#    'Man',
#    'McDonald',
#    'Mover',
#    'NBA',
#    'Nicole',
#    'Office',
#    'Officer',
#    'Pablito',
#    'Park',
#    'Party',
#    'Patron',
#    'Pedestrian',
#    'Penthouse',
#    'Peter',
#    'Play',
#    'Player',
#    'Police',
#    'Priest',
#    'Prisoner',
#    'Raging',
#    'Raoul',
#    'Restaurant',
#    'Roberto',
#    'Russian',
#    'San',
#    'Security',
#    'Sergeant',
#    'Soldier',
#    'Sportscaster',
#    'Supervisor',
#    'Support',
#    'Surfer',
#    'Synedyne',
#    'Tech',
#    'The',
#    'Usher',
#    'Waitress',
#    'Wilkes',
#    'at',
#    'in',
#    's',
#    'the',
#    'worker'},
#   'sum': 'Elliot Richardson, a socially awkward IT worker, is given seven wishes to get the girl of his dreams when he meets up with a very seductive Satan. The catch: his soul. Some of his wishes include being a 7 foot basketball star, a wealthy, powerful man, and a sensitive caring guy. But, as could be expected, the Devil must put her own little twist on each his fantasies. Elliot Richards, a socially incompetent technical advisor working at a call-center, has had a crush on Alison Gardner for nearly four years. One evening, which already started particularly bad for Elliot, she ditches him. Elliot wishes for her to be in his life with all his heart - and is heard. An incredibly beautiful young lady addresses Elliot, and after introducing herself as the Devil, Lucifer, the Princess of Darkness, she offers him a deal: Seven wishes for him, his Soul for her. Quickly, Elliot is convinced and accepts. But every wish he gets fulfilled has massive disadvantages as well, and soon Elliot wants to get out of the contract. The only thing that matters to him now is being able to take his chances by himself. Elliot Richards is a geeky, over-zealous man working a dead-end technical support job in a San Francisco computer company. He has no friends and his co-workers use him, knowing he will do anything for acceptance. He has a crush on his colleague, Alison Gardner , but lacks the courage to ask her out. After Elliot is again ditched by his co-workers, at a bar while trying to talk to Alison, he says to himself that he would give anything for Alison to be with him. Satan , in the form of a beautiful woman, overhears him and offers to give Elliot seven wishes in return for his soul. As a test, he wishes for a Big Mac and Coke. Satan takes him to McDonald\'s and places the order. Elliot has to pay for it, because, "there ain\'t no such thing as a free lunch." After taking Elliot to her office, based at a nightclub in Oakland, Satan convinces Elliot to sign her contract, and delivers further wishes. Each wish has Elliot living them out with Alison and his co-workers in surrogate roles. However, he doesn\'t know that Satan will always spoil his wishes by adding something he doesn\'t want. Elliot wishes to be rich and powerful, with Alison as his wife. Satan makes him a Colombian drug lord whose wife despises him and cheats on him with Raul, his co-worker, who is secretly planning to get rid of Elliot and take his position and property. Soon after there is a firefight between his and Raul\'s people where Elliot "dies". When he returns to the real world, Satan points out that he never wished for Alison to love him. Secondly, Elliot wishes to be emotionally sensitive so he will understand the needs and desires of women. Satan makes him so sensitive that he spends most of his time crying over how beautiful the world is, and constantly asks Alison, his girlfriend of "three magical weeks," whether he has hurt her or if she needs anything. Alison says she has had enough of it and wants to be with a man who is strong and shallow. She then leaves Elliot for a man who is strong, rude and completely different from the romantic and emotionally sensitive Elliot. Elliot then wishes to be a superstar athlete who would be a woman magnet. Satan makes him a clich̩-spewing NBA star, but also gives him a small penis and a low IQ, which causes Alison, a sports reporter, to lose interest in him shortly after they meet. He then wishes to be intelligent, witty and well-endowed. Satan grants this by making him a famous writer whom Alison falls in love with at a cocktail party. When they arrive at Elliot\'s home to make love it is revealed that Elliot is gay and living with a flamboyant male partner. Lastly, Elliot wishes to be President of the United States to try to improve the world and get Alison to take him seriously. Satan makes him Abraham Lincoln at Ford\'s Theatre on the night of his assassination which he nearly avoids. After each wish is renounced, Ellio ...
#  'city after dark.1980': {'char_filtered': [],
#   'char_raw': {'Ishmael Bernal'},
#   'roles_bag': {'Adelina',
#    'Alex',
#    'Baby',
#    'Bea',
#    'Client',
#    'Cora',
#    'Gaying',
#    'Greggy',
#    'Husband',
#    'Kano',
#    'Mall',
#    'Manay',
#    'Marichu',
#    'Mother',
#    'Nelie',
#    'Pebrero',
#    'Recruiter',
#    'Sharon',
#    'Vanessa',
#    'Virgie',
#    'Virgir',
#    'Williams',
#    'couple',
#    's'},
#   'sum': "The hidden nightlife of ordinary people living in Manila unveils. Lovers and families' conflicts are radically pitted against each other as they live in the night streets rampant with drugs and prostitution. The outstanding narrative explicitly unravels the various characters and episodes. This landmark film of Ishmael Bernal depicts the darkness of city life so vividly that it was once prohibited to use the word 'Manila' on its title."},
#  'flirtation walk.1934': {'char_filtered': ['Dick Powell',
#    "Scrapper Thornhill Pat O'Brien",
#    'Kit',
#    'Biddle John Eldredge',
#    'Fitts',
#    'Biddle',
#    'Dick'],
#   'char_raw': {'Biddle',
#    'Biddle John Eldredge',
#    'Dick',
#    'Dick Powell',
#    'Fitts',
#    'Kit',
#    'Richard Palmer Grant',
#    "Scrapper Thornhill Pat O'Brien"},
#   'roles_bag': {'',
#    'Ball',
#    'Bandleader',
#    'Biddle',
#    'Blonde',
#    'Butler',
#    'Cadet',
#    'Canary',
#    'Chase',
#    'Chorus',
#    'Dick',
#    'Dorcy',
#    'Dowager',
#    'Eight',
#    'Fitts',
#    'Gen.',
#    'Girl',
#    'Kit',
#    'Landacre',
#    'Leader',
#    'Lieut.',
#    'Native',
#    'Oskie',
#    'Redhead',
#    'Scrapper',
#    'Show',
#    'Sleepy',
#    'Spike',
#    'Superintendent',
#    'Thornhhill',
#    'at'},
#   'sum': 'A Musical-romance with Dick Powell as a private stationed in Hawaii who gets involved with Ruby Keeler, the general\'s engaged daughter. In order to avoid a scandal, the pair break up, but meet again years later when Powell\'s at West Point producing the annual play that turns out to star Keeler. Richard Palmer Grant Dorcy, known as "Canary," is an enlisted man in the United States Army. Currently stationed on the Hawaiian Islands, he has an affectionately argumentative relationship with his sergeant, Scrapper Thornhill Pat O\'Brien . Although he hates taking orders, Dick has no intention of becoming an officer. When General Fitts arrives at the base with his daughter Kit , Dick is assigned to drive her to the reception that evening. Falling victim to the moonlit night, Kit and Dick miss the reception and attend a native luau instead. They are discovered in each other\'s arms by Lieutenant Biddle John Eldredge , who is also in love with Kit. Biddle blames Dick for ruining Kit\'s reputation and Dick decides to desert. Scrapper begs Kit to straighten things out with Biddle. To prevent Dick from deserting, Kit tells him that she is not in love with him, but was responding to a crazy impulse. Stung by her words, Dick decides to compete with Biddle as an equal and applies for West Point. He is accepted and does very well, to Scrapper\'s delight. In Dick\'s senior year, General Fitts is appointed West Point superintendent. While most of the men are infatuated with Kit, Dick is cold to her. Consequently, he is not very happy when the rest of the men insist that she participate in the traditional Hundredth Night theatrical performance. Dick writes a show about a female general with a message directed at Kit. After the first rehearsal, Kit walks with Dick on Flirtation Walk and tries to explain why she told him she was not in love with him. Dick is too angry to listen to Kit but, during their on-stage love scene, kisses her, and she admits she loves him. When General Fitts announces Kit\'s engagement to Biddle, Dick naturally is confused, and visits her after lights out to talk her out of marrying Biddle. He is caught and, to protect Kit\'s name, agrees to resign from the Academy. Scrapper arrives at the Academy to see Dick graduate and is disappointed to learn of Dick\'s resignation. The day is saved when Biddle tells Dick that his resignation was not accepted and that Kit returned his ring. Dick graduates a happy man.'},
#  'kotpanum chonio.1972': {'char_filtered': [],
#   'char_raw': {},
#   'roles_bag': {'Chol',
#    'Hui',
#    'Koppun',
#    'Landowner',
#    'Mother',
#    'Old',
#    'Sun',
#    'Yong',
#    'man'},
#   'sum': 'The country is occupied by the Japanese imperialists. Koppun is selling flowers at the market to get some money to buy medicine for her sick mother. Her brother is imprisoned, her father dead and her sister blind.'}}

# %% [markdown]
# ###Define chunking regexp

# %%
string = "John is a farmer."
p = re.compile('John is a (.*)')
m = p.search(string)

# %%
m.group(1)
# Out:
# 'farmer.'

# %%
regex_str = '(.*) is a (.*)'
f = re.search(regex_str, string)

# %%
f.group(2)
# Out:
# 'farmer.'

# %%
for key, value in sum_and_char.items():
    for char in value['char_filtered']:
        regex_str = char + ' is a ([^.]+?)\.'
        p = re.compile(regex_str)
        m = p.search(value['sum'])
        if m:
            print(m.group(1))
        else:
            print('no match')
# Out:
# no match
# no match
# no match
# no match
# no match
# no match
# no match
# no match
# no match
# no match
# no match
# no match
# no match
# geeky, over-zealous man working a dead-end technical support job in a San Francisco computer company
# no match
# no match

# %%
post.tag(('John is a ' + 'geeky, over-zealous man working a dead-end technical support job in a San Francisco computer company').split())
# Out:
# [('John', 'NNP'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('geeky,', 'NN'),
#  ('over-zealous', 'JJ'),
#  ('man', 'NN'),
#  ('working', 'VBG'),
#  ('a', 'DT'),
#  ('dead-end', 'JJ'),
#  ('technical', 'JJ'),
#  ('support', 'NN'),
#  ('job', 'NN'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('San', 'NNP'),
#  ('Francisco', 'NNP'),
#  ('computer', 'NN'),
#  ('company', 'NN')]

# %%
for key, value in sum_and_char.items():
    for char in value['char_filtered']:
        regex_str = char + ', a ([^.]+?)\.'
        print(regex_str)
        p = re.compile(regex_str)
        m = p.search(value['sum'])
        if m:
            print(m.group(1))
        else:
            print('no match')
# Out:
# Constance, a ([^.]+?)\.
# no match
# Joseph, a ([^.]+?)\.
# no match
# Dick Powell, a ([^.]+?)\.
# no match
# Scrapper Thornhill Pat O'Brien, a ([^.]+?)\.
# no match
# Kit, a ([^.]+?)\.
# no match
# Biddle John Eldredge, a ([^.]+?)\.
# no match
# Fitts, a ([^.]+?)\.
# no match
# Biddle, a ([^.]+?)\.
# no match
# Dick, a ([^.]+?)\.
# no match
# Elliot, a ([^.]+?)\.
# no match
# Abraham Lincoln, a ([^.]+?)\.
# no match
# Bob, a ([^.]+?)\.
# no match
# Alison Gardner, a ([^.]+?)\.
# no match
# Elliot Richards, a ([^.]+?)\.
# socially incompetent technical advisor working at a call-center, has had a crush on Alison Gardner for nearly four years
# Alison, a ([^.]+?)\.
# sports reporter, to lose interest in him shortly after they meet
# Nicole Delarusso, a ([^.]+?)\.
# no match

# %%
string = post.tag("socially incompetent technical advisor working at a call-center, \
has had a crush on Alison Gardner for nearly four years".split())
string
# Out:
# [('socially', 'RB'),
#  ('incompetent', 'JJ'),
#  ('technical', 'JJ'),
#  ('advisor', 'NN'),
#  ('working', 'VBG'),
#  ('at', 'IN'),
#  ('a', 'DT'),
#  ('call-center,', 'NN'),
#  ('has', 'VBZ'),
#  ('had', 'VBN'),
#  ('a', 'DT'),
#  ('crush', 'NN'),
#  ('on', 'IN'),
#  ('Alison', 'NNP'),
#  ('Gardner', 'NNP'),
#  ('for', 'IN'),
#  ('nearly', 'RB'),
#  ('four', 'CD'),
#  ('years', 'NNS')]

# %%
# TODO: define multiple grammar
cp = nltk.RegexpParser('CHUNK: {^<.*>+?<NN.*>+}')
# brown = nltk.corpus.brown
# for sent in tagged:
tree = cp.parse(string)
for subtree in tree.subtrees():
    if subtree.label() == 'CHUNK': 
        print(subtree)
        test_str = subtree
# Out:
# (CHUNK socially/RB incompetent/JJ technical/JJ advisor/NN)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-408-705d3838ed29> in <module>()
# ----> 1 str(test_str)
#
# TypeError: 'str' object is not callable
